# %%
# !pip install torch_geometric
# !pip install git+https://github.com/Blealtan/efficient-kan.git
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.13.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2025.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (7.1.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2025.10.5)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal>=1.4.0->aiohttp->torch_geometric) (4.15.0)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torch_geometric) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torch_geometric) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torch_geometric) (2024.2.0)
# Downloading torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 36.0 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.7.0
# Collecting git+https://github.com/Blealtan/efficient-kan.git
#   Cloning https://github.com/Blealtan/efficient-kan.git to /tmp/pip-req-build-mmb8xe8x
#   Running command git clone --filter=blob:none --quiet https://github.com/Blealtan/efficient-kan.git /tmp/pip-req-build-mmb8xe8x
#   Resolved https://github.com/Blealtan/efficient-kan.git to commit 7b6ce1c87f18c8bc90c208f6b494042344216b11
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (2.6.0+cu124)
# Requirement already satisfied: pytest>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (8.4.1)
# Requirement already satisfied: tqdm>=4.66.2 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (4.67.1)
# Requirement already satisfied: torchvision>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (0.21.0+cu124)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (2.1.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (25.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (2.19.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (2025.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.3.0->efficient-kan==0.1.0) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.18.0->efficient-kan==0.1.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.18.0->efficient-kan==0.1.0) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.3.0->efficient-kan==0.1.0) (3.0.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2.4.1)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 122.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 94.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 48.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 25.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 5.8 MB/s eta 0:00:00
# Building wheels for collected packages: efficient-kan
#   Building wheel for efficient-kan (pyproject.toml) ... done
#   Created wheel for efficient-kan: filename=efficient_kan-0.1.0-py3-none-any.whl size=5981 sha256=3fadb37365bda971d6bcb716e5ecf58aca9c70ee79e32324453796857b325548
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gi_bu054/wheels/da/a3/b4/30b3e3df2edaded3c87227cb9faea5878f18ec03e1c2137839
# Successfully built efficient-kan
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, efficient-kan
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed efficient-kan-0.1.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !git clone https://agusth24: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@github.com/agusth24/ethereum-fraud-detection.git
# Out:
# Cloning into 'ethereum-fraud-detection'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 51 (delta 23), reused 45 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (51/51), 14.72 KiB | 2.94 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/wacgan-ethereum-balanced/graph_data/wgangp_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GCN \
--classifier CNN \
--epochs_stage1 200 --epochs_stage2 200 --patience 50 --use_oversampling --output_file --use_csl --csl_weight 0.2
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/wacgan-ethereum-balanced/graph_data/wgangp_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 7713 nodes and 24896 edges
# Merge Info: 7613 overlapping nodes (anchors), 100 new synthetic nodes.
# Num nodes 7713 | Features: torch.Size([7713, 27]) | Fraud Train: 139 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5581 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7713, Edges: 24896, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 200, Patience: 50
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GCN + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GCN_CNN_OS_CSL_0...
#       Stage 1 Epoch 10 | Loss: 8.5602 | Val Loss: 6.4205
#       Stage 1 Epoch 20 | Loss: 8.5438 | Val Loss: 6.4210
#       Stage 1 Epoch 30 | Loss: 8.5401 | Val Loss: 6.4207
#       Stage 1 Epoch 40 | Loss: 8.5353 | Val Loss: 6.4201
#       Stage 1 Epoch 50 | Loss: 8.5296 | Val Loss: 6.4169
#       Stage 1 Epoch 60 | Loss: 8.5324 | Val Loss: 6.4133
#       Stage 1 Epoch 70 | Loss: 8.5288 | Val Loss: 6.4116
#       Stage 1 Epoch 80 | Loss: 8.5269 | Val Loss: 6.4115
#       Stage 1 Epoch 90 | Loss: 8.5253 | Val Loss: 6.4093
#       Stage 1 Epoch 100 | Loss: 8.5239 | Val Loss: 6.4103
#       Stage 1 Epoch 110 | Loss: 8.5267 | Val Loss: 6.4114
#       Stage 1 Epoch 120 | Loss: 8.5216 | Val Loss: 6.4113
#       Stage 1 Epoch 130 | Loss: 8.5213 | Val Loss: 6.4109
#       Stage 1 Epoch 140 | Loss: 8.5242 | Val Loss: 6.4120
#       Stage 1 Epoch 150 | Loss: 8.5205 | Val Loss: 6.4126
#       Stage 1 Epoch 160 | Loss: 8.5187 | Val Loss: 6.4113
#       Stage 1 Epoch 170 | Loss: 8.5211 | Val Loss: 6.4103
#       Stage 1 Epoch 180 | Loss: 8.5207 | Val Loss: 6.4113
#       Stage 1 Epoch 190 | Loss: 8.5221 | Val Loss: 6.4105
#       Stage 1 Epoch 200 | Loss: 8.5219 | Val Loss: 6.4122
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_CNN_OS_CSL_0...
#       Stage 2 Epoch 10 | Loss: 0.1123 | Val Loss: 0.0379
#       Stage 2 Epoch 20 | Loss: 0.0160 | Val Loss: 0.0337
#       Stage 2 Epoch 30 | Loss: 0.0102 | Val Loss: 0.0290
#       Stage 2 Epoch 40 | Loss: 0.0090 | Val Loss: 0.0299
#       Stage 2 Epoch 50 | Loss: 0.0081 | Val Loss: 0.0254
#       Stage 2 Epoch 60 | Loss: 0.0090 | Val Loss: 0.0276
#       Stage 2 Epoch 70 | Loss: 0.0065 | Val Loss: 0.0198
#       Stage 2 Epoch 80 | Loss: 0.0063 | Val Loss: 0.0219
#       Stage 2 Epoch 90 | Loss: 0.0053 | Val Loss: 0.0209
#       Stage 2 Epoch 100 | Loss: 0.0064 | Val Loss: 0.0197
#       Stage 2 Epoch 110 | Loss: 0.0078 | Val Loss: 0.0279
#       Stage 2 Epoch 120 | Loss: 0.0052 | Val Loss: 0.0221
#       Stage 2 Early stopping at epoch 125
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_CNN_OS_CSL_0.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9960604070912672, 'prec': 0.7777777777777778, 'rec': 0.6363636363636364, 'f1': 0.7000000000000001}
# Results ready to be saved to results/eval_first_graph_GCN_CNN_OS_CSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GCN + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GCN_CNN_OS_CSL_42...
#       Stage 1 Epoch 10 | Loss: 8.5666 | Val Loss: 6.4270
#       Stage 1 Epoch 20 | Loss: 8.5463 | Val Loss: 6.4230
#       Stage 1 Epoch 30 | Loss: 8.5407 | Val Loss: 6.4200
#       Stage 1 Epoch 40 | Loss: 8.5381 | Val Loss: 6.4210
#       Stage 1 Epoch 50 | Loss: 8.5369 | Val Loss: 6.4201
#       Stage 1 Epoch 60 | Loss: 8.5329 | Val Loss: 6.4191
#       Stage 1 Epoch 70 | Loss: 8.5289 | Val Loss: 6.4185
#       Stage 1 Epoch 80 | Loss: 8.5342 | Val Loss: 6.4150
#       Stage 1 Epoch 90 | Loss: 8.5301 | Val Loss: 6.4144
#       Stage 1 Epoch 100 | Loss: 8.5276 | Val Loss: 6.4115
#       Stage 1 Epoch 110 | Loss: 8.5277 | Val Loss: 6.4123
#       Stage 1 Epoch 120 | Loss: 8.5256 | Val Loss: 6.4105
#       Stage 1 Epoch 130 | Loss: 8.5243 | Val Loss: 6.4131
#       Stage 1 Epoch 140 | Loss: 8.5226 | Val Loss: 6.4126
#       Stage 1 Epoch 150 | Loss: 8.5204 | Val Loss: 6.4133
#       Stage 1 Epoch 160 | Loss: 8.5230 | Val Loss: 6.4113
#       Stage 1 Epoch 170 | Loss: 8.5180 | Val Loss: 6.4130
#       Stage 1 Epoch 180 | Loss: 8.5224 | Val Loss: 6.4113
#       Stage 1 Epoch 190 | Loss: 8.5191 | Val Loss: 6.4118
#       Stage 1 Epoch 200 | Loss: 8.5203 | Val Loss: 6.4116
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_CNN_OS_CSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0954 | Val Loss: 0.0428
#       Stage 2 Epoch 20 | Loss: 0.0141 | Val Loss: 0.0355
#       Stage 2 Epoch 30 | Loss: 0.0115 | Val Loss: 0.0360
#       Stage 2 Epoch 40 | Loss: 0.0090 | Val Loss: 0.0214
#       Stage 2 Epoch 50 | Loss: 0.0076 | Val Loss: 0.0270
#       Stage 2 Epoch 60 | Loss: 0.0066 | Val Loss: 0.0262
#       Stage 2 Epoch 70 | Loss: 0.0059 | Val Loss: 0.0245
#       Stage 2 Epoch 80 | Loss: 0.0060 | Val Loss: 0.0241
#       Stage 2 Epoch 90 | Loss: 0.0063 | Val Loss: 0.0237
#       Stage 2 Early stopping at epoch 98
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_CNN_OS_CSL_42.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9954038082731451, 'prec': 0.7, 'rec': 0.6363636363636364, 'f1': 0.6666666666666666}
# Results ready to be saved to results/eval_first_graph_GCN_CNN_OS_CSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GCN + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GCN_CNN_OS_CSL_101...
#       Stage 1 Epoch 10 | Loss: 8.5628 | Val Loss: 6.4208
#       Stage 1 Epoch 20 | Loss: 8.5455 | Val Loss: 6.4226
#       Stage 1 Epoch 30 | Loss: 8.5406 | Val Loss: 6.4225
#       Stage 1 Epoch 40 | Loss: 8.5377 | Val Loss: 6.4210
#       Stage 1 Epoch 50 | Loss: 8.5335 | Val Loss: 6.4206
#       Stage 1 Epoch 60 | Loss: 8.5320 | Val Loss: 6.4183
#       Stage 1 Epoch 70 | Loss: 8.5284 | Val Loss: 6.4150
#       Stage 1 Epoch 80 | Loss: 8.5255 | Val Loss: 6.4132
#       Stage 1 Epoch 90 | Loss: 8.5264 | Val Loss: 6.4119
#       Stage 1 Epoch 100 | Loss: 8.5280 | Val Loss: 6.4113
#       Stage 1 Epoch 110 | Loss: 8.5217 | Val Loss: 6.4110
#       Stage 1 Epoch 120 | Loss: 8.5222 | Val Loss: 6.4103
#       Stage 1 Epoch 130 | Loss: 8.5217 | Val Loss: 6.4115
#       Stage 1 Epoch 140 | Loss: 8.5229 | Val Loss: 6.4126
#       Stage 1 Epoch 150 | Loss: 8.5225 | Val Loss: 6.4116
#       Stage 1 Epoch 160 | Loss: 8.5201 | Val Loss: 6.4119
#       Stage 1 Epoch 170 | Loss: 8.5216 | Val Loss: 6.4112
#       Stage 1 Epoch 180 | Loss: 8.5202 | Val Loss: 6.4113
#       Stage 1 Epoch 190 | Loss: 8.5212 | Val Loss: 6.4105
#       Stage 1 Epoch 200 | Loss: 8.5219 | Val Loss: 6.4099
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_CNN_OS_CSL_101...
#       Stage 2 Epoch 10 | Loss: 0.1195 | Val Loss: 0.0445
#       Stage 2 Epoch 20 | Loss: 0.1331 | Val Loss: 0.0389
#       Stage 2 Epoch 30 | Loss: 0.0501 | Val Loss: 0.0417
#       Stage 2 Epoch 40 | Loss: 0.0119 | Val Loss: 0.0334
#       Stage 2 Epoch 50 | Loss: 0.0097 | Val Loss: 0.0361
#       Stage 2 Epoch 60 | Loss: 0.0067 | Val Loss: 0.0205
#       Stage 2 Epoch 70 | Loss: 0.0065 | Val Loss: 0.0224
#       Stage 2 Epoch 80 | Loss: 0.0083 | Val Loss: 0.0257
#       Stage 2 Epoch 90 | Loss: 0.0053 | Val Loss: 0.0214
#       Stage 2 Epoch 100 | Loss: 0.0059 | Val Loss: 0.0239
#       Stage 2 Epoch 110 | Loss: 0.0047 | Val Loss: 0.0238
#       Stage 2 Epoch 120 | Loss: 0.0042 | Val Loss: 0.0243
#       Stage 2 Early stopping at epoch 129
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_CNN_OS_CSL_101.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9960604070912672, 'prec': 0.7777777777777778, 'rec': 0.6363636363636364, 'f1': 0.7000000000000001}
# Results ready to be saved to results/eval_first_graph_GCN_CNN_OS_CSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GCN + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GCN_CNN_OS_CSL_1024...
#       Stage 1 Epoch 10 | Loss: 8.5574 | Val Loss: 6.4179
#       Stage 1 Epoch 20 | Loss: 8.5436 | Val Loss: 6.4261
#       Stage 1 Epoch 30 | Loss: 8.5388 | Val Loss: 6.4212
#       Stage 1 Epoch 40 | Loss: 8.5361 | Val Loss: 6.4199
#       Stage 1 Epoch 50 | Loss: 8.5348 | Val Loss: 6.4208
#       Stage 1 Epoch 60 | Loss: 8.5318 | Val Loss: 6.4182
#       Stage 1 Epoch 70 | Loss: 8.5285 | Val Loss: 6.4148
#       Stage 1 Epoch 80 | Loss: 8.5269 | Val Loss: 6.4125
#       Stage 1 Epoch 90 | Loss: 8.5227 | Val Loss: 6.4103
#       Stage 1 Epoch 100 | Loss: 8.5266 | Val Loss: 6.4094
#       Stage 1 Epoch 110 | Loss: 8.5228 | Val Loss: 6.4100
#       Stage 1 Epoch 120 | Loss: 8.5243 | Val Loss: 6.4096
#       Stage 1 Epoch 130 | Loss: 8.5231 | Val Loss: 6.4116
#       Stage 1 Epoch 140 | Loss: 8.5228 | Val Loss: 6.4105
#       Stage 1 Epoch 150 | Loss: 8.5233 | Val Loss: 6.4097
#       Stage 1 Epoch 160 | Loss: 8.5202 | Val Loss: 6.4102
#       Stage 1 Epoch 170 | Loss: 8.5212 | Val Loss: 6.4123
#       Stage 1 Epoch 180 | Loss: 8.5217 | Val Loss: 6.4136
#       Stage 1 Epoch 190 | Loss: 8.5199 | Val Loss: 6.4098
#       Stage 1 Epoch 200 | Loss: 8.5215 | Val Loss: 6.4145
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_CNN_OS_CSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.1262 | Val Loss: 0.0581
#       Stage 2 Epoch 20 | Loss: 0.0219 | Val Loss: 0.0310
#       Stage 2 Epoch 30 | Loss: 0.0104 | Val Loss: 0.0249
#       Stage 2 Epoch 40 | Loss: 0.0091 | Val Loss: 0.0268
#       Stage 2 Epoch 50 | Loss: 0.0082 | Val Loss: 0.0227
#       Stage 2 Epoch 60 | Loss: 0.0076 | Val Loss: 0.0211
#       Stage 2 Epoch 70 | Loss: 0.0083 | Val Loss: 0.0216
#       Stage 2 Epoch 80 | Loss: 0.0079 | Val Loss: 0.0233
#       Stage 2 Epoch 90 | Loss: 0.0067 | Val Loss: 0.0246
#       Stage 2 Epoch 100 | Loss: 0.0057 | Val Loss: 0.0196
#       Stage 2 Epoch 110 | Loss: 0.0077 | Val Loss: 0.0214
#       Stage 2 Epoch 120 | Loss: 0.0068 | Val Loss: 0.0157
#       Stage 2 Epoch 130 | Loss: 0.0070 | Val Loss: 0.0280
#       Stage 2 Epoch 140 | Loss: 0.0050 | Val Loss: 0.0208
#       Stage 2 Epoch 150 | Loss: 0.0053 | Val Loss: 0.0190
#       Stage 2 Early stopping at epoch 157
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_CNN_OS_CSL_1024.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9947472094550229, 'prec': 0.6363636363636364, 'rec': 0.6363636363636364, 'f1': 0.6363636363636364}
# Results ready to be saved to results/eval_first_graph_GCN_CNN_OS_CSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GCN + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GCN_CNN_OS_CSL_2025...
#       Stage 1 Epoch 10 | Loss: 8.5636 | Val Loss: 6.4201
#       Stage 1 Epoch 20 | Loss: 8.5416 | Val Loss: 6.4221
#       Stage 1 Epoch 30 | Loss: 8.5348 | Val Loss: 6.4198
#       Stage 1 Epoch 40 | Loss: 8.5336 | Val Loss: 6.4166
#       Stage 1 Epoch 50 | Loss: 8.5308 | Val Loss: 6.4145
#       Stage 1 Epoch 60 | Loss: 8.5256 | Val Loss: 6.4123
#       Stage 1 Epoch 70 | Loss: 8.5257 | Val Loss: 6.4116
#       Stage 1 Epoch 80 | Loss: 8.5267 | Val Loss: 6.4112
#       Stage 1 Epoch 90 | Loss: 8.5240 | Val Loss: 6.4115
#       Stage 1 Epoch 100 | Loss: 8.5219 | Val Loss: 6.4116
#       Stage 1 Epoch 110 | Loss: 8.5221 | Val Loss: 6.4093
#       Stage 1 Epoch 120 | Loss: 8.5208 | Val Loss: 6.4108
#       Stage 1 Epoch 130 | Loss: 8.5209 | Val Loss: 6.4101
#       Stage 1 Epoch 140 | Loss: 8.5212 | Val Loss: 6.4116
#       Stage 1 Epoch 150 | Loss: 8.5226 | Val Loss: 6.4120
#       Stage 1 Epoch 160 | Loss: 8.5201 | Val Loss: 6.4115
#       Stage 1 Epoch 170 | Loss: 8.5207 | Val Loss: 6.4122
#       Stage 1 Epoch 180 | Loss: 8.5209 | Val Loss: 6.4131
#       Stage 1 Epoch 190 | Loss: 8.5185 | Val Loss: 6.4121
#       Stage 1 Epoch 200 | Loss: 8.5187 | Val Loss: 6.4125
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_CNN_OS_CSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.0233 | Val Loss: 0.0309
#       Stage 2 Epoch 20 | Loss: 0.0123 | Val Loss: 0.0471
#       Stage 2 Epoch 30 | Loss: 0.0122 | Val Loss: 0.0373
#       Stage 2 Epoch 40 | Loss: 0.0067 | Val Loss: 0.0326
#       Stage 2 Epoch 50 | Loss: 0.0069 | Val Loss: 0.0290
#       Stage 2 Epoch 60 | Loss: 0.0052 | Val Loss: 0.0232
#       Stage 2 Epoch 70 | Loss: 0.0056 | Val Loss: 0.0292
#       Stage 2 Epoch 80 | Loss: 0.0042 | Val Loss: 0.0213
#       Stage 2 Early stopping at epoch 88
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_CNN_OS_CSL_2025.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9954038082731451, 'prec': 0.75, 'rec': 0.5454545454545454, 'f1': 0.631578947368421}
# Results ready to be saved to results/eval_first_graph_GCN_CNN_OS_CSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/wacgan-ethereum-balanced/graph_data/wgangp_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GAT \
--classifier CNN \
--epochs_stage1 200 --epochs_stage2 200 --patience 50 --use_oversampling --output_file --use_csl --csl_weight 0.2
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/wacgan-ethereum-balanced/graph_data/wgangp_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 7713 nodes and 24896 edges
# Merge Info: 7613 overlapping nodes (anchors), 100 new synthetic nodes.
# Num nodes 7713 | Features: torch.Size([7713, 27]) | Fraud Train: 139 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5581 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7713, Edges: 24896, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 200, Patience: 50
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GAT + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GAT_CNN_OS_CSL_0...
#       Stage 1 Epoch 10 | Loss: 8.6262 | Val Loss: 6.4131
#       Stage 1 Epoch 20 | Loss: 8.6213 | Val Loss: 6.4117
#       Stage 1 Epoch 30 | Loss: 8.6178 | Val Loss: 6.4117
#       Stage 1 Epoch 40 | Loss: 8.6211 | Val Loss: 6.4102
#       Stage 1 Epoch 50 | Loss: 8.6157 | Val Loss: 6.4095
#       Stage 1 Epoch 60 | Loss: 8.6148 | Val Loss: 6.4094
#       Stage 1 Epoch 70 | Loss: 8.6140 | Val Loss: 6.4096
#       Stage 1 Epoch 80 | Loss: 8.6152 | Val Loss: 6.4117
#       Stage 1 Epoch 90 | Loss: 8.6184 | Val Loss: 6.4109
#       Stage 1 Epoch 100 | Loss: 8.6171 | Val Loss: 6.4123
#       Stage 1 Epoch 110 | Loss: 8.6109 | Val Loss: 6.4110
#       Stage 1 Epoch 120 | Loss: 8.6086 | Val Loss: 6.4103
#       Stage 1 Epoch 130 | Loss: 8.6105 | Val Loss: 6.4102
#       Stage 1 Epoch 140 | Loss: 8.6135 | Val Loss: 6.4101
#       Stage 1 Epoch 150 | Loss: 8.6139 | Val Loss: 6.4081
#       Stage 1 Epoch 160 | Loss: 8.6174 | Val Loss: 6.4077
#       Stage 1 Epoch 170 | Loss: 8.6144 | Val Loss: 6.4079
#       Stage 1 Epoch 180 | Loss: 8.6118 | Val Loss: 6.4079
#       Stage 1 Epoch 190 | Loss: 8.6164 | Val Loss: 6.4081
#       Stage 1 Epoch 200 | Loss: 8.6124 | Val Loss: 6.4076
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_CNN_OS_CSL_0...
#       Stage 2 Epoch 10 | Loss: 0.1108 | Val Loss: 0.0425
#       Stage 2 Epoch 20 | Loss: 0.0807 | Val Loss: 0.0269
#       Stage 2 Epoch 30 | Loss: 0.0564 | Val Loss: 0.0460
#       Stage 2 Epoch 40 | Loss: 0.0374 | Val Loss: 0.0358
#       Stage 2 Epoch 50 | Loss: 0.0279 | Val Loss: 0.0245
#       Stage 2 Epoch 60 | Loss: 0.0226 | Val Loss: 0.0191
#       Stage 2 Epoch 70 | Loss: 0.0277 | Val Loss: 0.0192
#       Stage 2 Epoch 80 | Loss: 0.0196 | Val Loss: 0.0294
#       Stage 2 Epoch 90 | Loss: 0.0234 | Val Loss: 0.0257
#       Stage 2 Epoch 100 | Loss: 0.0202 | Val Loss: 0.0287
#       Stage 2 Epoch 110 | Loss: 0.0217 | Val Loss: 0.0382
#       Stage 2 Epoch 120 | Loss: 0.0226 | Val Loss: 0.0253
#       Stage 2 Epoch 130 | Loss: 0.0225 | Val Loss: 0.0329
#       Stage 2 Epoch 140 | Loss: 0.0236 | Val Loss: 0.0112
#       Stage 2 Epoch 150 | Loss: 0.0237 | Val Loss: 0.0304
#       Stage 2 Epoch 160 | Loss: 0.0214 | Val Loss: 0.0238
#       Stage 2 Epoch 170 | Loss: 0.0181 | Val Loss: 0.0314
#       Stage 2 Epoch 180 | Loss: 0.0156 | Val Loss: 0.0291
#       Stage 2 Epoch 190 | Loss: 0.0232 | Val Loss: 0.0162
#       Stage 2 Epoch 200 | Loss: 0.0207 | Val Loss: 0.0295
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_CNN_OS_CSL_0.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9960604070912672, 'prec': 0.6923076923076923, 'rec': 0.8181818181818182, 'f1': 0.7500000000000001}
# Results ready to be saved to results/eval_first_graph_GAT_CNN_OS_CSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GAT + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GAT_CNN_OS_CSL_42...
#       Stage 1 Epoch 10 | Loss: 8.6308 | Val Loss: 6.4150
#       Stage 1 Epoch 20 | Loss: 8.6253 | Val Loss: 6.4127
#       Stage 1 Epoch 30 | Loss: 8.6244 | Val Loss: 6.4127
#       Stage 1 Epoch 40 | Loss: 8.6227 | Val Loss: 6.4121
#       Stage 1 Epoch 50 | Loss: 8.6196 | Val Loss: 6.4110
#       Stage 1 Epoch 60 | Loss: 8.6138 | Val Loss: 6.4097
#       Stage 1 Epoch 70 | Loss: 8.6176 | Val Loss: 6.4093
#       Stage 1 Epoch 80 | Loss: 8.6165 | Val Loss: 6.4092
#       Stage 1 Epoch 90 | Loss: 8.6171 | Val Loss: 6.4092
#       Stage 1 Epoch 100 | Loss: 8.6154 | Val Loss: 6.4092
#       Stage 1 Epoch 110 | Loss: 8.6163 | Val Loss: 6.4090
#       Stage 1 Epoch 120 | Loss: 8.6162 | Val Loss: 6.4089
#       Stage 1 Epoch 130 | Loss: 8.6142 | Val Loss: 6.4087
#       Stage 1 Epoch 140 | Loss: 8.6140 | Val Loss: 6.4086
#       Stage 1 Epoch 150 | Loss: 8.6122 | Val Loss: 6.4082
#       Stage 1 Epoch 160 | Loss: 8.6147 | Val Loss: 6.4087
#       Stage 1 Epoch 170 | Loss: 8.6110 | Val Loss: 6.4084
#       Stage 1 Epoch 180 | Loss: 8.6102 | Val Loss: 6.4073
#       Stage 1 Epoch 190 | Loss: 8.6167 | Val Loss: 6.4073
#       Stage 1 Epoch 200 | Loss: 8.6140 | Val Loss: 6.4060
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_CNN_OS_CSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0961 | Val Loss: 0.0425
#       Stage 2 Epoch 20 | Loss: 0.0999 | Val Loss: 0.0306
#       Stage 2 Epoch 30 | Loss: 0.0549 | Val Loss: 0.0477
#       Stage 2 Epoch 40 | Loss: 0.0639 | Val Loss: 0.0232
#       Stage 2 Epoch 50 | Loss: 0.0619 | Val Loss: 0.0316
#       Stage 2 Epoch 60 | Loss: 0.0541 | Val Loss: 0.0273
#       Stage 2 Epoch 70 | Loss: 0.0313 | Val Loss: 0.0356
#       Stage 2 Epoch 80 | Loss: 0.0267 | Val Loss: 0.0200
#       Stage 2 Epoch 90 | Loss: 0.0205 | Val Loss: 0.0227
#       Stage 2 Epoch 100 | Loss: 0.0177 | Val Loss: 0.0291
#       Stage 2 Epoch 110 | Loss: 0.0241 | Val Loss: 0.0344
#       Stage 2 Epoch 120 | Loss: 0.0214 | Val Loss: 0.0476
#       Stage 2 Epoch 130 | Loss: 0.0232 | Val Loss: 0.0144
#       Stage 2 Epoch 140 | Loss: 0.0242 | Val Loss: 0.0235
#       Stage 2 Epoch 150 | Loss: 0.0220 | Val Loss: 0.0348
#       Stage 2 Epoch 160 | Loss: 0.0214 | Val Loss: 0.0229
#       Stage 2 Epoch 170 | Loss: 0.0183 | Val Loss: 0.0273
#       Stage 2 Epoch 180 | Loss: 0.0223 | Val Loss: 0.0235
#       Stage 2 Epoch 190 | Loss: 0.0242 | Val Loss: 0.0362
#       Stage 2 Epoch 200 | Loss: 0.0184 | Val Loss: 0.0335
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_CNN_OS_CSL_42.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9960604070912672, 'prec': 0.6923076923076923, 'rec': 0.8181818181818182, 'f1': 0.7500000000000001}
# Results ready to be saved to results/eval_first_graph_GAT_CNN_OS_CSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GAT + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GAT_CNN_OS_CSL_101...
#       Stage 1 Epoch 10 | Loss: 8.6257 | Val Loss: 6.4128
#       Stage 1 Epoch 20 | Loss: 8.6247 | Val Loss: 6.4109
#       Stage 1 Epoch 30 | Loss: 8.6240 | Val Loss: 6.4109
#       Stage 1 Epoch 40 | Loss: 8.6154 | Val Loss: 6.4100
#       Stage 1 Epoch 50 | Loss: 8.6183 | Val Loss: 6.4097
#       Stage 1 Epoch 60 | Loss: 8.6159 | Val Loss: 6.4100
#       Stage 1 Epoch 70 | Loss: 8.6153 | Val Loss: 6.4094
#       Stage 1 Epoch 80 | Loss: 8.6163 | Val Loss: 6.4094
#       Stage 1 Epoch 90 | Loss: 8.6073 | Val Loss: 6.4098
#       Stage 1 Epoch 100 | Loss: 8.6123 | Val Loss: 6.4103
#       Stage 1 Epoch 110 | Loss: 8.6184 | Val Loss: 6.4100
#       Stage 1 Epoch 120 | Loss: 8.6176 | Val Loss: 6.4099
#       Stage 1 Epoch 130 | Loss: 8.6114 | Val Loss: 6.4098
#       Stage 1 Epoch 140 | Loss: 8.6178 | Val Loss: 6.4094
#       Stage 1 Epoch 150 | Loss: 8.6074 | Val Loss: 6.4103
#       Stage 1 Epoch 160 | Loss: 8.6102 | Val Loss: 6.4091
#       Stage 1 Epoch 170 | Loss: 8.6173 | Val Loss: 6.4108
#       Stage 1 Epoch 180 | Loss: 8.6047 | Val Loss: 6.4122
#       Stage 1 Epoch 190 | Loss: 8.5993 | Val Loss: 6.4124
#       Stage 1 Epoch 200 | Loss: 8.5612 | Val Loss: 6.4161
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_CNN_OS_CSL_101...
#       Stage 2 Epoch 10 | Loss: 0.1136 | Val Loss: 0.0399
#       Stage 2 Epoch 20 | Loss: 0.0949 | Val Loss: 0.0433
#       Stage 2 Epoch 30 | Loss: 0.0321 | Val Loss: 0.0278
#       Stage 2 Epoch 40 | Loss: 0.0265 | Val Loss: 0.0245
#       Stage 2 Epoch 50 | Loss: 0.0220 | Val Loss: 0.0390
#       Stage 2 Epoch 60 | Loss: 0.0164 | Val Loss: 0.0249
#       Stage 2 Epoch 70 | Loss: 0.0172 | Val Loss: 0.0253
#       Stage 2 Epoch 80 | Loss: 0.0234 | Val Loss: 0.0280
#       Stage 2 Epoch 90 | Loss: 0.0210 | Val Loss: 0.0301
#       Stage 2 Epoch 100 | Loss: 0.0208 | Val Loss: 0.0201
#       Stage 2 Epoch 110 | Loss: 0.0218 | Val Loss: 0.0409
#       Stage 2 Epoch 120 | Loss: 0.0186 | Val Loss: 0.0224
#       Stage 2 Epoch 130 | Loss: 0.0196 | Val Loss: 0.0322
#       Stage 2 Epoch 140 | Loss: 0.0221 | Val Loss: 0.0230
#       Stage 2 Epoch 150 | Loss: 0.0165 | Val Loss: 0.0345
#       Stage 2 Epoch 160 | Loss: 0.0203 | Val Loss: 0.0172
#       Stage 2 Epoch 170 | Loss: 0.0198 | Val Loss: 0.0185
#       Stage 2 Epoch 180 | Loss: 0.0148 | Val Loss: 0.0282
#       Stage 2 Epoch 190 | Loss: 0.0204 | Val Loss: 0.0311
#       Stage 2 Epoch 200 | Loss: 0.0212 | Val Loss: 0.0289
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_CNN_OS_CSL_101.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9960604070912672, 'prec': 0.7272727272727273, 'rec': 0.7272727272727273, 'f1': 0.7272727272727273}
# Results ready to be saved to results/eval_first_graph_GAT_CNN_OS_CSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GAT + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GAT_CNN_OS_CSL_1024...
#       Stage 1 Epoch 10 | Loss: 8.6289 | Val Loss: 6.4135
#       Stage 1 Epoch 20 | Loss: 8.6215 | Val Loss: 6.4107
#       Stage 1 Epoch 30 | Loss: 8.6207 | Val Loss: 6.4101
#       Stage 1 Epoch 40 | Loss: 8.6186 | Val Loss: 6.4095
#       Stage 1 Epoch 50 | Loss: 8.6211 | Val Loss: 6.4091
#       Stage 1 Epoch 60 | Loss: 8.6210 | Val Loss: 6.4089
#       Stage 1 Epoch 70 | Loss: 8.6143 | Val Loss: 6.4092
#       Stage 1 Epoch 80 | Loss: 8.6150 | Val Loss: 6.4093
#       Stage 1 Epoch 90 | Loss: 8.6152 | Val Loss: 6.4096
#       Stage 1 Epoch 100 | Loss: 8.6165 | Val Loss: 6.4084
#       Stage 1 Epoch 110 | Loss: 8.6164 | Val Loss: 6.4086
#       Stage 1 Epoch 120 | Loss: 8.6171 | Val Loss: 6.4066
#       Stage 1 Epoch 130 | Loss: 8.6093 | Val Loss: 6.4077
#       Stage 1 Epoch 140 | Loss: 8.6134 | Val Loss: 6.4077
#       Stage 1 Epoch 150 | Loss: 8.6131 | Val Loss: 6.4072
#       Stage 1 Epoch 160 | Loss: 8.6171 | Val Loss: 6.4076
#       Stage 1 Epoch 170 | Loss: 8.6113 | Val Loss: 6.4075
#       Stage 1 Epoch 180 | Loss: 8.6100 | Val Loss: 6.4077
#       Stage 1 Epoch 190 | Loss: 8.6133 | Val Loss: 6.4081
#       Stage 1 Epoch 200 | Loss: 8.6126 | Val Loss: 6.4078
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_CNN_OS_CSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.0616 | Val Loss: 0.0313
#       Stage 2 Epoch 20 | Loss: 0.0842 | Val Loss: 0.0319
#       Stage 2 Epoch 30 | Loss: 0.0666 | Val Loss: 0.0286
#       Stage 2 Epoch 40 | Loss: 0.0661 | Val Loss: 0.0382
#       Stage 2 Epoch 50 | Loss: 0.0636 | Val Loss: 0.0458
#       Stage 2 Epoch 60 | Loss: 0.0652 | Val Loss: 0.0335
#       Stage 2 Early stopping at epoch 64
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_CNN_OS_CSL_1024.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9927774130006566, 'prec': 0.0, 'rec': 0.0, 'f1': 0.0}
# Results ready to be saved to results/eval_first_graph_GAT_CNN_OS_CSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GAT + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GAT_CNN_OS_CSL_2025...
#       Stage 1 Epoch 10 | Loss: 8.6274 | Val Loss: 6.4117
#       Stage 1 Epoch 20 | Loss: 8.6245 | Val Loss: 6.4112
#       Stage 1 Epoch 30 | Loss: 8.6213 | Val Loss: 6.4110
#       Stage 1 Epoch 40 | Loss: 8.6186 | Val Loss: 6.4102
#       Stage 1 Epoch 50 | Loss: 8.6172 | Val Loss: 6.4096
#       Stage 1 Epoch 60 | Loss: 8.6184 | Val Loss: 6.4092
#       Stage 1 Epoch 70 | Loss: 8.6161 | Val Loss: 6.4089
#       Stage 1 Epoch 80 | Loss: 8.6125 | Val Loss: 6.4089
#       Stage 1 Epoch 90 | Loss: 8.6149 | Val Loss: 6.4087
#       Stage 1 Epoch 100 | Loss: 8.6104 | Val Loss: 6.4092
#       Stage 1 Epoch 110 | Loss: 8.6128 | Val Loss: 6.4086
#       Stage 1 Epoch 120 | Loss: 8.6151 | Val Loss: 6.4087
#       Stage 1 Epoch 130 | Loss: 8.6084 | Val Loss: 6.4085
#       Stage 1 Epoch 140 | Loss: 8.6162 | Val Loss: 6.4072
#       Stage 1 Epoch 150 | Loss: 8.6102 | Val Loss: 6.4083
#       Stage 1 Epoch 160 | Loss: 8.6109 | Val Loss: 6.4076
#       Stage 1 Epoch 170 | Loss: 8.6112 | Val Loss: 6.4075
#       Stage 1 Epoch 180 | Loss: 8.6127 | Val Loss: 6.4077
#       Stage 1 Epoch 190 | Loss: 8.6127 | Val Loss: 6.4076
#       Stage 1 Epoch 200 | Loss: 8.6149 | Val Loss: 6.4077
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_CNN_OS_CSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.1183 | Val Loss: 0.0543
#       Stage 2 Epoch 20 | Loss: 0.0757 | Val Loss: 0.0390
#       Stage 2 Epoch 30 | Loss: 0.0316 | Val Loss: 0.0498
#       Stage 2 Epoch 40 | Loss: 0.0269 | Val Loss: 0.0336
#       Stage 2 Epoch 50 | Loss: 0.0224 | Val Loss: 0.0341
#       Stage 2 Epoch 60 | Loss: 0.0236 | Val Loss: 0.0268
#       Stage 2 Epoch 70 | Loss: 0.0196 | Val Loss: 0.0320
#       Stage 2 Epoch 80 | Loss: 0.0258 | Val Loss: 0.0252
#       Stage 2 Epoch 90 | Loss: 0.0266 | Val Loss: 0.0351
#       Stage 2 Early stopping at epoch 98
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_CNN_OS_CSL_2025.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9960604070912672, 'prec': 0.7777777777777778, 'rec': 0.6363636363636364, 'f1': 0.7000000000000001}
# Results ready to be saved to results/eval_first_graph_GAT_CNN_OS_CSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/wacgan-ethereum-balanced/graph_data/wgangp_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GraphSAGE \
--classifier CNN \
--epochs_stage1 200 --epochs_stage2 200 --patience 50 --use_oversampling --output_file --use_csl --csl_weight 0.2
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/wacgan-ethereum-balanced/graph_data/wgangp_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 7713 nodes and 24896 edges
# Merge Info: 7613 overlapping nodes (anchors), 100 new synthetic nodes.
# Num nodes 7713 | Features: torch.Size([7713, 27]) | Fraud Train: 139 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5581 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7713, Edges: 24896, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 200, Patience: 50
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GraphSAGE + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GraphSAGE_CNN_OS_CSL_0...
#       Stage 1 Epoch 10 | Loss: 8.5771 | Val Loss: 6.4273
#       Stage 1 Epoch 20 | Loss: 8.5398 | Val Loss: 6.4183
#       Stage 1 Epoch 30 | Loss: 8.5329 | Val Loss: 6.4148
#       Stage 1 Epoch 40 | Loss: 8.5287 | Val Loss: 6.4100
#       Stage 1 Epoch 50 | Loss: 8.5227 | Val Loss: 6.4047
#       Stage 1 Epoch 60 | Loss: 8.5223 | Val Loss: 6.4012
#       Stage 1 Epoch 70 | Loss: 8.5176 | Val Loss: 6.4006
#       Stage 1 Epoch 80 | Loss: 8.5159 | Val Loss: 6.4002
#       Stage 1 Epoch 90 | Loss: 8.5159 | Val Loss: 6.4006
#       Stage 1 Epoch 100 | Loss: 8.5162 | Val Loss: 6.4004
#       Stage 1 Epoch 110 | Loss: 8.5153 | Val Loss: 6.4004
#       Stage 1 Epoch 120 | Loss: 8.5150 | Val Loss: 6.4011
#       Stage 1 Epoch 130 | Loss: 8.5133 | Val Loss: 6.4006
#       Stage 1 Epoch 140 | Loss: 8.5134 | Val Loss: 6.4009
#       Stage 1 Epoch 150 | Loss: 8.5150 | Val Loss: 6.4012
#       Stage 1 Epoch 160 | Loss: 8.5133 | Val Loss: 6.4007
#       Stage 1 Epoch 170 | Loss: 8.5123 | Val Loss: 6.4008
#       Stage 1 Epoch 180 | Loss: 8.5148 | Val Loss: 6.4009
#       Stage 1 Epoch 190 | Loss: 8.5129 | Val Loss: 6.4009
#       Stage 1 Epoch 200 | Loss: 8.5142 | Val Loss: 6.4008
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_CNN_OS_CSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0907 | Val Loss: 0.0382
#       Stage 2 Epoch 20 | Loss: 0.0123 | Val Loss: 0.0388
#       Stage 2 Epoch 30 | Loss: 0.0051 | Val Loss: 0.0233
#       Stage 2 Epoch 40 | Loss: 0.0043 | Val Loss: 0.0189
#       Stage 2 Epoch 50 | Loss: 0.0035 | Val Loss: 0.0172
#       Stage 2 Epoch 60 | Loss: 0.0038 | Val Loss: 0.0171
#       Stage 2 Epoch 70 | Loss: 0.0035 | Val Loss: 0.0180
#       Stage 2 Epoch 80 | Loss: 0.0024 | Val Loss: 0.0175
#       Stage 2 Epoch 90 | Loss: 0.0019 | Val Loss: 0.0130
#       Stage 2 Early stopping at epoch 98
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_CNN_OS_CSL_0.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9980302035456337, 'prec': 1.0, 'rec': 0.7272727272727273, 'f1': 0.8421052631578948}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_CNN_OS_CSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GraphSAGE + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GraphSAGE_CNN_OS_CSL_42...
#       Stage 1 Epoch 10 | Loss: 8.5621 | Val Loss: 6.4221
#       Stage 1 Epoch 20 | Loss: 8.5410 | Val Loss: 6.4153
#       Stage 1 Epoch 30 | Loss: 8.5316 | Val Loss: 6.4117
#       Stage 1 Epoch 40 | Loss: 8.5304 | Val Loss: 6.4080
#       Stage 1 Epoch 50 | Loss: 8.5260 | Val Loss: 6.4047
#       Stage 1 Epoch 60 | Loss: 8.5218 | Val Loss: 6.4013
#       Stage 1 Epoch 70 | Loss: 8.5204 | Val Loss: 6.4006
#       Stage 1 Epoch 80 | Loss: 8.5178 | Val Loss: 6.4005
#       Stage 1 Epoch 90 | Loss: 8.5185 | Val Loss: 6.4008
#       Stage 1 Epoch 100 | Loss: 8.5179 | Val Loss: 6.4002
#       Stage 1 Epoch 110 | Loss: 8.5153 | Val Loss: 6.4004
#       Stage 1 Epoch 120 | Loss: 8.5172 | Val Loss: 6.4005
#       Stage 1 Epoch 130 | Loss: 8.5168 | Val Loss: 6.4001
#       Stage 1 Epoch 140 | Loss: 8.5172 | Val Loss: 6.4003
#       Stage 1 Epoch 150 | Loss: 8.5200 | Val Loss: 6.4003
#       Stage 1 Epoch 160 | Loss: 8.5141 | Val Loss: 6.4006
#       Stage 1 Epoch 170 | Loss: 8.5133 | Val Loss: 6.4007
#       Stage 1 Epoch 180 | Loss: 8.5164 | Val Loss: 6.4008
#       Stage 1 Epoch 190 | Loss: 8.5143 | Val Loss: 6.4011
#       Stage 1 Epoch 200 | Loss: 8.5140 | Val Loss: 6.4027
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_CNN_OS_CSL_42...
#       Stage 2 Epoch 10 | Loss: 0.1933 | Val Loss: 0.1160
#       Stage 2 Epoch 20 | Loss: 0.0939 | Val Loss: 0.0494
#       Stage 2 Epoch 30 | Loss: 0.0492 | Val Loss: 0.0266
#       Stage 2 Epoch 40 | Loss: 0.0354 | Val Loss: 0.0244
#       Stage 2 Epoch 50 | Loss: 0.0256 | Val Loss: 0.0246
#       Stage 2 Epoch 60 | Loss: 0.0222 | Val Loss: 0.0207
#       Stage 2 Epoch 70 | Loss: 0.0147 | Val Loss: 0.0121
#       Stage 2 Epoch 80 | Loss: 0.0035 | Val Loss: 0.0197
#       Stage 2 Epoch 90 | Loss: 0.0025 | Val Loss: 0.0203
#       Stage 2 Epoch 100 | Loss: 0.0028 | Val Loss: 0.0170
#       Stage 2 Epoch 110 | Loss: 0.0030 | Val Loss: 0.0193
#       Stage 2 Epoch 120 | Loss: 0.0021 | Val Loss: 0.0122
#       Stage 2 Epoch 130 | Loss: 0.0024 | Val Loss: 0.0168
#       Stage 2 Early stopping at epoch 136
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_CNN_OS_CSL_42.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9980302035456337, 'prec': 1.0, 'rec': 0.7272727272727273, 'f1': 0.8421052631578948}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_CNN_OS_CSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GraphSAGE + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GraphSAGE_CNN_OS_CSL_101...
#       Stage 1 Epoch 10 | Loss: 8.5744 | Val Loss: 6.4200
#       Stage 1 Epoch 20 | Loss: 8.5367 | Val Loss: 6.4160
#       Stage 1 Epoch 30 | Loss: 8.5305 | Val Loss: 6.4104
#       Stage 1 Epoch 40 | Loss: 8.5308 | Val Loss: 6.4054
#       Stage 1 Epoch 50 | Loss: 8.5219 | Val Loss: 6.4017
#       Stage 1 Epoch 60 | Loss: 8.5190 | Val Loss: 6.4006
#       Stage 1 Epoch 70 | Loss: 8.5160 | Val Loss: 6.4008
#       Stage 1 Epoch 80 | Loss: 8.5170 | Val Loss: 6.4010
#       Stage 1 Epoch 90 | Loss: 8.5165 | Val Loss: 6.4013
#       Stage 1 Epoch 100 | Loss: 8.5218 | Val Loss: 6.4017
#       Stage 1 Epoch 110 | Loss: 8.5169 | Val Loss: 6.4015
#       Stage 1 Epoch 120 | Loss: 8.5153 | Val Loss: 6.4011
#       Stage 1 Epoch 130 | Loss: 8.5134 | Val Loss: 6.4011
#       Stage 1 Epoch 140 | Loss: 8.5142 | Val Loss: 6.4021
#       Stage 1 Epoch 150 | Loss: 8.5143 | Val Loss: 6.4015
#       Stage 1 Epoch 160 | Loss: 8.5132 | Val Loss: 6.4022
#       Stage 1 Epoch 170 | Loss: 8.5130 | Val Loss: 6.4019
#       Stage 1 Epoch 180 | Loss: 8.5143 | Val Loss: 6.4034
#       Stage 1 Epoch 190 | Loss: 8.5147 | Val Loss: 6.4027
#       Stage 1 Epoch 200 | Loss: 8.5143 | Val Loss: 6.4036
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_CNN_OS_CSL_101...
#       Stage 2 Epoch 10 | Loss: 0.1135 | Val Loss: 0.0415
#       Stage 2 Epoch 20 | Loss: 0.1425 | Val Loss: 0.0412
#       Stage 2 Epoch 30 | Loss: 0.1100 | Val Loss: 0.0532
#       Stage 2 Epoch 40 | Loss: 0.0997 | Val Loss: 0.0421
#       Stage 2 Epoch 50 | Loss: 0.0496 | Val Loss: 0.0291
#       Stage 2 Epoch 60 | Loss: 0.0248 | Val Loss: 0.0137
#       Stage 2 Epoch 70 | Loss: 0.0182 | Val Loss: 0.0184
#       Stage 2 Epoch 80 | Loss: 0.0039 | Val Loss: 0.0164
#       Stage 2 Epoch 90 | Loss: 0.0020 | Val Loss: 0.0154
#       Stage 2 Epoch 100 | Loss: 0.0036 | Val Loss: 0.0140
#       Stage 2 Epoch 110 | Loss: 0.0024 | Val Loss: 0.0250
#       Stage 2 Epoch 120 | Loss: 0.0020 | Val Loss: 0.0165
#       Stage 2 Epoch 130 | Loss: 0.0023 | Val Loss: 0.0113
#       Stage 2 Epoch 140 | Loss: 0.0043 | Val Loss: 0.0134
#       Stage 2 Epoch 150 | Loss: 0.0036 | Val Loss: 0.0165
#       Stage 2 Early stopping at epoch 153
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_CNN_OS_CSL_101.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9980302035456337, 'prec': 1.0, 'rec': 0.7272727272727273, 'f1': 0.8421052631578948}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_CNN_OS_CSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GraphSAGE + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GraphSAGE_CNN_OS_CSL_1024...
#       Stage 1 Epoch 10 | Loss: 8.5897 | Val Loss: 6.4235
#       Stage 1 Epoch 20 | Loss: 8.5476 | Val Loss: 6.4261
#       Stage 1 Epoch 30 | Loss: 8.5370 | Val Loss: 6.4225
#       Stage 1 Epoch 40 | Loss: 8.5318 | Val Loss: 6.4140
#       Stage 1 Epoch 50 | Loss: 8.5275 | Val Loss: 6.4078
#       Stage 1 Epoch 60 | Loss: 8.5271 | Val Loss: 6.4012
#       Stage 1 Epoch 70 | Loss: 8.5203 | Val Loss: 6.4014
#       Stage 1 Epoch 80 | Loss: 8.5154 | Val Loss: 6.4013
#       Stage 1 Epoch 90 | Loss: 8.5164 | Val Loss: 6.4024
#       Stage 1 Epoch 100 | Loss: 8.5146 | Val Loss: 6.4027
#       Stage 1 Epoch 110 | Loss: 8.5137 | Val Loss: 6.4017
#       Stage 1 Epoch 120 | Loss: 8.5138 | Val Loss: 6.4016
#       Stage 1 Epoch 130 | Loss: 8.5135 | Val Loss: 6.4020
#       Stage 1 Epoch 140 | Loss: 8.5138 | Val Loss: 6.4023
#       Stage 1 Epoch 150 | Loss: 8.5149 | Val Loss: 6.4025
#       Stage 1 Epoch 160 | Loss: 8.5141 | Val Loss: 6.4026
#       Stage 1 Epoch 170 | Loss: 8.5137 | Val Loss: 6.4015
#       Stage 1 Epoch 180 | Loss: 8.5147 | Val Loss: 6.4014
#       Stage 1 Epoch 190 | Loss: 8.5139 | Val Loss: 6.4023
#       Stage 1 Epoch 200 | Loss: 8.5125 | Val Loss: 6.4029
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_CNN_OS_CSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.1001 | Val Loss: 0.0489
#       Stage 2 Epoch 20 | Loss: 0.1292 | Val Loss: 0.0667
#       Stage 2 Epoch 30 | Loss: 0.0820 | Val Loss: 0.0508
#       Stage 2 Epoch 40 | Loss: 0.0671 | Val Loss: 0.0480
#       Stage 2 Epoch 50 | Loss: 0.0538 | Val Loss: 0.0520
#       Stage 2 Epoch 60 | Loss: 0.0292 | Val Loss: 0.0311
#       Stage 2 Epoch 70 | Loss: 0.0150 | Val Loss: 0.0417
#       Stage 2 Epoch 80 | Loss: 0.0117 | Val Loss: 0.0352
#       Stage 2 Epoch 90 | Loss: 0.0077 | Val Loss: 0.0305
#       Stage 2 Epoch 100 | Loss: 0.0041 | Val Loss: 0.0340
#       Stage 2 Epoch 110 | Loss: 0.0053 | Val Loss: 0.0344
#       Stage 2 Epoch 120 | Loss: 0.0058 | Val Loss: 0.0183
#       Stage 2 Epoch 130 | Loss: 0.0029 | Val Loss: 0.0208
#       Stage 2 Epoch 140 | Loss: 0.0026 | Val Loss: 0.0200
#       Stage 2 Epoch 150 | Loss: 0.0026 | Val Loss: 0.0241
#       Stage 2 Epoch 160 | Loss: 0.0020 | Val Loss: 0.0212
#       Stage 2 Epoch 170 | Loss: 0.0020 | Val Loss: 0.0241
#       Stage 2 Epoch 180 | Loss: 0.0019 | Val Loss: 0.0156
#       Stage 2 Epoch 190 | Loss: 0.0022 | Val Loss: 0.0225
#       Stage 2 Epoch 200 | Loss: 0.0018 | Val Loss: 0.0229
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_CNN_OS_CSL_1024.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9986868023637557, 'prec': 1.0, 'rec': 0.8181818181818182, 'f1': 0.9}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_CNN_OS_CSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GraphSAGE + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GraphSAGE_CNN_OS_CSL_2025...
#       Stage 1 Epoch 10 | Loss: 8.5788 | Val Loss: 6.4254
#       Stage 1 Epoch 20 | Loss: 8.5415 | Val Loss: 6.4178
#       Stage 1 Epoch 30 | Loss: 8.5363 | Val Loss: 6.4149
#       Stage 1 Epoch 40 | Loss: 8.5301 | Val Loss: 6.4126
#       Stage 1 Epoch 50 | Loss: 8.5288 | Val Loss: 6.4104
#       Stage 1 Epoch 60 | Loss: 8.5276 | Val Loss: 6.4041
#       Stage 1 Epoch 70 | Loss: 8.5214 | Val Loss: 6.4007
#       Stage 1 Epoch 80 | Loss: 8.5213 | Val Loss: 6.4006
#       Stage 1 Epoch 90 | Loss: 8.5158 | Val Loss: 6.4006
#       Stage 1 Epoch 100 | Loss: 8.5154 | Val Loss: 6.4005
#       Stage 1 Epoch 110 | Loss: 8.5164 | Val Loss: 6.4007
#       Stage 1 Epoch 120 | Loss: 8.5158 | Val Loss: 6.4003
#       Stage 1 Epoch 130 | Loss: 8.5166 | Val Loss: 6.4005
#       Stage 1 Epoch 140 | Loss: 8.5145 | Val Loss: 6.4007
#       Stage 1 Epoch 150 | Loss: 8.5152 | Val Loss: 6.4010
#       Stage 1 Epoch 160 | Loss: 8.5150 | Val Loss: 6.4011
#       Stage 1 Epoch 170 | Loss: 8.5156 | Val Loss: 6.4011
#       Stage 1 Epoch 180 | Loss: 8.5139 | Val Loss: 6.4007
#       Stage 1 Epoch 190 | Loss: 8.5144 | Val Loss: 6.4008
#       Stage 1 Epoch 200 | Loss: 8.5151 | Val Loss: 6.4014
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_CNN_OS_CSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.1233 | Val Loss: 0.0633
#       Stage 2 Epoch 20 | Loss: 0.0351 | Val Loss: 0.0380
#       Stage 2 Epoch 30 | Loss: 0.0095 | Val Loss: 0.0155
#       Stage 2 Epoch 40 | Loss: 0.0041 | Val Loss: 0.0272
#       Stage 2 Epoch 50 | Loss: 0.0062 | Val Loss: 0.0248
#       Stage 2 Epoch 60 | Loss: 0.0020 | Val Loss: 0.0208
#       Stage 2 Epoch 70 | Loss: 0.0027 | Val Loss: 0.0373
#       Stage 2 Epoch 80 | Loss: 0.0035 | Val Loss: 0.0224
#       Stage 2 Epoch 90 | Loss: 0.0025 | Val Loss: 0.0128
#       Stage 2 Epoch 100 | Loss: 0.0034 | Val Loss: 0.0165
#       Stage 2 Epoch 110 | Loss: 0.0030 | Val Loss: 0.0133
#       Stage 2 Epoch 120 | Loss: 0.0026 | Val Loss: 0.0159
#       Stage 2 Epoch 130 | Loss: 0.0029 | Val Loss: 0.0139
#       Stage 2 Early stopping at epoch 135
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_CNN_OS_CSL_2025.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9993434011818779, 'prec': 1.0, 'rec': 0.9090909090909091, 'f1': 0.9523809523809523}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_CNN_OS_CSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/wacgan-ethereum-balanced/graph_data/wgangp_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GIN \
--classifier CNN \
--epochs_stage1 200 --epochs_stage2 200 --patience 50 --use_oversampling --output_file --use_csl --csl_weight 0.2
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/wacgan-ethereum-balanced/graph_data/wgangp_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 7713 nodes and 24896 edges
# Merge Info: 7613 overlapping nodes (anchors), 100 new synthetic nodes.
# Num nodes 7713 | Features: torch.Size([7713, 27]) | Fraud Train: 139 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5581 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7713, Edges: 24896, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 200, Patience: 50
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GIN + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GIN_CNN_OS_CSL_0...
#       Stage 1 Epoch 10 | Loss: 8.5882 | Val Loss: 6.4298
#       Stage 1 Epoch 20 | Loss: 8.5577 | Val Loss: 6.4135
#       Stage 1 Epoch 30 | Loss: 8.5457 | Val Loss: 6.4104
#       Stage 1 Epoch 40 | Loss: 8.5512 | Val Loss: 6.4097
#       Stage 1 Epoch 50 | Loss: 8.5398 | Val Loss: 6.4105
#       Stage 1 Epoch 60 | Loss: 8.5520 | Val Loss: 6.4119
#       Stage 1 Epoch 70 | Loss: 8.5464 | Val Loss: 6.4120
#       Stage 1 Epoch 80 | Loss: 8.5375 | Val Loss: 6.4123
#       Stage 1 Epoch 90 | Loss: 8.5388 | Val Loss: 6.4122
#       Stage 1 Epoch 100 | Loss: 8.5389 | Val Loss: 6.4129
#       Stage 1 Epoch 110 | Loss: 8.5361 | Val Loss: 6.4125
#       Stage 1 Epoch 120 | Loss: 8.5360 | Val Loss: 6.4128
#       Stage 1 Epoch 130 | Loss: 8.5354 | Val Loss: 6.4125
#       Stage 1 Epoch 140 | Loss: 8.5366 | Val Loss: 6.4134
#       Stage 1 Epoch 150 | Loss: 8.5360 | Val Loss: 6.4133
#       Stage 1 Epoch 160 | Loss: 8.5352 | Val Loss: 6.4140
#       Stage 1 Epoch 170 | Loss: 8.5336 | Val Loss: 6.4143
#       Stage 1 Epoch 180 | Loss: 8.5313 | Val Loss: 6.4148
#       Stage 1 Epoch 190 | Loss: 8.5337 | Val Loss: 6.4140
#       Stage 1 Epoch 200 | Loss: 8.5337 | Val Loss: 6.4155
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_CNN_OS_CSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0511 | Val Loss: 0.0436
#       Stage 2 Epoch 20 | Loss: 0.0413 | Val Loss: 0.0508
#       Stage 2 Epoch 30 | Loss: 0.0296 | Val Loss: 0.0369
#       Stage 2 Epoch 40 | Loss: 0.0202 | Val Loss: 0.0314
#       Stage 2 Epoch 50 | Loss: 0.0157 | Val Loss: 0.0275
#       Stage 2 Epoch 60 | Loss: 0.0137 | Val Loss: 0.0225
#       Stage 2 Epoch 70 | Loss: 0.0094 | Val Loss: 0.0247
#       Stage 2 Epoch 80 | Loss: 0.0088 | Val Loss: 0.0310
#       Stage 2 Epoch 90 | Loss: 0.0107 | Val Loss: 0.0274
#       Stage 2 Epoch 100 | Loss: 0.0113 | Val Loss: 0.0243
#       Stage 2 Epoch 110 | Loss: 0.0111 | Val Loss: 0.0246
#       Stage 2 Epoch 120 | Loss: 0.0123 | Val Loss: 0.0265
#       Stage 2 Epoch 130 | Loss: 0.0105 | Val Loss: 0.0246
#       Stage 2 Epoch 140 | Loss: 0.0104 | Val Loss: 0.0265
#       Stage 2 Epoch 150 | Loss: 0.0100 | Val Loss: 0.0214
#       Stage 2 Early stopping at epoch 159
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_CNN_OS_CSL_0.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9973736047275115, 'prec': 1.0, 'rec': 0.6363636363636364, 'f1': 0.7777777777777778}
# Results ready to be saved to results/eval_first_graph_GIN_CNN_OS_CSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GIN + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GIN_CNN_OS_CSL_42...
#       Stage 1 Epoch 10 | Loss: 8.5718 | Val Loss: 6.4303
#       Stage 1 Epoch 20 | Loss: 8.5631 | Val Loss: 6.4132
#       Stage 1 Epoch 30 | Loss: 8.5464 | Val Loss: 6.4099
#       Stage 1 Epoch 40 | Loss: 8.5408 | Val Loss: 6.4132
#       Stage 1 Epoch 50 | Loss: 8.5402 | Val Loss: 6.4123
#       Stage 1 Epoch 60 | Loss: 8.5383 | Val Loss: 6.4129
#       Stage 1 Epoch 70 | Loss: 8.5378 | Val Loss: 6.4133
#       Stage 1 Epoch 80 | Loss: 8.5378 | Val Loss: 6.4134
#       Stage 1 Epoch 90 | Loss: 8.5377 | Val Loss: 6.4125
#       Stage 1 Epoch 100 | Loss: 8.5357 | Val Loss: 6.4129
#       Stage 1 Epoch 110 | Loss: 8.5344 | Val Loss: 6.4128
#       Stage 1 Epoch 120 | Loss: 8.5351 | Val Loss: 6.4127
#       Stage 1 Epoch 130 | Loss: 8.5360 | Val Loss: 6.4137
#       Stage 1 Epoch 140 | Loss: 8.5349 | Val Loss: 6.4127
#       Stage 1 Epoch 150 | Loss: 8.5331 | Val Loss: 6.4134
#       Stage 1 Epoch 160 | Loss: 8.5342 | Val Loss: 6.4139
#       Stage 1 Epoch 170 | Loss: 8.5379 | Val Loss: 6.4141
#       Stage 1 Epoch 180 | Loss: 8.5392 | Val Loss: 6.4149
#       Stage 1 Epoch 190 | Loss: 8.5346 | Val Loss: 6.4140
#       Stage 1 Epoch 200 | Loss: 8.5327 | Val Loss: 6.4163
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_CNN_OS_CSL_42...
#       Stage 2 Epoch 10 | Loss: 0.3155 | Val Loss: 0.2779
#       Stage 2 Epoch 20 | Loss: 0.0413 | Val Loss: 0.0419
#       Stage 2 Epoch 30 | Loss: 0.0286 | Val Loss: 0.0350
#       Stage 2 Epoch 40 | Loss: 0.0245 | Val Loss: 0.0347
#       Stage 2 Epoch 50 | Loss: 0.0202 | Val Loss: 0.0254
#       Stage 2 Epoch 60 | Loss: 0.0118 | Val Loss: 0.0203
#       Stage 2 Epoch 70 | Loss: 0.0112 | Val Loss: 0.0290
#       Stage 2 Epoch 80 | Loss: 0.0079 | Val Loss: 0.0301
#       Stage 2 Epoch 90 | Loss: 0.0204 | Val Loss: 0.0256
#       Stage 2 Epoch 100 | Loss: 0.0093 | Val Loss: 0.0208
#       Stage 2 Epoch 110 | Loss: 0.0149 | Val Loss: 0.0302
#       Stage 2 Epoch 120 | Loss: 0.0081 | Val Loss: 0.0236
#       Stage 2 Epoch 130 | Loss: 0.0106 | Val Loss: 0.0337
#       Stage 2 Epoch 140 | Loss: 0.0079 | Val Loss: 0.0253
#       Stage 2 Early stopping at epoch 146
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_CNN_OS_CSL_42.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9967170059093894, 'prec': 0.8, 'rec': 0.7272727272727273, 'f1': 0.761904761904762}
# Results ready to be saved to results/eval_first_graph_GIN_CNN_OS_CSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GIN + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GIN_CNN_OS_CSL_101...
#       Stage 1 Epoch 10 | Loss: 8.5648 | Val Loss: 6.4129
#       Stage 1 Epoch 20 | Loss: 8.5648 | Val Loss: 6.4108
#       Stage 1 Epoch 30 | Loss: 8.5429 | Val Loss: 6.4116
#       Stage 1 Epoch 40 | Loss: 8.5412 | Val Loss: 6.4114
#       Stage 1 Epoch 50 | Loss: 8.5382 | Val Loss: 6.4126
#       Stage 1 Epoch 60 | Loss: 8.5442 | Val Loss: 6.4125
#       Stage 1 Epoch 70 | Loss: 8.5378 | Val Loss: 6.4127
#       Stage 1 Epoch 80 | Loss: 8.5367 | Val Loss: 6.4137
#       Stage 1 Epoch 90 | Loss: 8.5357 | Val Loss: 6.4124
#       Stage 1 Epoch 100 | Loss: 8.5347 | Val Loss: 6.4146
#       Stage 1 Epoch 110 | Loss: 8.5355 | Val Loss: 6.4136
#       Stage 1 Epoch 120 | Loss: 8.5323 | Val Loss: 6.4146
#       Stage 1 Epoch 130 | Loss: 8.5356 | Val Loss: 6.4134
#       Stage 1 Epoch 140 | Loss: 8.5359 | Val Loss: 6.4169
#       Stage 1 Epoch 150 | Loss: 8.5323 | Val Loss: 6.4144
#       Stage 1 Epoch 160 | Loss: 8.5318 | Val Loss: 6.4150
#       Stage 1 Epoch 170 | Loss: 8.5306 | Val Loss: 6.4163
#       Stage 1 Epoch 180 | Loss: 8.5306 | Val Loss: 6.4162
#       Stage 1 Epoch 190 | Loss: 8.5425 | Val Loss: 6.4147
#       Stage 1 Epoch 200 | Loss: 8.5358 | Val Loss: 6.4166
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_CNN_OS_CSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0773 | Val Loss: 0.0589
#       Stage 2 Epoch 20 | Loss: 0.0378 | Val Loss: 0.0501
#       Stage 2 Epoch 30 | Loss: 0.0338 | Val Loss: 0.0435
#       Stage 2 Epoch 40 | Loss: 0.0196 | Val Loss: 0.0361
#       Stage 2 Epoch 50 | Loss: 0.0142 | Val Loss: 0.0233
#       Stage 2 Epoch 60 | Loss: 0.0121 | Val Loss: 0.0240
#       Stage 2 Epoch 70 | Loss: 0.0142 | Val Loss: 0.0278
#       Stage 2 Epoch 80 | Loss: 0.0185 | Val Loss: 0.0276
#       Stage 2 Early stopping at epoch 83
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_CNN_OS_CSL_101.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9921208141825345, 'prec': 0.4, 'rec': 0.18181818181818182, 'f1': 0.25000000000000006}
# Results ready to be saved to results/eval_first_graph_GIN_CNN_OS_CSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GIN + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GIN_CNN_OS_CSL_1024...
#       Stage 1 Epoch 10 | Loss: 8.5706 | Val Loss: 6.4125
#       Stage 1 Epoch 20 | Loss: 8.5496 | Val Loss: 6.4101
#       Stage 1 Epoch 30 | Loss: 8.5448 | Val Loss: 6.4104
#       Stage 1 Epoch 40 | Loss: 8.5512 | Val Loss: 6.4115
#       Stage 1 Epoch 50 | Loss: 8.5384 | Val Loss: 6.4122
#       Stage 1 Epoch 60 | Loss: 8.5402 | Val Loss: 6.4121
#       Stage 1 Epoch 70 | Loss: 8.5360 | Val Loss: 6.4127
#       Stage 1 Epoch 80 | Loss: 8.5361 | Val Loss: 6.4131
#       Stage 1 Epoch 90 | Loss: 8.5349 | Val Loss: 6.4137
#       Stage 1 Epoch 100 | Loss: 8.5346 | Val Loss: 6.4131
#       Stage 1 Epoch 110 | Loss: 8.5344 | Val Loss: 6.4150
#       Stage 1 Epoch 120 | Loss: 8.5334 | Val Loss: 6.4146
#       Stage 1 Epoch 130 | Loss: 8.5338 | Val Loss: 6.4147
#       Stage 1 Epoch 140 | Loss: 8.5334 | Val Loss: 6.4135
#       Stage 1 Epoch 150 | Loss: 8.5333 | Val Loss: 6.4171
#       Stage 1 Epoch 160 | Loss: 8.5325 | Val Loss: 6.4158
#       Stage 1 Epoch 170 | Loss: 8.5325 | Val Loss: 6.4149
#       Stage 1 Epoch 180 | Loss: 8.5333 | Val Loss: 6.4153
#       Stage 1 Epoch 190 | Loss: 8.5317 | Val Loss: 6.4147
#       Stage 1 Epoch 200 | Loss: 8.5329 | Val Loss: 6.4149
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_CNN_OS_CSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.0550 | Val Loss: 0.0446
#       Stage 2 Epoch 20 | Loss: 0.0350 | Val Loss: 0.0414
#       Stage 2 Epoch 30 | Loss: 0.0384 | Val Loss: 0.0410
#       Stage 2 Epoch 40 | Loss: 0.0288 | Val Loss: 0.0379
#       Stage 2 Epoch 50 | Loss: 0.0221 | Val Loss: 0.0325
#       Stage 2 Epoch 60 | Loss: 0.0155 | Val Loss: 0.0259
#       Stage 2 Epoch 70 | Loss: 0.0132 | Val Loss: 0.0224
#       Stage 2 Epoch 80 | Loss: 0.0121 | Val Loss: 0.0213
#       Stage 2 Epoch 90 | Loss: 0.0124 | Val Loss: 0.0279
#       Stage 2 Epoch 100 | Loss: 0.0097 | Val Loss: 0.0233
#       Stage 2 Epoch 110 | Loss: 0.0091 | Val Loss: 0.0208
#       Stage 2 Epoch 120 | Loss: 0.0159 | Val Loss: 0.0205
#       Stage 2 Epoch 130 | Loss: 0.0131 | Val Loss: 0.0268
#       Stage 2 Early stopping at epoch 133
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_CNN_OS_CSL_1024.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9960604070912672, 'prec': 0.8571428571428571, 'rec': 0.5454545454545454, 'f1': 0.6666666666666665}
# Results ready to be saved to results/eval_first_graph_GIN_CNN_OS_CSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GIN + CNN...
#    [STAGE 1] CSL Pre-training for first_graph_GIN_CNN_OS_CSL_2025...
#       Stage 1 Epoch 10 | Loss: 8.5610 | Val Loss: 6.4122
#       Stage 1 Epoch 20 | Loss: 8.5452 | Val Loss: 6.4100
#       Stage 1 Epoch 30 | Loss: 8.5498 | Val Loss: 6.4099
#       Stage 1 Epoch 40 | Loss: 8.5391 | Val Loss: 6.4101
#       Stage 1 Epoch 50 | Loss: 8.5435 | Val Loss: 6.4110
#       Stage 1 Epoch 60 | Loss: 8.5371 | Val Loss: 6.4103
#       Stage 1 Epoch 70 | Loss: 8.5356 | Val Loss: 6.4105
#       Stage 1 Epoch 80 | Loss: 8.5361 | Val Loss: 6.4113
#       Stage 1 Epoch 90 | Loss: 8.5388 | Val Loss: 6.4122
#       Stage 1 Epoch 100 | Loss: 8.5445 | Val Loss: 6.4127
#       Stage 1 Epoch 110 | Loss: 8.5360 | Val Loss: 6.4132
#       Stage 1 Epoch 120 | Loss: 8.5379 | Val Loss: 6.4139
#       Stage 1 Epoch 130 | Loss: 8.5341 | Val Loss: 6.4128
#       Stage 1 Epoch 140 | Loss: 8.5398 | Val Loss: 6.4135
#       Stage 1 Epoch 150 | Loss: 8.5348 | Val Loss: 6.4138
#       Stage 1 Epoch 160 | Loss: 8.5337 | Val Loss: 6.4146
#       Stage 1 Epoch 170 | Loss: 8.5338 | Val Loss: 6.4138
#       Stage 1 Epoch 180 | Loss: 8.5317 | Val Loss: 6.4148
#       Stage 1 Epoch 190 | Loss: 8.5337 | Val Loss: 6.4152
#       Stage 1 Epoch 200 | Loss: 8.5318 | Val Loss: 6.4154
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_CNN_OS_CSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.1482 | Val Loss: 0.1115
#       Stage 2 Epoch 20 | Loss: 0.0447 | Val Loss: 0.0453
#       Stage 2 Epoch 30 | Loss: 0.0279 | Val Loss: 0.0363
#       Stage 2 Epoch 40 | Loss: 0.0135 | Val Loss: 0.0262
#       Stage 2 Epoch 50 | Loss: 0.0100 | Val Loss: 0.0229
#       Stage 2 Epoch 60 | Loss: 0.0088 | Val Loss: 0.0217
#       Stage 2 Epoch 70 | Loss: 0.0086 | Val Loss: 0.0214
#       Stage 2 Epoch 80 | Loss: 0.0152 | Val Loss: 0.0267
#       Stage 2 Epoch 90 | Loss: 0.0094 | Val Loss: 0.0258
#       Stage 2 Epoch 100 | Loss: 0.0127 | Val Loss: 0.0258
#       Stage 2 Epoch 110 | Loss: 0.0103 | Val Loss: 0.0259
#       Stage 2 Epoch 120 | Loss: 0.0088 | Val Loss: 0.0277
#       Stage 2 Epoch 130 | Loss: 0.0072 | Val Loss: 0.0274
#       Stage 2 Early stopping at epoch 133
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_CNN_OS_CSL_2025.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: CNN, Oversample: True, CSL: True
# {'acc': 0.9940906106369009, 'prec': 1.0, 'rec': 0.18181818181818182, 'f1': 0.3076923076923077}
# Results ready to be saved to results/eval_first_graph_GIN_CNN_OS_CSL_2025.json

# %%
# !cd /kaggle/working/results
# !zip -r G1-CNN-WGANGP-CSL.zip /kaggle/working/results/
# Out:
#   adding: kaggle/working/results/ (stored 0%)
#   adding: kaggle/working/results/pred_first_graph_GIN_CNN_OS_CSL_1024.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_CNN_OS_CSL_42.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_CNN_OS_CSL_101.json (deflated 36%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_CNN_OS_CSL_101.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GIN_CNN_OS_CSL_101.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GCN_CNN_OS_CSL_2025.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GCN_CNN_OS_CSL_42.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GAT_CNN_OS_CSL_2025.json (deflated 45%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_CNN_OS_CSL_1024.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GIN_CNN_OS_CSL_42.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GAT_CNN_OS_CSL_101.json (deflated 47%)
#   adding: kaggle/working/results/pred_first_graph_GAT_CNN_OS_CSL_101.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GIN_CNN_OS_CSL_0.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_CNN_OS_CSL_42.json (deflated 36%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_CNN_OS_CSL_0.json (deflated 36%)
#   adding: kaggle/working/results/pred_first_graph_GAT_CNN_OS_CSL_42.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GAT_CNN_OS_CSL_2025.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GCN_CNN_OS_CSL_42.json (deflated 42%)
#   adding: kaggle/working/results/eval_first_graph_GCN_CNN_OS_CSL_2025.json (deflated 39%)
#   adding: kaggle/working/results/eval_first_graph_GIN_CNN_OS_CSL_0.json (deflated 41%)
#   adding: kaggle/working/results/eval_first_graph_GAT_CNN_OS_CSL_1024.json (deflated 37%)
#   adding: kaggle/working/results/pred_first_graph_GAT_CNN_OS_CSL_1024.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_CNN_OS_CSL_2025.json (deflated 39%)
#   adding: kaggle/working/results/eval_first_graph_GCN_CNN_OS_CSL_0.json (deflated 46%)
#   adding: kaggle/working/results/pred_first_graph_GCN_CNN_OS_CSL_0.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GAT_CNN_OS_CSL_0.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GIN_CNN_OS_CSL_1024.json (deflated 43%)
#   adding: kaggle/working/results/eval_first_graph_GIN_CNN_OS_CSL_2025.json (deflated 39%)
#   adding: kaggle/working/results/pred_first_graph_GCN_CNN_OS_CSL_101.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GCN_CNN_OS_CSL_1024.json (deflated 47%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_CNN_OS_CSL_2025.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GCN_CNN_OS_CSL_101.json (deflated 46%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_CNN_OS_CSL_1024.json (deflated 37%)
#   adding: kaggle/working/results/pred_first_graph_GIN_CNN_OS_CSL_2025.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GAT_CNN_OS_CSL_42.json (deflated 42%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_CNN_OS_CSL_0.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GIN_CNN_OS_CSL_101.json (deflated 42%)
#   adding: kaggle/working/results/eval_first_graph_GIN_CNN_OS_CSL_42.json (deflated 40%)
#   adding: kaggle/working/results/pred_first_graph_GCN_CNN_OS_CSL_1024.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GAT_CNN_OS_CSL_0.json (deflated 42%)
