# %%
# !pip install torch_geometric
# !pip install git+https://github.com/Blealtan/efficient-kan.git
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.13.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2025.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (7.1.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2025.10.5)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal>=1.4.0->aiohttp->torch_geometric) (4.15.0)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torch_geometric) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torch_geometric) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torch_geometric) (2024.2.0)
# Downloading torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 30.7 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.7.0
# Collecting git+https://github.com/Blealtan/efficient-kan.git
#   Cloning https://github.com/Blealtan/efficient-kan.git to /tmp/pip-req-build-ev_q5mmg
#   Running command git clone --filter=blob:none --quiet https://github.com/Blealtan/efficient-kan.git /tmp/pip-req-build-ev_q5mmg
#   Resolved https://github.com/Blealtan/efficient-kan.git to commit 7b6ce1c87f18c8bc90c208f6b494042344216b11
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (2.6.0+cu124)
# Requirement already satisfied: pytest>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (8.4.1)
# Requirement already satisfied: tqdm>=4.66.2 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (4.67.1)
# Requirement already satisfied: torchvision>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (0.21.0+cu124)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (2.1.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (25.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (2.19.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (2025.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.3.0->efficient-kan==0.1.0) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.18.0->efficient-kan==0.1.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.18.0->efficient-kan==0.1.0) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.3.0->efficient-kan==0.1.0) (3.0.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2.4.1)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 114.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 64.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 16.2 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 50.5 MB/s eta 0:00:00
# Building wheels for collected packages: efficient-kan
#   Building wheel for efficient-kan (pyproject.toml) ... done
#   Created wheel for efficient-kan: filename=efficient_kan-0.1.0-py3-none-any.whl size=5981 sha256=3fadb37365bda971d6bcb716e5ecf58aca9c70ee79e32324453796857b325548
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ceqhbe3j/wheels/da/a3/b4/30b3e3df2edaded3c87227cb9faea5878f18ec03e1c2137839
# Successfully built efficient-kan
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, efficient-kan
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed efficient-kan-0.1.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !git clone https://agusth24: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@github.com/agusth24/ethereum-fraud-detection.git
# Out:
# Cloning into 'ethereum-fraud-detection'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (31/31), done.
# Receiving objects: 100% (51/51), 14.72 KiB | 2.45 MiB/s, done.
# remote: Total 51 (delta 23), reused 45 (delta 17), pack-reused 0 (from 0)
# Resolving deltas: 100% (23/23), done.

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/wacgan-ethereum-balanced/graph_data/wacgan_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GCN \
--classifier KAN \
--epochs_stage1 200 --epochs_stage2 200 --patience 50 --use_oversampling --output_file --use_csl --csl_weight 0.2
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/wacgan-ethereum-balanced/graph_data/wacgan_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 7863 nodes and 26082 edges
# Merge Info: 7613 overlapping nodes (anchors), 250 new synthetic nodes.
# Num nodes 7863 | Features: torch.Size([7863, 27]) | Fraud Train: 289 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5731 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7863, Edges: 26082, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 200, Patience: 50
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GCN + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GCN_KAN_OS_CSL_0...
#       Stage 1 Epoch 10 | Loss: 8.4796 | Val Loss: 6.3882
#       Stage 1 Epoch 20 | Loss: 8.4663 | Val Loss: 6.3861
#       Stage 1 Epoch 30 | Loss: 8.4653 | Val Loss: 6.3833
#       Stage 1 Epoch 40 | Loss: 8.4629 | Val Loss: 6.3826
#       Stage 1 Epoch 50 | Loss: 8.4600 | Val Loss: 6.3826
#       Stage 1 Epoch 60 | Loss: 8.4597 | Val Loss: 6.3814
#       Stage 1 Epoch 70 | Loss: 8.4606 | Val Loss: 6.3808
#       Stage 1 Epoch 80 | Loss: 8.4589 | Val Loss: 6.3799
#       Stage 1 Epoch 90 | Loss: 8.4592 | Val Loss: 6.3797
#       Stage 1 Epoch 100 | Loss: 8.4591 | Val Loss: 6.3792
#       Stage 1 Epoch 110 | Loss: 8.4594 | Val Loss: 6.3787
#       Stage 1 Epoch 120 | Loss: 8.4573 | Val Loss: 6.3786
#       Stage 1 Epoch 130 | Loss: 8.4578 | Val Loss: 6.3794
#       Stage 1 Epoch 140 | Loss: 8.4596 | Val Loss: 6.3796
#       Stage 1 Epoch 150 | Loss: 8.4577 | Val Loss: 6.3780
#       Stage 1 Epoch 160 | Loss: 8.4579 | Val Loss: 6.3751
#       Stage 1 Epoch 170 | Loss: 8.4593 | Val Loss: 6.3789
#       Stage 1 Epoch 180 | Loss: 8.4584 | Val Loss: 6.3835
#       Stage 1 Epoch 190 | Loss: 8.4586 | Val Loss: 6.3832
#       Stage 1 Epoch 200 | Loss: 8.4579 | Val Loss: 6.3797
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_KAN_OS_CSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0045 | Val Loss: 0.0169
#       Stage 2 Epoch 20 | Loss: 0.0036 | Val Loss: 0.0084
#       Stage 2 Epoch 30 | Loss: 0.0014 | Val Loss: 0.0073
#       Stage 2 Epoch 40 | Loss: 0.0014 | Val Loss: 0.0064
#       Stage 2 Epoch 50 | Loss: 0.0012 | Val Loss: 0.0024
#       Stage 2 Epoch 60 | Loss: 0.0018 | Val Loss: 0.0069
#       Stage 2 Epoch 70 | Loss: 0.0030 | Val Loss: 0.0045
#       Stage 2 Epoch 80 | Loss: 0.0031 | Val Loss: 0.0042
#       Stage 2 Early stopping at epoch 86
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_KAN_OS_CSL_0.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9960604070912672, 'prec': 0.7777777777777778, 'rec': 0.6363636363636364, 'f1': 0.7000000000000001}
# Results ready to be saved to results/eval_first_graph_GCN_KAN_OS_CSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GCN + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GCN_KAN_OS_CSL_42...
#       Stage 1 Epoch 10 | Loss: 8.4740 | Val Loss: 6.3883
#       Stage 1 Epoch 20 | Loss: 8.4672 | Val Loss: 6.3855
#       Stage 1 Epoch 30 | Loss: 8.4626 | Val Loss: 6.3835
#       Stage 1 Epoch 40 | Loss: 8.4609 | Val Loss: 6.3825
#       Stage 1 Epoch 50 | Loss: 8.4608 | Val Loss: 6.3821
#       Stage 1 Epoch 60 | Loss: 8.4608 | Val Loss: 6.3815
#       Stage 1 Epoch 70 | Loss: 8.4598 | Val Loss: 6.3795
#       Stage 1 Epoch 80 | Loss: 8.4593 | Val Loss: 6.3797
#       Stage 1 Epoch 90 | Loss: 8.4585 | Val Loss: 6.3803
#       Stage 1 Epoch 100 | Loss: 8.4589 | Val Loss: 6.3798
#       Stage 1 Epoch 110 | Loss: 8.4581 | Val Loss: 6.3796
#       Stage 1 Epoch 120 | Loss: 8.4574 | Val Loss: 6.3787
#       Stage 1 Epoch 130 | Loss: 8.4573 | Val Loss: 6.3810
#       Stage 1 Epoch 140 | Loss: 8.4593 | Val Loss: 6.3766
#       Stage 1 Epoch 150 | Loss: 8.4592 | Val Loss: 6.3769
#       Stage 1 Epoch 160 | Loss: 8.4571 | Val Loss: 6.3776
#       Stage 1 Epoch 170 | Loss: 8.4573 | Val Loss: 6.3741
#       Stage 1 Epoch 180 | Loss: 8.4588 | Val Loss: 6.3842
#       Stage 1 Epoch 190 | Loss: 8.4563 | Val Loss: 6.3832
#       Stage 1 Epoch 200 | Loss: 8.4585 | Val Loss: 6.3791
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_KAN_OS_CSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0042 | Val Loss: 0.0095
#       Stage 2 Epoch 20 | Loss: 0.0052 | Val Loss: 0.0219
#       Stage 2 Epoch 30 | Loss: 0.0024 | Val Loss: 0.0052
#       Stage 2 Epoch 40 | Loss: 0.0016 | Val Loss: 0.0017
#       Stage 2 Epoch 50 | Loss: 0.0022 | Val Loss: 0.0064
#       Stage 2 Epoch 60 | Loss: 0.0021 | Val Loss: 0.0046
#       Stage 2 Epoch 70 | Loss: 0.0035 | Val Loss: 0.0077
#       Stage 2 Epoch 80 | Loss: 0.0027 | Val Loss: 0.0093
#       Stage 2 Epoch 90 | Loss: 0.0023 | Val Loss: 0.0034
#       Stage 2 Epoch 100 | Loss: 0.0027 | Val Loss: 0.0033
#       Stage 2 Early stopping at epoch 101
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_KAN_OS_CSL_42.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9973736047275115, 'prec': 1.0, 'rec': 0.6363636363636364, 'f1': 0.7777777777777778}
# Results ready to be saved to results/eval_first_graph_GCN_KAN_OS_CSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GCN + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GCN_KAN_OS_CSL_101...
#       Stage 1 Epoch 10 | Loss: 8.4785 | Val Loss: 6.3867
#       Stage 1 Epoch 20 | Loss: 8.4688 | Val Loss: 6.3846
#       Stage 1 Epoch 30 | Loss: 8.4653 | Val Loss: 6.3836
#       Stage 1 Epoch 40 | Loss: 8.4637 | Val Loss: 6.3826
#       Stage 1 Epoch 50 | Loss: 8.4627 | Val Loss: 6.3821
#       Stage 1 Epoch 60 | Loss: 8.4612 | Val Loss: 6.3827
#       Stage 1 Epoch 70 | Loss: 8.4598 | Val Loss: 6.3816
#       Stage 1 Epoch 80 | Loss: 8.4615 | Val Loss: 6.3794
#       Stage 1 Epoch 90 | Loss: 8.4597 | Val Loss: 6.3797
#       Stage 1 Epoch 100 | Loss: 8.4598 | Val Loss: 6.3797
#       Stage 1 Epoch 110 | Loss: 8.4578 | Val Loss: 6.3795
#       Stage 1 Epoch 120 | Loss: 8.4585 | Val Loss: 6.3807
#       Stage 1 Epoch 130 | Loss: 8.4590 | Val Loss: 6.3795
#       Stage 1 Epoch 140 | Loss: 8.4584 | Val Loss: 6.3802
#       Stage 1 Epoch 150 | Loss: 8.4573 | Val Loss: 6.3806
#       Stage 1 Epoch 160 | Loss: 8.4576 | Val Loss: 6.3793
#       Stage 1 Epoch 170 | Loss: 8.4575 | Val Loss: 6.3826
#       Stage 1 Epoch 180 | Loss: 8.4580 | Val Loss: 6.3812
#       Stage 1 Epoch 190 | Loss: 8.4574 | Val Loss: 6.3804
#       Stage 1 Epoch 200 | Loss: 8.4572 | Val Loss: 6.3783
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_KAN_OS_CSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0047 | Val Loss: 0.0069
#       Stage 2 Epoch 20 | Loss: 0.0030 | Val Loss: 0.0006
#       Stage 2 Epoch 30 | Loss: 0.0021 | Val Loss: 0.0071
#       Stage 2 Epoch 40 | Loss: 0.0018 | Val Loss: 0.0038
#       Stage 2 Epoch 50 | Loss: 0.0019 | Val Loss: 0.0030
#       Stage 2 Epoch 60 | Loss: 0.0023 | Val Loss: 0.0029
#       Stage 2 Early stopping at epoch 70
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_KAN_OS_CSL_101.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9980302035456337, 'prec': 0.8333333333333334, 'rec': 0.9090909090909091, 'f1': 0.8695652173913043}
# Results ready to be saved to results/eval_first_graph_GCN_KAN_OS_CSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GCN + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GCN_KAN_OS_CSL_1024...
#       Stage 1 Epoch 10 | Loss: 8.4862 | Val Loss: 6.3958
#       Stage 1 Epoch 20 | Loss: 8.4672 | Val Loss: 6.3872
#       Stage 1 Epoch 30 | Loss: 8.4633 | Val Loss: 6.3849
#       Stage 1 Epoch 40 | Loss: 8.4617 | Val Loss: 6.3836
#       Stage 1 Epoch 50 | Loss: 8.4615 | Val Loss: 6.3841
#       Stage 1 Epoch 60 | Loss: 8.4585 | Val Loss: 6.3833
#       Stage 1 Epoch 70 | Loss: 8.4585 | Val Loss: 6.3832
#       Stage 1 Epoch 80 | Loss: 8.4592 | Val Loss: 6.3816
#       Stage 1 Epoch 90 | Loss: 8.4585 | Val Loss: 6.3817
#       Stage 1 Epoch 100 | Loss: 8.4584 | Val Loss: 6.3816
#       Stage 1 Epoch 110 | Loss: 8.4593 | Val Loss: 6.3821
#       Stage 1 Epoch 120 | Loss: 8.4597 | Val Loss: 6.3822
#       Stage 1 Epoch 130 | Loss: 8.4599 | Val Loss: 6.3801
#       Stage 1 Epoch 140 | Loss: 8.4585 | Val Loss: 6.3820
#       Stage 1 Epoch 150 | Loss: 8.4593 | Val Loss: 6.3807
#       Stage 1 Epoch 160 | Loss: 8.4572 | Val Loss: 6.3780
#       Stage 1 Epoch 170 | Loss: 8.4593 | Val Loss: 6.3757
#       Stage 1 Epoch 180 | Loss: 8.4587 | Val Loss: 6.3813
#       Stage 1 Epoch 190 | Loss: 8.4572 | Val Loss: 6.3822
#       Stage 1 Epoch 200 | Loss: 8.4572 | Val Loss: 6.3819
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_KAN_OS_CSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.0062 | Val Loss: 0.0196
#       Stage 2 Epoch 20 | Loss: 0.0043 | Val Loss: 0.0070
#       Stage 2 Epoch 30 | Loss: 0.0013 | Val Loss: 0.0064
#       Stage 2 Epoch 40 | Loss: 0.0021 | Val Loss: 0.0024
#       Stage 2 Epoch 50 | Loss: 0.0014 | Val Loss: 0.0061
#       Stage 2 Epoch 60 | Loss: 0.0024 | Val Loss: 0.0037
#       Stage 2 Early stopping at epoch 69
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_KAN_OS_CSL_1024.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9980302035456337, 'prec': 0.8333333333333334, 'rec': 0.9090909090909091, 'f1': 0.8695652173913043}
# Results ready to be saved to results/eval_first_graph_GCN_KAN_OS_CSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GCN + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GCN_KAN_OS_CSL_2025...
#       Stage 1 Epoch 10 | Loss: 8.4775 | Val Loss: 6.3909
#       Stage 1 Epoch 20 | Loss: 8.4668 | Val Loss: 6.3856
#       Stage 1 Epoch 30 | Loss: 8.4622 | Val Loss: 6.3828
#       Stage 1 Epoch 40 | Loss: 8.4611 | Val Loss: 6.3829
#       Stage 1 Epoch 50 | Loss: 8.4601 | Val Loss: 6.3830
#       Stage 1 Epoch 60 | Loss: 8.4605 | Val Loss: 6.3819
#       Stage 1 Epoch 70 | Loss: 8.4592 | Val Loss: 6.3821
#       Stage 1 Epoch 80 | Loss: 8.4597 | Val Loss: 6.3814
#       Stage 1 Epoch 90 | Loss: 8.4594 | Val Loss: 6.3819
#       Stage 1 Epoch 100 | Loss: 8.4582 | Val Loss: 6.3814
#       Stage 1 Epoch 110 | Loss: 8.4586 | Val Loss: 6.3821
#       Stage 1 Epoch 120 | Loss: 8.4579 | Val Loss: 6.3795
#       Stage 1 Epoch 130 | Loss: 8.4599 | Val Loss: 6.3781
#       Stage 1 Epoch 140 | Loss: 8.4574 | Val Loss: 6.3779
#       Stage 1 Epoch 150 | Loss: 8.4582 | Val Loss: 6.3796
#       Stage 1 Epoch 160 | Loss: 8.4597 | Val Loss: 6.3819
#       Stage 1 Epoch 170 | Loss: 8.4584 | Val Loss: 6.3794
#       Stage 1 Epoch 180 | Loss: 8.4568 | Val Loss: 6.3800
#       Stage 1 Epoch 190 | Loss: 8.4585 | Val Loss: 6.3784
#       Stage 1 Epoch 200 | Loss: 8.4579 | Val Loss: 6.3796
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_KAN_OS_CSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.0065 | Val Loss: 0.0163
#       Stage 2 Epoch 20 | Loss: 0.0027 | Val Loss: 0.0072
#       Stage 2 Epoch 30 | Loss: 0.0020 | Val Loss: 0.0056
#       Stage 2 Epoch 40 | Loss: 0.0016 | Val Loss: 0.0027
#       Stage 2 Epoch 50 | Loss: 0.0018 | Val Loss: 0.0059
#       Stage 2 Epoch 60 | Loss: 0.0023 | Val Loss: 0.0060
#       Stage 2 Epoch 70 | Loss: 0.0023 | Val Loss: 0.0029
#       Stage 2 Early stopping at epoch 73
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_KAN_OS_CSL_2025.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9973736047275115, 'prec': 0.8181818181818182, 'rec': 0.8181818181818182, 'f1': 0.8181818181818182}
# Results ready to be saved to results/eval_first_graph_GCN_KAN_OS_CSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/wacgan-ethereum-balanced/graph_data/wacgan_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GAT \
--classifier KAN \
--epochs_stage1 200 --epochs_stage2 200 --patience 50 --use_oversampling --output_file --use_csl --csl_weight 0.2
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/wacgan-ethereum-balanced/graph_data/wacgan_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 7863 nodes and 26082 edges
# Merge Info: 7613 overlapping nodes (anchors), 250 new synthetic nodes.
# Num nodes 7863 | Features: torch.Size([7863, 27]) | Fraud Train: 289 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5731 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7863, Edges: 26082, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 200, Patience: 50
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GAT + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GAT_KAN_OS_CSL_0...
#       Stage 1 Epoch 10 | Loss: 8.5298 | Val Loss: 6.4196
#       Stage 1 Epoch 20 | Loss: 8.5689 | Val Loss: 6.4116
#       Stage 1 Epoch 30 | Loss: 8.5317 | Val Loss: 6.3957
#       Stage 1 Epoch 40 | Loss: 8.4956 | Val Loss: 6.3865
#       Stage 1 Epoch 50 | Loss: 8.4983 | Val Loss: 6.3804
#       Stage 1 Epoch 60 | Loss: 8.5096 | Val Loss: 6.3807
#       Stage 1 Epoch 70 | Loss: 8.4998 | Val Loss: 6.3800
#       Stage 1 Epoch 80 | Loss: 8.4916 | Val Loss: 6.3817
#       Stage 1 Epoch 90 | Loss: 8.4835 | Val Loss: 6.3819
#       Stage 1 Epoch 100 | Loss: 8.5027 | Val Loss: 6.3814
#       Stage 1 Epoch 110 | Loss: 8.4866 | Val Loss: 6.3817
#       Stage 1 Epoch 120 | Loss: 8.4835 | Val Loss: 6.3811
#       Stage 1 Epoch 130 | Loss: 8.4927 | Val Loss: 6.3812
#       Stage 1 Epoch 140 | Loss: 8.4854 | Val Loss: 6.3808
#       Stage 1 Epoch 150 | Loss: 8.4812 | Val Loss: 6.3817
#       Stage 1 Epoch 160 | Loss: 8.4854 | Val Loss: 6.3820
#       Stage 1 Epoch 170 | Loss: 8.5013 | Val Loss: 6.3803
#       Stage 1 Epoch 180 | Loss: 8.4743 | Val Loss: 6.3809
#       Stage 1 Epoch 190 | Loss: 8.4824 | Val Loss: 6.3820
#       Stage 1 Epoch 200 | Loss: 8.4960 | Val Loss: 6.3783
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_KAN_OS_CSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0278 | Val Loss: 0.0005
#       Stage 2 Epoch 20 | Loss: 0.0301 | Val Loss: 0.0061
#       Stage 2 Epoch 30 | Loss: 0.0232 | Val Loss: 0.0033
#       Stage 2 Epoch 40 | Loss: 0.0129 | Val Loss: 0.0022
#       Stage 2 Epoch 50 | Loss: 0.0151 | Val Loss: 0.0028
#       Stage 2 Early stopping at epoch 60
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_KAN_OS_CSL_0.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9960604070912672, 'prec': 0.7272727272727273, 'rec': 0.7272727272727273, 'f1': 0.7272727272727273}
# Results ready to be saved to results/eval_first_graph_GAT_KAN_OS_CSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GAT + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GAT_KAN_OS_CSL_42...
#       Stage 1 Epoch 10 | Loss: 8.5584 | Val Loss: 6.4235
#       Stage 1 Epoch 20 | Loss: 8.5332 | Val Loss: 6.4171
#       Stage 1 Epoch 30 | Loss: 8.5035 | Val Loss: 6.3755
#       Stage 1 Epoch 40 | Loss: 8.4929 | Val Loss: 6.3739
#       Stage 1 Epoch 50 | Loss: 8.4978 | Val Loss: 6.3720
#       Stage 1 Epoch 60 | Loss: 8.5015 | Val Loss: 6.3742
#       Stage 1 Epoch 70 | Loss: 8.4876 | Val Loss: 6.3720
#       Stage 1 Epoch 80 | Loss: 8.4899 | Val Loss: 6.3729
#       Stage 1 Epoch 90 | Loss: 8.4867 | Val Loss: 6.3733
#       Stage 1 Epoch 100 | Loss: 8.4936 | Val Loss: 6.3738
#       Stage 1 Epoch 110 | Loss: 8.4917 | Val Loss: 6.3748
#       Stage 1 Epoch 120 | Loss: 8.4960 | Val Loss: 6.3719
#       Stage 1 Epoch 130 | Loss: 8.4812 | Val Loss: 6.3727
#       Stage 1 Epoch 140 | Loss: 8.4944 | Val Loss: 6.3731
#       Stage 1 Epoch 150 | Loss: 8.5018 | Val Loss: 6.3731
#       Stage 1 Epoch 160 | Loss: 8.4992 | Val Loss: 6.3734
#       Stage 1 Epoch 170 | Loss: 8.4873 | Val Loss: 6.3739
#       Stage 1 Epoch 180 | Loss: 8.4895 | Val Loss: 6.3722
#       Stage 1 Epoch 190 | Loss: 8.4815 | Val Loss: 6.3729
#       Stage 1 Epoch 200 | Loss: 8.4840 | Val Loss: 6.3738
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_KAN_OS_CSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0435 | Val Loss: 0.0243
#       Stage 2 Epoch 20 | Loss: 0.0218 | Val Loss: 0.0029
#       Stage 2 Epoch 30 | Loss: 0.0222 | Val Loss: 0.0040
#       Stage 2 Epoch 40 | Loss: 0.0135 | Val Loss: 0.0048
#       Stage 2 Epoch 50 | Loss: 0.0166 | Val Loss: 0.0029
#       Stage 2 Epoch 60 | Loss: 0.0185 | Val Loss: 0.0055
#       Stage 2 Epoch 70 | Loss: 0.0183 | Val Loss: 0.0039
#       Stage 2 Early stopping at epoch 74
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_KAN_OS_CSL_42.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9986868023637557, 'prec': 1.0, 'rec': 0.8181818181818182, 'f1': 0.9}
# Results ready to be saved to results/eval_first_graph_GAT_KAN_OS_CSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GAT + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GAT_KAN_OS_CSL_101...
#       Stage 1 Epoch 10 | Loss: 8.5264 | Val Loss: 6.4169
#       Stage 1 Epoch 20 | Loss: 8.5162 | Val Loss: 6.4011
#       Stage 1 Epoch 30 | Loss: 8.5071 | Val Loss: 6.3792
#       Stage 1 Epoch 40 | Loss: 8.5065 | Val Loss: 6.3806
#       Stage 1 Epoch 50 | Loss: 8.5093 | Val Loss: 6.3765
#       Stage 1 Epoch 60 | Loss: 8.5035 | Val Loss: 6.3783
#       Stage 1 Epoch 70 | Loss: 8.5018 | Val Loss: 6.3771
#       Stage 1 Epoch 80 | Loss: 8.4842 | Val Loss: 6.3795
#       Stage 1 Epoch 90 | Loss: 8.4905 | Val Loss: 6.3801
#       Stage 1 Epoch 100 | Loss: 8.4884 | Val Loss: 6.3789
#       Stage 1 Epoch 110 | Loss: 8.4934 | Val Loss: 6.3799
#       Stage 1 Epoch 120 | Loss: 8.4893 | Val Loss: 6.3798
#       Stage 1 Epoch 130 | Loss: 8.4933 | Val Loss: 6.3806
#       Stage 1 Epoch 140 | Loss: 8.4897 | Val Loss: 6.3817
#       Stage 1 Epoch 150 | Loss: 8.4833 | Val Loss: 6.3792
#       Stage 1 Epoch 160 | Loss: 8.4961 | Val Loss: 6.3773
#       Stage 1 Epoch 170 | Loss: 8.4867 | Val Loss: 6.3787
#       Stage 1 Epoch 180 | Loss: 8.4886 | Val Loss: 6.3797
#       Stage 1 Epoch 190 | Loss: 8.4795 | Val Loss: 6.3791
#       Stage 1 Epoch 200 | Loss: 8.4806 | Val Loss: 6.3823
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_KAN_OS_CSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0324 | Val Loss: 0.0194
#       Stage 2 Epoch 20 | Loss: 0.0366 | Val Loss: 0.0144
#       Stage 2 Epoch 30 | Loss: 0.0211 | Val Loss: 0.0109
#       Stage 2 Epoch 40 | Loss: 0.0278 | Val Loss: 0.0065
#       Stage 2 Epoch 50 | Loss: 0.0173 | Val Loss: 0.0101
#       Stage 2 Epoch 60 | Loss: 0.0185 | Val Loss: 0.0066
#       Stage 2 Early stopping at epoch 63
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_KAN_OS_CSL_101.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9973736047275115, 'prec': 0.8181818181818182, 'rec': 0.8181818181818182, 'f1': 0.8181818181818182}
# Results ready to be saved to results/eval_first_graph_GAT_KAN_OS_CSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GAT + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GAT_KAN_OS_CSL_1024...
#       Stage 1 Epoch 10 | Loss: 8.5413 | Val Loss: 6.4123
#       Stage 1 Epoch 20 | Loss: 8.5187 | Val Loss: 6.4126
#       Stage 1 Epoch 30 | Loss: 8.5220 | Val Loss: 6.3964
#       Stage 1 Epoch 40 | Loss: 8.5073 | Val Loss: 6.3881
#       Stage 1 Epoch 50 | Loss: 8.5009 | Val Loss: 6.3858
#       Stage 1 Epoch 60 | Loss: 8.4946 | Val Loss: 6.3777
#       Stage 1 Epoch 70 | Loss: 8.5003 | Val Loss: 6.3748
#       Stage 1 Epoch 80 | Loss: 8.4964 | Val Loss: 6.3739
#       Stage 1 Epoch 90 | Loss: 8.4879 | Val Loss: 6.3761
#       Stage 1 Epoch 100 | Loss: 8.4999 | Val Loss: 6.3737
#       Stage 1 Epoch 110 | Loss: 8.4919 | Val Loss: 6.3774
#       Stage 1 Epoch 120 | Loss: 8.4908 | Val Loss: 6.3729
#       Stage 1 Epoch 130 | Loss: 8.4951 | Val Loss: 6.3754
#       Stage 1 Epoch 140 | Loss: 8.4872 | Val Loss: 6.3741
#       Stage 1 Epoch 150 | Loss: 8.4862 | Val Loss: 6.3765
#       Stage 1 Epoch 160 | Loss: 8.4836 | Val Loss: 6.3741
#       Stage 1 Epoch 170 | Loss: 8.4870 | Val Loss: 6.3728
#       Stage 1 Epoch 180 | Loss: 8.4885 | Val Loss: 6.3758
#       Stage 1 Epoch 190 | Loss: 8.4815 | Val Loss: 6.3758
#       Stage 1 Epoch 200 | Loss: 8.4864 | Val Loss: 6.3746
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_KAN_OS_CSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.0347 | Val Loss: 0.0127
#       Stage 2 Epoch 20 | Loss: 0.0261 | Val Loss: 0.0103
#       Stage 2 Epoch 30 | Loss: 0.0206 | Val Loss: 0.0207
#       Stage 2 Epoch 40 | Loss: 0.0118 | Val Loss: 0.0031
#       Stage 2 Epoch 50 | Loss: 0.0157 | Val Loss: 0.0030
#       Stage 2 Epoch 60 | Loss: 0.0146 | Val Loss: 0.0043
#       Stage 2 Early stopping at epoch 64
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_KAN_OS_CSL_1024.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9986868023637557, 'prec': 1.0, 'rec': 0.8181818181818182, 'f1': 0.9}
# Results ready to be saved to results/eval_first_graph_GAT_KAN_OS_CSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GAT + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GAT_KAN_OS_CSL_2025...
#       Stage 1 Epoch 10 | Loss: 8.6318 | Val Loss: 6.4130
#       Stage 1 Epoch 20 | Loss: 8.5492 | Val Loss: 6.4130
#       Stage 1 Epoch 30 | Loss: 8.5376 | Val Loss: 6.4149
#       Stage 1 Epoch 40 | Loss: 8.5085 | Val Loss: 6.3976
#       Stage 1 Epoch 50 | Loss: 8.5017 | Val Loss: 6.3776
#       Stage 1 Epoch 60 | Loss: 8.4957 | Val Loss: 6.3781
#       Stage 1 Epoch 70 | Loss: 8.4986 | Val Loss: 6.3805
#       Stage 1 Epoch 80 | Loss: 8.4862 | Val Loss: 6.3791
#       Stage 1 Epoch 90 | Loss: 8.4938 | Val Loss: 6.3783
#       Stage 1 Epoch 100 | Loss: 8.4981 | Val Loss: 6.3851
#       Stage 1 Epoch 110 | Loss: 8.4938 | Val Loss: 6.3803
#       Stage 1 Epoch 120 | Loss: 8.4976 | Val Loss: 6.3806
#       Stage 1 Epoch 130 | Loss: 8.4957 | Val Loss: 6.3841
#       Stage 1 Epoch 140 | Loss: 8.4874 | Val Loss: 6.3832
#       Stage 1 Epoch 150 | Loss: 8.4935 | Val Loss: 6.3831
#       Stage 1 Epoch 160 | Loss: 8.4861 | Val Loss: 6.3834
#       Stage 1 Epoch 170 | Loss: 8.5026 | Val Loss: 6.3835
#       Stage 1 Epoch 180 | Loss: 8.4897 | Val Loss: 6.3824
#       Stage 1 Epoch 190 | Loss: 8.4945 | Val Loss: 6.3839
#       Stage 1 Epoch 200 | Loss: 8.4988 | Val Loss: 6.3844
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_KAN_OS_CSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.0300 | Val Loss: 0.0202
#       Stage 2 Epoch 20 | Loss: 0.0219 | Val Loss: 0.0049
#       Stage 2 Epoch 30 | Loss: 0.0253 | Val Loss: 0.0034
#       Stage 2 Epoch 40 | Loss: 0.0151 | Val Loss: 0.0048
#       Stage 2 Epoch 50 | Loss: 0.0126 | Val Loss: 0.0036
#       Stage 2 Epoch 60 | Loss: 0.0153 | Val Loss: 0.0057
#       Stage 2 Early stopping at epoch 65
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_KAN_OS_CSL_2025.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9967170059093894, 'prec': 0.75, 'rec': 0.8181818181818182, 'f1': 0.7826086956521738}
# Results ready to be saved to results/eval_first_graph_GAT_KAN_OS_CSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/wacgan-ethereum-balanced/graph_data/wacgan_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GraphSAGE \
--classifier KAN \
--epochs_stage1 200 --epochs_stage2 200 --patience 50 --use_oversampling --output_file --use_csl --csl_weight 0.2
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/wacgan-ethereum-balanced/graph_data/wacgan_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 7863 nodes and 26082 edges
# Merge Info: 7613 overlapping nodes (anchors), 250 new synthetic nodes.
# Num nodes 7863 | Features: torch.Size([7863, 27]) | Fraud Train: 289 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5731 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7863, Edges: 26082, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 200, Patience: 50
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GraphSAGE + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GraphSAGE_KAN_OS_CSL_0...
#       Stage 1 Epoch 10 | Loss: 8.4904 | Val Loss: 6.3998
#       Stage 1 Epoch 20 | Loss: 8.4637 | Val Loss: 6.3760
#       Stage 1 Epoch 30 | Loss: 8.4653 | Val Loss: 6.3714
#       Stage 1 Epoch 40 | Loss: 8.4586 | Val Loss: 6.3703
#       Stage 1 Epoch 50 | Loss: 8.4561 | Val Loss: 6.3697
#       Stage 1 Epoch 60 | Loss: 8.4549 | Val Loss: 6.3692
#       Stage 1 Epoch 70 | Loss: 8.4544 | Val Loss: 6.3690
#       Stage 1 Epoch 80 | Loss: 8.4548 | Val Loss: 6.3690
#       Stage 1 Epoch 90 | Loss: 8.4539 | Val Loss: 6.3689
#       Stage 1 Epoch 100 | Loss: 8.4540 | Val Loss: 6.3689
#       Stage 1 Epoch 110 | Loss: 8.4539 | Val Loss: 6.3689
#       Stage 1 Epoch 120 | Loss: 8.4539 | Val Loss: 6.3689
#       Stage 1 Epoch 130 | Loss: 8.4539 | Val Loss: 6.3689
#       Stage 1 Epoch 140 | Loss: 8.4538 | Val Loss: 6.3689
#       Stage 1 Epoch 150 | Loss: 8.4537 | Val Loss: 6.3689
#       Stage 1 Epoch 160 | Loss: 8.4547 | Val Loss: 6.3689
#       Stage 1 Epoch 170 | Loss: 8.4538 | Val Loss: 6.3689
#       Stage 1 Epoch 180 | Loss: 8.4539 | Val Loss: 6.3688
#       Stage 1 Epoch 190 | Loss: 8.4539 | Val Loss: 6.3688
#       Stage 1 Epoch 200 | Loss: 8.4537 | Val Loss: 6.3688
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_KAN_OS_CSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0034 | Val Loss: 0.0105
#       Stage 2 Epoch 20 | Loss: 0.0001 | Val Loss: 0.0000
#       Stage 2 Epoch 30 | Loss: 0.0012 | Val Loss: 0.0006
#       Stage 2 Epoch 40 | Loss: 0.0001 | Val Loss: 0.0000
#       Stage 2 Epoch 50 | Loss: 0.0008 | Val Loss: 0.0004
#       Stage 2 Epoch 60 | Loss: 0.0005 | Val Loss: 0.0017
#       Stage 2 Early stopping at epoch 67
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_KAN_OS_CSL_0.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9993434011818779, 'prec': 1.0, 'rec': 0.9090909090909091, 'f1': 0.9523809523809523}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_KAN_OS_CSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GraphSAGE + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GraphSAGE_KAN_OS_CSL_42...
#       Stage 1 Epoch 10 | Loss: 8.4731 | Val Loss: 6.3860
#       Stage 1 Epoch 20 | Loss: 8.4622 | Val Loss: 6.3790
#       Stage 1 Epoch 30 | Loss: 8.4565 | Val Loss: 6.3730
#       Stage 1 Epoch 40 | Loss: 8.4556 | Val Loss: 6.3710
#       Stage 1 Epoch 50 | Loss: 8.4551 | Val Loss: 6.3707
#       Stage 1 Epoch 60 | Loss: 8.4541 | Val Loss: 6.3691
#       Stage 1 Epoch 70 | Loss: 8.4546 | Val Loss: 6.3690
#       Stage 1 Epoch 80 | Loss: 8.4542 | Val Loss: 6.3689
#       Stage 1 Epoch 90 | Loss: 8.4554 | Val Loss: 6.3689
#       Stage 1 Epoch 100 | Loss: 8.4544 | Val Loss: 6.3689
#       Stage 1 Epoch 110 | Loss: 8.4538 | Val Loss: 6.3695
#       Stage 1 Epoch 120 | Loss: 8.4539 | Val Loss: 6.3690
#       Stage 1 Epoch 130 | Loss: 8.4541 | Val Loss: 6.3692
#       Stage 1 Epoch 140 | Loss: 8.4541 | Val Loss: 6.3689
#       Stage 1 Epoch 150 | Loss: 8.4540 | Val Loss: 6.3689
#       Stage 1 Epoch 160 | Loss: 8.4539 | Val Loss: 6.3689
#       Stage 1 Epoch 170 | Loss: 8.4556 | Val Loss: 6.3688
#       Stage 1 Epoch 180 | Loss: 8.4542 | Val Loss: 6.3689
#       Stage 1 Epoch 190 | Loss: 8.4538 | Val Loss: 6.3689
#       Stage 1 Epoch 200 | Loss: 8.4538 | Val Loss: 6.3688
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_KAN_OS_CSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0035 | Val Loss: 0.0014
#       Stage 2 Epoch 20 | Loss: 0.0003 | Val Loss: 0.0000
#       Stage 2 Epoch 30 | Loss: 0.0001 | Val Loss: 0.0000
#       Stage 2 Epoch 40 | Loss: 0.0002 | Val Loss: 0.0003
#       Stage 2 Epoch 50 | Loss: 0.0023 | Val Loss: 0.0000
#       Stage 2 Epoch 60 | Loss: 0.0010 | Val Loss: 0.0002
#       Stage 2 Early stopping at epoch 66
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_KAN_OS_CSL_42.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9993434011818779, 'prec': 1.0, 'rec': 0.9090909090909091, 'f1': 0.9523809523809523}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_KAN_OS_CSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GraphSAGE + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GraphSAGE_KAN_OS_CSL_101...
#       Stage 1 Epoch 10 | Loss: 8.4796 | Val Loss: 6.3868
#       Stage 1 Epoch 20 | Loss: 8.4632 | Val Loss: 6.3749
#       Stage 1 Epoch 30 | Loss: 8.4583 | Val Loss: 6.3703
#       Stage 1 Epoch 40 | Loss: 8.4573 | Val Loss: 6.3705
#       Stage 1 Epoch 50 | Loss: 8.4547 | Val Loss: 6.3702
#       Stage 1 Epoch 60 | Loss: 8.4540 | Val Loss: 6.3693
#       Stage 1 Epoch 70 | Loss: 8.4563 | Val Loss: 6.3691
#       Stage 1 Epoch 80 | Loss: 8.4544 | Val Loss: 6.3694
#       Stage 1 Epoch 90 | Loss: 8.4541 | Val Loss: 6.3691
#       Stage 1 Epoch 100 | Loss: 8.4539 | Val Loss: 6.3692
#       Stage 1 Epoch 110 | Loss: 8.4542 | Val Loss: 6.3693
#       Stage 1 Epoch 120 | Loss: 8.4539 | Val Loss: 6.3690
#       Stage 1 Epoch 130 | Loss: 8.4538 | Val Loss: 6.3689
#       Stage 1 Epoch 140 | Loss: 8.4543 | Val Loss: 6.3690
#       Stage 1 Epoch 150 | Loss: 8.4544 | Val Loss: 6.3689
#       Stage 1 Epoch 160 | Loss: 8.4541 | Val Loss: 6.3689
#       Stage 1 Epoch 170 | Loss: 8.4537 | Val Loss: 6.3689
#       Stage 1 Epoch 180 | Loss: 8.4538 | Val Loss: 6.3689
#       Stage 1 Epoch 190 | Loss: 8.4542 | Val Loss: 6.3689
#       Stage 1 Epoch 200 | Loss: 8.4547 | Val Loss: 6.3712
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_KAN_OS_CSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0052 | Val Loss: 0.0018
#       Stage 2 Epoch 20 | Loss: 0.0001 | Val Loss: 0.0000
#       Stage 2 Epoch 30 | Loss: 0.0002 | Val Loss: 0.0000
#       Stage 2 Epoch 40 | Loss: 0.0000 | Val Loss: 0.0000
#       Stage 2 Epoch 50 | Loss: 0.0005 | Val Loss: 0.0001
#       Stage 2 Epoch 60 | Loss: 0.0003 | Val Loss: 0.0003
#       Stage 2 Early stopping at epoch 65
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_KAN_OS_CSL_101.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9986868023637557, 'prec': 0.9090909090909091, 'rec': 0.9090909090909091, 'f1': 0.9090909090909091}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_KAN_OS_CSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GraphSAGE + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GraphSAGE_KAN_OS_CSL_1024...
#       Stage 1 Epoch 10 | Loss: 8.4705 | Val Loss: 6.3829
#       Stage 1 Epoch 20 | Loss: 8.4627 | Val Loss: 6.3723
#       Stage 1 Epoch 30 | Loss: 8.4606 | Val Loss: 6.3699
#       Stage 1 Epoch 40 | Loss: 8.4565 | Val Loss: 6.3697
#       Stage 1 Epoch 50 | Loss: 8.4543 | Val Loss: 6.3691
#       Stage 1 Epoch 60 | Loss: 8.4540 | Val Loss: 6.3691
#       Stage 1 Epoch 70 | Loss: 8.4545 | Val Loss: 6.3690
#       Stage 1 Epoch 80 | Loss: 8.4539 | Val Loss: 6.3689
#       Stage 1 Epoch 90 | Loss: 8.4539 | Val Loss: 6.3689
#       Stage 1 Epoch 100 | Loss: 8.4539 | Val Loss: 6.3689
#       Stage 1 Epoch 110 | Loss: 8.4538 | Val Loss: 6.3689
#       Stage 1 Epoch 120 | Loss: 8.4544 | Val Loss: 6.3689
#       Stage 1 Epoch 130 | Loss: 8.4537 | Val Loss: 6.3689
#       Stage 1 Epoch 140 | Loss: 8.4538 | Val Loss: 6.3688
#       Stage 1 Epoch 150 | Loss: 8.4538 | Val Loss: 6.3688
#       Stage 1 Epoch 160 | Loss: 8.4538 | Val Loss: 6.3689
#       Stage 1 Epoch 170 | Loss: 8.4538 | Val Loss: 6.3689
#       Stage 1 Epoch 180 | Loss: 8.4537 | Val Loss: 6.3688
#       Stage 1 Epoch 190 | Loss: 8.4537 | Val Loss: 6.3688
#       Stage 1 Epoch 200 | Loss: 8.4540 | Val Loss: 6.3688
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_KAN_OS_CSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.0036 | Val Loss: 0.0048
#       Stage 2 Epoch 20 | Loss: 0.0000 | Val Loss: 0.0000
#       Stage 2 Epoch 30 | Loss: 0.0000 | Val Loss: 0.0000
#       Stage 2 Epoch 40 | Loss: 0.0034 | Val Loss: 0.0001
#       Stage 2 Epoch 50 | Loss: 0.0002 | Val Loss: 0.0001
#       Stage 2 Epoch 60 | Loss: 0.0003 | Val Loss: 0.0018
#       Stage 2 Early stopping at epoch 61
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_KAN_OS_CSL_1024.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9973736047275115, 'prec': 0.7692307692307693, 'rec': 0.9090909090909091, 'f1': 0.8333333333333333}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_KAN_OS_CSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GraphSAGE + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GraphSAGE_KAN_OS_CSL_2025...
#       Stage 1 Epoch 10 | Loss: 8.4941 | Val Loss: 6.4063
#       Stage 1 Epoch 20 | Loss: 8.4638 | Val Loss: 6.3772
#       Stage 1 Epoch 30 | Loss: 8.4610 | Val Loss: 6.3713
#       Stage 1 Epoch 40 | Loss: 8.4560 | Val Loss: 6.3706
#       Stage 1 Epoch 50 | Loss: 8.4554 | Val Loss: 6.3699
#       Stage 1 Epoch 60 | Loss: 8.4564 | Val Loss: 6.3694
#       Stage 1 Epoch 70 | Loss: 8.4546 | Val Loss: 6.3694
#       Stage 1 Epoch 80 | Loss: 8.4542 | Val Loss: 6.3694
#       Stage 1 Epoch 90 | Loss: 8.4547 | Val Loss: 6.3693
#       Stage 1 Epoch 100 | Loss: 8.4540 | Val Loss: 6.3690
#       Stage 1 Epoch 110 | Loss: 8.4540 | Val Loss: 6.3690
#       Stage 1 Epoch 120 | Loss: 8.4556 | Val Loss: 6.3690
#       Stage 1 Epoch 130 | Loss: 8.4539 | Val Loss: 6.3689
#       Stage 1 Epoch 140 | Loss: 8.4544 | Val Loss: 6.3689
#       Stage 1 Epoch 150 | Loss: 8.4540 | Val Loss: 6.3690
#       Stage 1 Epoch 160 | Loss: 8.4545 | Val Loss: 6.3689
#       Stage 1 Epoch 170 | Loss: 8.4539 | Val Loss: 6.3689
#       Stage 1 Epoch 180 | Loss: 8.4539 | Val Loss: 6.3689
#       Stage 1 Epoch 190 | Loss: 8.4538 | Val Loss: 6.3689
#       Stage 1 Epoch 200 | Loss: 8.4539 | Val Loss: 6.3689
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_KAN_OS_CSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.0043 | Val Loss: 0.0049
#       Stage 2 Epoch 20 | Loss: 0.0000 | Val Loss: 0.0000
#       Stage 2 Epoch 30 | Loss: 0.0001 | Val Loss: 0.0000
#       Stage 2 Epoch 40 | Loss: 0.0004 | Val Loss: 0.0001
#       Stage 2 Epoch 50 | Loss: 0.0008 | Val Loss: 0.0002
#       Stage 2 Epoch 60 | Loss: 0.0004 | Val Loss: 0.0003
#       Stage 2 Early stopping at epoch 63
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_KAN_OS_CSL_2025.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9986868023637557, 'prec': 0.9090909090909091, 'rec': 0.9090909090909091, 'f1': 0.9090909090909091}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_KAN_OS_CSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/wacgan-ethereum-balanced/graph_data/wacgan_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GIN \
--classifier KAN \
--epochs_stage1 200 --epochs_stage2 200 --patience 50 --use_oversampling --output_file --use_csl --csl_weight 0.2
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/wacgan-ethereum-balanced/graph_data/wacgan_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 7863 nodes and 26082 edges
# Merge Info: 7613 overlapping nodes (anchors), 250 new synthetic nodes.
# Num nodes 7863 | Features: torch.Size([7863, 27]) | Fraud Train: 289 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5731 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7863, Edges: 26082, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 200, Patience: 50
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GIN + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GIN_KAN_OS_CSL_0...
#       Stage 1 Epoch 10 | Loss: 8.4956 | Val Loss: 6.3770
#       Stage 1 Epoch 20 | Loss: 8.4664 | Val Loss: 6.3722
#       Stage 1 Epoch 30 | Loss: 8.4625 | Val Loss: 6.3701
#       Stage 1 Epoch 40 | Loss: 8.4629 | Val Loss: 6.3704
#       Stage 1 Epoch 50 | Loss: 8.4582 | Val Loss: 6.3700
#       Stage 1 Epoch 60 | Loss: 8.4603 | Val Loss: 6.3696
#       Stage 1 Epoch 70 | Loss: 8.4586 | Val Loss: 6.3696
#       Stage 1 Epoch 80 | Loss: 8.4569 | Val Loss: 6.3698
#       Stage 1 Epoch 90 | Loss: 8.4588 | Val Loss: 6.3698
#       Stage 1 Epoch 100 | Loss: 8.4594 | Val Loss: 6.3699
#       Stage 1 Epoch 110 | Loss: 8.4565 | Val Loss: 6.3699
#       Stage 1 Epoch 120 | Loss: 8.4571 | Val Loss: 6.3705
#       Stage 1 Epoch 130 | Loss: 8.4581 | Val Loss: 6.3703
#       Stage 1 Epoch 140 | Loss: 8.4580 | Val Loss: 6.3700
#       Stage 1 Epoch 150 | Loss: 8.4597 | Val Loss: 6.3698
#       Stage 1 Epoch 160 | Loss: 8.4583 | Val Loss: 6.3702
#       Stage 1 Epoch 170 | Loss: 8.4571 | Val Loss: 6.3697
#       Stage 1 Epoch 180 | Loss: 8.4563 | Val Loss: 6.3699
#       Stage 1 Epoch 190 | Loss: 8.4559 | Val Loss: 6.3703
#       Stage 1 Epoch 200 | Loss: 8.4559 | Val Loss: 6.3701
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_KAN_OS_CSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0103 | Val Loss: 0.0018
#       Stage 2 Epoch 20 | Loss: 0.0068 | Val Loss: 0.0005
#       Stage 2 Epoch 30 | Loss: 0.0029 | Val Loss: 0.0005
#       Stage 2 Epoch 40 | Loss: 0.0017 | Val Loss: 0.0006
#       Stage 2 Epoch 50 | Loss: 0.0019 | Val Loss: 0.0010
#       Stage 2 Epoch 60 | Loss: 0.0022 | Val Loss: 0.0016
#       Stage 2 Early stopping at epoch 67
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_KAN_OS_CSL_0.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9947472094550229, 'prec': 1.0, 'rec': 0.2727272727272727, 'f1': 0.42857142857142855}
# Results ready to be saved to results/eval_first_graph_GIN_KAN_OS_CSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GIN + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GIN_KAN_OS_CSL_42...
#       Stage 1 Epoch 10 | Loss: 8.5026 | Val Loss: 6.3758
#       Stage 1 Epoch 20 | Loss: 8.4600 | Val Loss: 6.3708
#       Stage 1 Epoch 30 | Loss: 8.4596 | Val Loss: 6.3709
#       Stage 1 Epoch 40 | Loss: 8.4578 | Val Loss: 6.3719
#       Stage 1 Epoch 50 | Loss: 8.4577 | Val Loss: 6.3708
#       Stage 1 Epoch 60 | Loss: 8.4586 | Val Loss: 6.3702
#       Stage 1 Epoch 70 | Loss: 8.4567 | Val Loss: 6.3700
#       Stage 1 Epoch 80 | Loss: 8.4585 | Val Loss: 6.3696
#       Stage 1 Epoch 90 | Loss: 8.4579 | Val Loss: 6.3696
#       Stage 1 Epoch 100 | Loss: 8.4572 | Val Loss: 6.3698
#       Stage 1 Epoch 110 | Loss: 8.4568 | Val Loss: 6.3699
#       Stage 1 Epoch 120 | Loss: 8.4580 | Val Loss: 6.3696
#       Stage 1 Epoch 130 | Loss: 8.4562 | Val Loss: 6.3697
#       Stage 1 Epoch 140 | Loss: 8.4563 | Val Loss: 6.3700
#       Stage 1 Epoch 150 | Loss: 8.4606 | Val Loss: 6.3700
#       Stage 1 Epoch 160 | Loss: 8.4565 | Val Loss: 6.3697
#       Stage 1 Epoch 170 | Loss: 8.4560 | Val Loss: 6.3694
#       Stage 1 Epoch 180 | Loss: 8.4573 | Val Loss: 6.3695
#       Stage 1 Epoch 190 | Loss: 8.4560 | Val Loss: 6.3695
#       Stage 1 Epoch 200 | Loss: 8.4561 | Val Loss: 6.3694
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_KAN_OS_CSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0150 | Val Loss: 0.0046
#       Stage 2 Epoch 20 | Loss: 0.0036 | Val Loss: 0.0006
#       Stage 2 Epoch 30 | Loss: 0.0020 | Val Loss: 0.0006
#       Stage 2 Epoch 40 | Loss: 0.0019 | Val Loss: 0.0009
#       Stage 2 Epoch 50 | Loss: 0.0020 | Val Loss: 0.0014
#       Stage 2 Epoch 60 | Loss: 0.0019 | Val Loss: 0.0014
#       Stage 2 Early stopping at epoch 61
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_KAN_OS_CSL_42.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9934340118187788, 'prec': 1.0, 'rec': 0.09090909090909091, 'f1': 0.16666666666666669}
# Results ready to be saved to results/eval_first_graph_GIN_KAN_OS_CSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GIN + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GIN_KAN_OS_CSL_101...
#       Stage 1 Epoch 10 | Loss: 8.5146 | Val Loss: 6.3816
#       Stage 1 Epoch 20 | Loss: 8.4732 | Val Loss: 6.3765
#       Stage 1 Epoch 30 | Loss: 8.4605 | Val Loss: 6.3702
#       Stage 1 Epoch 40 | Loss: 8.4617 | Val Loss: 6.3694
#       Stage 1 Epoch 50 | Loss: 8.4583 | Val Loss: 6.3697
#       Stage 1 Epoch 60 | Loss: 8.4578 | Val Loss: 6.3700
#       Stage 1 Epoch 70 | Loss: 8.4585 | Val Loss: 6.3700
#       Stage 1 Epoch 80 | Loss: 8.4573 | Val Loss: 6.3699
#       Stage 1 Epoch 90 | Loss: 8.4576 | Val Loss: 6.3696
#       Stage 1 Epoch 100 | Loss: 8.4561 | Val Loss: 6.3696
#       Stage 1 Epoch 110 | Loss: 8.4578 | Val Loss: 6.3697
#       Stage 1 Epoch 120 | Loss: 8.4634 | Val Loss: 6.3699
#       Stage 1 Epoch 130 | Loss: 8.4602 | Val Loss: 6.3701
#       Stage 1 Epoch 140 | Loss: 8.4575 | Val Loss: 6.3698
#       Stage 1 Epoch 150 | Loss: 8.4573 | Val Loss: 6.3695
#       Stage 1 Epoch 160 | Loss: 8.4561 | Val Loss: 6.3695
#       Stage 1 Epoch 170 | Loss: 8.4562 | Val Loss: 6.3697
#       Stage 1 Epoch 180 | Loss: 8.4561 | Val Loss: 6.3697
#       Stage 1 Epoch 190 | Loss: 8.4562 | Val Loss: 6.3697
#       Stage 1 Epoch 200 | Loss: 8.4563 | Val Loss: 6.3707
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_KAN_OS_CSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0199 | Val Loss: 0.0056
#       Stage 2 Epoch 20 | Loss: 0.0151 | Val Loss: 0.0028
#       Stage 2 Epoch 30 | Loss: 0.0085 | Val Loss: 0.0035
#       Stage 2 Epoch 40 | Loss: 0.0068 | Val Loss: 0.0009
#       Stage 2 Epoch 50 | Loss: 0.0048 | Val Loss: 0.0019
#       Stage 2 Epoch 60 | Loss: 0.0042 | Val Loss: 0.0018
#       Stage 2 Early stopping at epoch 62
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_KAN_OS_CSL_101.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9934340118187788, 'prec': 1.0, 'rec': 0.09090909090909091, 'f1': 0.16666666666666669}
# Results ready to be saved to results/eval_first_graph_GIN_KAN_OS_CSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GIN + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GIN_KAN_OS_CSL_1024...
#       Stage 1 Epoch 10 | Loss: 8.4818 | Val Loss: 6.3730
#       Stage 1 Epoch 20 | Loss: 8.4648 | Val Loss: 6.3699
#       Stage 1 Epoch 30 | Loss: 8.4598 | Val Loss: 6.3709
#       Stage 1 Epoch 40 | Loss: 8.4629 | Val Loss: 6.3703
#       Stage 1 Epoch 50 | Loss: 8.4578 | Val Loss: 6.3705
#       Stage 1 Epoch 60 | Loss: 8.4582 | Val Loss: 6.3700
#       Stage 1 Epoch 70 | Loss: 8.4595 | Val Loss: 6.3698
#       Stage 1 Epoch 80 | Loss: 8.4576 | Val Loss: 6.3703
#       Stage 1 Epoch 90 | Loss: 8.4595 | Val Loss: 6.3705
#       Stage 1 Epoch 100 | Loss: 8.4577 | Val Loss: 6.3703
#       Stage 1 Epoch 110 | Loss: 8.4578 | Val Loss: 6.3699
#       Stage 1 Epoch 120 | Loss: 8.4576 | Val Loss: 6.3698
#       Stage 1 Epoch 130 | Loss: 8.4563 | Val Loss: 6.3697
#       Stage 1 Epoch 140 | Loss: 8.4564 | Val Loss: 6.3696
#       Stage 1 Epoch 150 | Loss: 8.4602 | Val Loss: 6.3702
#       Stage 1 Epoch 160 | Loss: 8.4581 | Val Loss: 6.3701
#       Stage 1 Epoch 170 | Loss: 8.4570 | Val Loss: 6.3698
#       Stage 1 Epoch 180 | Loss: 8.4558 | Val Loss: 6.3696
#       Stage 1 Epoch 190 | Loss: 8.4557 | Val Loss: 6.3698
#       Stage 1 Epoch 200 | Loss: 8.4560 | Val Loss: 6.3699
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_KAN_OS_CSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.0177 | Val Loss: 0.0016
#       Stage 2 Epoch 20 | Loss: 0.0138 | Val Loss: 0.0028
#       Stage 2 Epoch 30 | Loss: 0.0051 | Val Loss: 0.0013
#       Stage 2 Epoch 40 | Loss: 0.0033 | Val Loss: 0.0008
#       Stage 2 Epoch 50 | Loss: 0.0032 | Val Loss: 0.0009
#       Stage 2 Epoch 60 | Loss: 0.0026 | Val Loss: 0.0009
#       Stage 2 Epoch 70 | Loss: 0.0060 | Val Loss: 0.0024
#       Stage 2 Early stopping at epoch 71
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_KAN_OS_CSL_1024.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9967170059093894, 'prec': 1.0, 'rec': 0.5454545454545454, 'f1': 0.7058823529411764}
# Results ready to be saved to results/eval_first_graph_GIN_KAN_OS_CSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GIN + KAN...
#    [STAGE 1] CSL Pre-training for first_graph_GIN_KAN_OS_CSL_2025...
#       Stage 1 Epoch 10 | Loss: 8.5072 | Val Loss: 6.3848
#       Stage 1 Epoch 20 | Loss: 8.4686 | Val Loss: 6.3725
#       Stage 1 Epoch 30 | Loss: 8.4603 | Val Loss: 6.3714
#       Stage 1 Epoch 40 | Loss: 8.4616 | Val Loss: 6.3704
#       Stage 1 Epoch 50 | Loss: 8.4596 | Val Loss: 6.3702
#       Stage 1 Epoch 60 | Loss: 8.4586 | Val Loss: 6.3704
#       Stage 1 Epoch 70 | Loss: 8.4573 | Val Loss: 6.3701
#       Stage 1 Epoch 80 | Loss: 8.4563 | Val Loss: 6.3696
#       Stage 1 Epoch 90 | Loss: 8.4587 | Val Loss: 6.3696
#       Stage 1 Epoch 100 | Loss: 8.4576 | Val Loss: 6.3697
#       Stage 1 Epoch 110 | Loss: 8.4597 | Val Loss: 6.3700
#       Stage 1 Epoch 120 | Loss: 8.4568 | Val Loss: 6.3699
#       Stage 1 Epoch 130 | Loss: 8.4570 | Val Loss: 6.3700
#       Stage 1 Epoch 140 | Loss: 8.4566 | Val Loss: 6.3698
#       Stage 1 Epoch 150 | Loss: 8.4562 | Val Loss: 6.3696
#       Stage 1 Epoch 160 | Loss: 8.4561 | Val Loss: 6.3696
#       Stage 1 Epoch 170 | Loss: 8.4581 | Val Loss: 6.3700
#       Stage 1 Epoch 180 | Loss: 8.4562 | Val Loss: 6.3700
#       Stage 1 Epoch 190 | Loss: 8.4568 | Val Loss: 6.3699
#       Stage 1 Epoch 200 | Loss: 8.4561 | Val Loss: 6.3698
#       Stage 1 Completed. Best model saved.
#       Loading best Encoder from Stage 1...
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_KAN_OS_CSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.0120 | Val Loss: 0.0031
#       Stage 2 Epoch 20 | Loss: 0.0070 | Val Loss: 0.0001
#       Stage 2 Epoch 30 | Loss: 0.0022 | Val Loss: 0.0010
#       Stage 2 Epoch 40 | Loss: 0.0048 | Val Loss: 0.0008
#       Stage 2 Epoch 50 | Loss: 0.0023 | Val Loss: 0.0009
#       Stage 2 Epoch 60 | Loss: 0.0023 | Val Loss: 0.0012
#       Stage 2 Early stopping at epoch 68
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_KAN_OS_CSL_2025.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: KAN, Oversample: True, CSL: True
# {'acc': 0.9947472094550229, 'prec': 1.0, 'rec': 0.2727272727272727, 'f1': 0.42857142857142855}
# Results ready to be saved to results/eval_first_graph_GIN_KAN_OS_CSL_2025.json

# %%
# !cd /kaggle/working/results
# !zip -r G1-KAN-WACGAN-CSL.zip /kaggle/working/results/
# Out:
#   adding: kaggle/working/results/ (stored 0%)
#   adding: kaggle/working/results/pred_first_graph_GAT_KAN_OS_CSL_0.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_KAN_OS_CSL_101.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_KAN_OS_CSL_101.json (deflated 48%)
#   adding: kaggle/working/results/pred_first_graph_GIN_KAN_OS_CSL_1024.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GAT_KAN_OS_CSL_2025.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_KAN_OS_CSL_42.json (deflated 39%)
#   adding: kaggle/working/results/pred_first_graph_GAT_KAN_OS_CSL_42.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GAT_KAN_OS_CSL_42.json (deflated 37%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_KAN_OS_CSL_0.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GCN_KAN_OS_CSL_101.json (deflated 41%)
#   adding: kaggle/working/results/eval_first_graph_GAT_KAN_OS_CSL_1024.json (deflated 37%)
#   adding: kaggle/working/results/eval_first_graph_GIN_KAN_OS_CSL_42.json (deflated 41%)
#   adding: kaggle/working/results/pred_first_graph_GIN_KAN_OS_CSL_42.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GAT_KAN_OS_CSL_101.json (deflated 47%)
#   adding: kaggle/working/results/eval_first_graph_GAT_KAN_OS_CSL_0.json (deflated 47%)
#   adding: kaggle/working/results/pred_first_graph_GAT_KAN_OS_CSL_1024.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GIN_KAN_OS_CSL_0.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GCN_KAN_OS_CSL_101.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GAT_KAN_OS_CSL_2025.json (deflated 39%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_KAN_OS_CSL_1024.json (deflated 42%)
#   adding: kaggle/working/results/eval_first_graph_GIN_KAN_OS_CSL_1024.json (deflated 37%)
#   adding: kaggle/working/results/eval_first_graph_GIN_KAN_OS_CSL_101.json (deflated 41%)
#   adding: kaggle/working/results/eval_first_graph_GCN_KAN_OS_CSL_1024.json (deflated 41%)
#   adding: kaggle/working/results/pred_first_graph_GIN_KAN_OS_CSL_101.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_KAN_OS_CSL_1024.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GCN_KAN_OS_CSL_1024.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_KAN_OS_CSL_0.json (deflated 39%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_KAN_OS_CSL_2025.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GCN_KAN_OS_CSL_0.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GCN_KAN_OS_CSL_42.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GIN_KAN_OS_CSL_0.json (deflated 40%)
#   adding: kaggle/working/results/eval_first_graph_GCN_KAN_OS_CSL_0.json (deflated 45%)
#   adding: kaggle/working/results/pred_first_graph_GIN_KAN_OS_CSL_2025.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GAT_KAN_OS_CSL_101.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GCN_KAN_OS_CSL_2025.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GCN_KAN_OS_CSL_2025.json (deflated 47%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_KAN_OS_CSL_42.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GIN_KAN_OS_CSL_2025.json (deflated 40%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_KAN_OS_CSL_2025.json (deflated 48%)
#   adding: kaggle/working/results/eval_first_graph_GCN_KAN_OS_CSL_42.json (deflated 40%)
