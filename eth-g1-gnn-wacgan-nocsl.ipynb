# %%
# !pip install torch_geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 31.2 MB/s eta 0:00:00
# ...

# %%
# !git clone https://agusth24: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@github.com/agusth24/ethereum-fraud-detection.git
# Out:
# Cloning into 'ethereum-fraud-detection'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 51 (delta 23), reused 45 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (51/51), 14.72 KiB | 4.91 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/wacgan-ethereum-balanced/graph_data/wacgan_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GCN \
--classifier GCN \
--epochs_stage2 1000 --patience 100 --use_oversampling --output_file
# Out:
# ...
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/wacgan-ethereum-balanced/graph_data/wacgan_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 7863 nodes and 26082 edges
# Merge Info: 7613 overlapping nodes (anchors), 250 new synthetic nodes.
# Num nodes 7863 | Features: torch.Size([7863, 27]) | Fraud Train: 289 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5731 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7863, Edges: 26082, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 1000, Patience: 100
# ...
#
# [RUN 1/5] Setting Seed: 0
# Initializing GCN + GCN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_GCN_OS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0589 | Val Loss: 0.0614
# ...

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/wacgan-ethereum-balanced/graph_data/wacgan_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GAT \
--classifier GAT \
--epochs_stage2 1000 --patience 100 --use_oversampling --output_file
# Out:
# ...
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/wacgan-ethereum-balanced/graph_data/wacgan_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 7863 nodes and 26082 edges
# Merge Info: 7613 overlapping nodes (anchors), 250 new synthetic nodes.
# Num nodes 7863 | Features: torch.Size([7863, 27]) | Fraud Train: 289 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5731 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7863, Edges: 26082, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 1000, Patience: 100
# ...
#
# [RUN 1/5] Setting Seed: 0
# Initializing GAT + GAT...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_GAT_OS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.1314 | Val Loss: 0.1394
# ...

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/wacgan-ethereum-balanced/graph_data/wacgan_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GraphSAGE \
--classifier GraphSAGE \
--epochs_stage2 1000 --patience 100 --use_oversampling --output_file
# Out:
# ...
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/wacgan-ethereum-balanced/graph_data/wacgan_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 7863 nodes and 26082 edges
# Merge Info: 7613 overlapping nodes (anchors), 250 new synthetic nodes.
# Num nodes 7863 | Features: torch.Size([7863, 27]) | Fraud Train: 289 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5731 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7863, Edges: 26082, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 1000, Patience: 100
# ...
#
# [RUN 1/5] Setting Seed: 0
# Initializing GraphSAGE + GraphSAGE...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_GraphSAGE_OS_NoCSL_0...
# ...

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/wacgan-ethereum-balanced/graph_data/wacgan_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GIN \
--classifier GIN \
--epochs_stage2 1000 --patience 100 --use_oversampling --output_file
# Out:
# ...
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/wacgan-ethereum-balanced/graph_data/wacgan_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 7863 nodes and 26082 edges
# Merge Info: 7613 overlapping nodes (anchors), 250 new synthetic nodes.
# Num nodes 7863 | Features: torch.Size([7863, 27]) | Fraud Train: 289 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5731 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7863, Edges: 26082, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 1000, Patience: 100
# ...
#
# [RUN 1/5] Setting Seed: 0
# Initializing GIN + GIN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_GIN_OS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0918 | Val Loss: 0.1098
# ...

# %%
# !cd /kaggle/working/results
# !zip -r G1-GNN-WACGAN-NoCSL.zip /kaggle/working/results/
# Out:
#   adding: kaggle/working/results/ (stored 0%)
#   adding: kaggle/working/results/eval_first_graph_GAT_GAT_OS_NoCSL_101.json (deflated 39%)
#   adding: kaggle/working/results/pred_first_graph_GCN_GCN_OS_NoCSL_42.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_GraphSAGE_OS_NoCSL_0.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GIN_GIN_OS_NoCSL_0.json (deflated 40%)
#   adding: kaggle/working/results/pred_first_graph_GAT_GAT_OS_NoCSL_2025.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_GraphSAGE_OS_NoCSL_0.json (deflated 41%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_GraphSAGE_OS_NoCSL_101.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GCN_GCN_OS_NoCSL_1024.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GCN_GCN_OS_NoCSL_2025.csv (deflated 98%)
# ...
