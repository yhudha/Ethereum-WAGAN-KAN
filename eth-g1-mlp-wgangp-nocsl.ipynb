# %%
# !pip install torch_geometric
# !pip install git+https://github.com/Blealtan/efficient-kan.git
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.13.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2025.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (7.1.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2025.10.5)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal>=1.4.0->aiohttp->torch_geometric) (4.15.0)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torch_geometric) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torch_geometric) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torch_geometric) (2024.2.0)
# Downloading torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.4 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.7.0
# Collecting git+https://github.com/Blealtan/efficient-kan.git
#   Cloning https://github.com/Blealtan/efficient-kan.git to /tmp/pip-req-build-3wxq6q8v
#   Running command git clone --filter=blob:none --quiet https://github.com/Blealtan/efficient-kan.git /tmp/pip-req-build-3wxq6q8v
#   Resolved https://github.com/Blealtan/efficient-kan.git to commit 7b6ce1c87f18c8bc90c208f6b494042344216b11
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (2.6.0+cu124)
# Requirement already satisfied: pytest>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (8.4.1)
# Requirement already satisfied: tqdm>=4.66.2 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (4.67.1)
# Requirement already satisfied: torchvision>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (0.21.0+cu124)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (2.1.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (25.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (2.19.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (2025.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.3.0->efficient-kan==0.1.0) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.18.0->efficient-kan==0.1.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.18.0->efficient-kan==0.1.0) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.3.0->efficient-kan==0.1.0) (3.0.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2.4.1)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 109.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 34.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 9.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 9.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 96.5 MB/s eta 0:00:00
# Building wheels for collected packages: efficient-kan
#   Building wheel for efficient-kan (pyproject.toml) ... done
#   Created wheel for efficient-kan: filename=efficient_kan-0.1.0-py3-none-any.whl size=5981 sha256=3fadb37365bda971d6bcb716e5ecf58aca9c70ee79e32324453796857b325548
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9epddyti/wheels/da/a3/b4/30b3e3df2edaded3c87227cb9faea5878f18ec03e1c2137839
# Successfully built efficient-kan
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, efficient-kan
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed efficient-kan-0.1.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !git clone https://agusth24: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@github.com/agusth24/ethereum-fraud-detection.git
# Out:
# Cloning into 'ethereum-fraud-detection'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 51 (delta 23), reused 45 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (51/51), 14.72 KiB | 430.00 KiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/wacgan-ethereum-balanced/graph_data/wgangp_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GCN \
--classifier MLP \
--epochs_stage2 1000 --patience 100 --use_oversampling --output_file
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/wacgan-ethereum-balanced/graph_data/wgangp_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 7713 nodes and 24896 edges
# Merge Info: 7613 overlapping nodes (anchors), 100 new synthetic nodes.
# Num nodes 7713 | Features: torch.Size([7713, 27]) | Fraud Train: 139 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5581 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7713, Edges: 24896, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 1000, Patience: 100
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GCN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_MLP_OS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0223 | Val Loss: 0.0616
#       Stage 2 Epoch 20 | Loss: 0.0188 | Val Loss: 0.0676
#       Stage 2 Epoch 30 | Loss: 0.0125 | Val Loss: 0.0356
#       Stage 2 Epoch 40 | Loss: 0.0053 | Val Loss: 0.0176
#       Stage 2 Epoch 50 | Loss: 0.0053 | Val Loss: 0.0155
#       Stage 2 Epoch 60 | Loss: 0.0047 | Val Loss: 0.0176
#       Stage 2 Epoch 70 | Loss: 0.0057 | Val Loss: 0.0164
#       Stage 2 Epoch 80 | Loss: 0.0038 | Val Loss: 0.0199
#       Stage 2 Epoch 90 | Loss: 0.0043 | Val Loss: 0.0221
#       Stage 2 Epoch 100 | Loss: 0.0045 | Val Loss: 0.0151
#       Stage 2 Epoch 110 | Loss: 0.0052 | Val Loss: 0.0194
#       Stage 2 Epoch 120 | Loss: 0.0038 | Val Loss: 0.0197
#       Stage 2 Epoch 130 | Loss: 0.0044 | Val Loss: 0.0287
#       Stage 2 Epoch 140 | Loss: 0.0048 | Val Loss: 0.0352
#       Stage 2 Early stopping at epoch 143
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_MLP_OS_NoCSL_0.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9973736047275115, 'prec': 0.7333333333333333, 'rec': 1.0, 'f1': 0.846153846153846}
# Results ready to be saved to results/eval_first_graph_GCN_MLP_OS_NoCSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GCN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_MLP_OS_NoCSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0280 | Val Loss: 0.0509
#       Stage 2 Epoch 20 | Loss: 0.0255 | Val Loss: 0.0488
#       Stage 2 Epoch 30 | Loss: 0.0082 | Val Loss: 0.0298
#       Stage 2 Epoch 40 | Loss: 0.0065 | Val Loss: 0.0217
#       Stage 2 Epoch 50 | Loss: 0.0054 | Val Loss: 0.0175
#       Stage 2 Epoch 60 | Loss: 0.0045 | Val Loss: 0.0125
#       Stage 2 Epoch 70 | Loss: 0.0043 | Val Loss: 0.0116
#       Stage 2 Epoch 80 | Loss: 0.0044 | Val Loss: 0.0166
#       Stage 2 Epoch 90 | Loss: 0.0042 | Val Loss: 0.0190
#       Stage 2 Epoch 100 | Loss: 0.0041 | Val Loss: 0.0194
#       Stage 2 Epoch 110 | Loss: 0.0046 | Val Loss: 0.0229
#       Stage 2 Epoch 120 | Loss: 0.0039 | Val Loss: 0.0249
#       Stage 2 Epoch 130 | Loss: 0.0042 | Val Loss: 0.0256
#       Stage 2 Epoch 140 | Loss: 0.0042 | Val Loss: 0.0194
#       Stage 2 Epoch 150 | Loss: 0.0040 | Val Loss: 0.0248
#       Stage 2 Early stopping at epoch 160
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_MLP_OS_NoCSL_42.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9967170059093894, 'prec': 0.7142857142857143, 'rec': 0.9090909090909091, 'f1': 0.8}
# Results ready to be saved to results/eval_first_graph_GCN_MLP_OS_NoCSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GCN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_MLP_OS_NoCSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0268 | Val Loss: 0.0537
#       Stage 2 Epoch 20 | Loss: 0.0205 | Val Loss: 0.0537
#       Stage 2 Epoch 30 | Loss: 0.0132 | Val Loss: 0.0376
#       Stage 2 Epoch 40 | Loss: 0.0051 | Val Loss: 0.0237
#       Stage 2 Epoch 50 | Loss: 0.0064 | Val Loss: 0.0168
#       Stage 2 Epoch 60 | Loss: 0.0043 | Val Loss: 0.0191
#       Stage 2 Epoch 70 | Loss: 0.0042 | Val Loss: 0.0131
#       Stage 2 Epoch 80 | Loss: 0.0046 | Val Loss: 0.0145
#       Stage 2 Epoch 90 | Loss: 0.0048 | Val Loss: 0.0233
#       Stage 2 Epoch 100 | Loss: 0.0053 | Val Loss: 0.0154
#       Stage 2 Epoch 110 | Loss: 0.0048 | Val Loss: 0.0202
#       Stage 2 Epoch 120 | Loss: 0.0049 | Val Loss: 0.0178
#       Stage 2 Epoch 130 | Loss: 0.0043 | Val Loss: 0.0224
#       Stage 2 Epoch 140 | Loss: 0.0044 | Val Loss: 0.0189
#       Stage 2 Epoch 150 | Loss: 0.0048 | Val Loss: 0.0181
#       Stage 2 Epoch 160 | Loss: 0.0040 | Val Loss: 0.0251
#       Stage 2 Early stopping at epoch 166
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_MLP_OS_NoCSL_101.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9967170059093894, 'prec': 0.7142857142857143, 'rec': 0.9090909090909091, 'f1': 0.8}
# Results ready to be saved to results/eval_first_graph_GCN_MLP_OS_NoCSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GCN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_MLP_OS_NoCSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.0234 | Val Loss: 0.0576
#       Stage 2 Epoch 20 | Loss: 0.0188 | Val Loss: 0.0317
#       Stage 2 Epoch 30 | Loss: 0.0093 | Val Loss: 0.0233
#       Stage 2 Epoch 40 | Loss: 0.0056 | Val Loss: 0.0197
#       Stage 2 Epoch 50 | Loss: 0.0042 | Val Loss: 0.0161
#       Stage 2 Epoch 60 | Loss: 0.0046 | Val Loss: 0.0167
#       Stage 2 Epoch 70 | Loss: 0.0039 | Val Loss: 0.0226
#       Stage 2 Epoch 80 | Loss: 0.0034 | Val Loss: 0.0239
#       Stage 2 Epoch 90 | Loss: 0.0036 | Val Loss: 0.0221
#       Stage 2 Epoch 100 | Loss: 0.0038 | Val Loss: 0.0232
#       Stage 2 Epoch 110 | Loss: 0.0050 | Val Loss: 0.0178
#       Stage 2 Epoch 120 | Loss: 0.0045 | Val Loss: 0.0164
#       Stage 2 Epoch 130 | Loss: 0.0045 | Val Loss: 0.0262
#       Stage 2 Epoch 140 | Loss: 0.0043 | Val Loss: 0.0228
#       Stage 2 Early stopping at epoch 149
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_MLP_OS_NoCSL_1024.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9967170059093894, 'prec': 0.7142857142857143, 'rec': 0.9090909090909091, 'f1': 0.8}
# Results ready to be saved to results/eval_first_graph_GCN_MLP_OS_NoCSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GCN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_MLP_OS_NoCSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.0207 | Val Loss: 0.0485
#       Stage 2 Epoch 20 | Loss: 0.0145 | Val Loss: 0.0311
#       Stage 2 Epoch 30 | Loss: 0.0078 | Val Loss: 0.0310
#       Stage 2 Epoch 40 | Loss: 0.0047 | Val Loss: 0.0207
#       Stage 2 Epoch 50 | Loss: 0.0051 | Val Loss: 0.0217
#       Stage 2 Epoch 60 | Loss: 0.0051 | Val Loss: 0.0140
#       Stage 2 Epoch 70 | Loss: 0.0043 | Val Loss: 0.0129
#       Stage 2 Epoch 80 | Loss: 0.0050 | Val Loss: 0.0132
#       Stage 2 Epoch 90 | Loss: 0.0033 | Val Loss: 0.0200
#       Stage 2 Epoch 100 | Loss: 0.0042 | Val Loss: 0.0227
#       Stage 2 Epoch 110 | Loss: 0.0041 | Val Loss: 0.0224
#       Stage 2 Epoch 120 | Loss: 0.0038 | Val Loss: 0.0225
#       Stage 2 Epoch 130 | Loss: 0.0046 | Val Loss: 0.0215
#       Stage 2 Epoch 140 | Loss: 0.0049 | Val Loss: 0.0233
#       Stage 2 Early stopping at epoch 141
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_MLP_OS_NoCSL_2025.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9967170059093894, 'prec': 0.7142857142857143, 'rec': 0.9090909090909091, 'f1': 0.8}
# Results ready to be saved to results/eval_first_graph_GCN_MLP_OS_NoCSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/wacgan-ethereum-balanced/graph_data/wgangp_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GAT \
--classifier MLP \
--epochs_stage2 1000 --patience 100 --use_oversampling --output_file
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/wacgan-ethereum-balanced/graph_data/wgangp_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 7713 nodes and 24896 edges
# Merge Info: 7613 overlapping nodes (anchors), 100 new synthetic nodes.
# Num nodes 7713 | Features: torch.Size([7713, 27]) | Fraud Train: 139 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5581 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7713, Edges: 24896, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 1000, Patience: 100
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GAT + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_MLP_OS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0598 | Val Loss: 0.0371
#       Stage 2 Epoch 20 | Loss: 0.0315 | Val Loss: 0.0238
#       Stage 2 Epoch 30 | Loss: 0.0208 | Val Loss: 0.0174
#       Stage 2 Epoch 40 | Loss: 0.0230 | Val Loss: 0.0225
#       Stage 2 Epoch 50 | Loss: 0.0179 | Val Loss: 0.0348
#       Stage 2 Epoch 60 | Loss: 0.0158 | Val Loss: 0.0259
#       Stage 2 Epoch 70 | Loss: 0.0193 | Val Loss: 0.0215
#       Stage 2 Epoch 80 | Loss: 0.0139 | Val Loss: 0.0406
#       Stage 2 Epoch 90 | Loss: 0.0194 | Val Loss: 0.0181
#       Stage 2 Epoch 100 | Loss: 0.0176 | Val Loss: 0.0362
#       Stage 2 Epoch 110 | Loss: 0.0187 | Val Loss: 0.0191
#       Stage 2 Epoch 120 | Loss: 0.0193 | Val Loss: 0.0287
#       Stage 2 Epoch 130 | Loss: 0.0182 | Val Loss: 0.0328
#       Stage 2 Epoch 140 | Loss: 0.0149 | Val Loss: 0.0220
#       Stage 2 Epoch 150 | Loss: 0.0209 | Val Loss: 0.0156
#       Stage 2 Epoch 160 | Loss: 0.0200 | Val Loss: 0.0224
#       Stage 2 Early stopping at epoch 167
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_MLP_OS_NoCSL_0.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9967170059093894, 'prec': 0.75, 'rec': 0.8181818181818182, 'f1': 0.7826086956521738}
# Results ready to be saved to results/eval_first_graph_GAT_MLP_OS_NoCSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GAT + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_MLP_OS_NoCSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0722 | Val Loss: 0.0373
#       Stage 2 Epoch 20 | Loss: 0.0370 | Val Loss: 0.0601
#       Stage 2 Epoch 30 | Loss: 0.0319 | Val Loss: 0.0239
#       Stage 2 Epoch 40 | Loss: 0.0296 | Val Loss: 0.0203
#       Stage 2 Epoch 50 | Loss: 0.0234 | Val Loss: 0.0236
#       Stage 2 Epoch 60 | Loss: 0.0219 | Val Loss: 0.0182
#       Stage 2 Epoch 70 | Loss: 0.0200 | Val Loss: 0.0397
#       Stage 2 Epoch 80 | Loss: 0.0212 | Val Loss: 0.0128
#       Stage 2 Epoch 90 | Loss: 0.0238 | Val Loss: 0.0208
#       Stage 2 Epoch 100 | Loss: 0.0208 | Val Loss: 0.0263
#       Stage 2 Epoch 110 | Loss: 0.0213 | Val Loss: 0.0251
#       Stage 2 Epoch 120 | Loss: 0.0176 | Val Loss: 0.0189
#       Stage 2 Epoch 130 | Loss: 0.0196 | Val Loss: 0.0258
#       Stage 2 Epoch 140 | Loss: 0.0182 | Val Loss: 0.0206
#       Stage 2 Epoch 150 | Loss: 0.0183 | Val Loss: 0.0318
#       Stage 2 Epoch 160 | Loss: 0.0160 | Val Loss: 0.0281
#       Stage 2 Epoch 170 | Loss: 0.0209 | Val Loss: 0.0229
#       Stage 2 Epoch 180 | Loss: 0.0139 | Val Loss: 0.0196
#       Stage 2 Epoch 190 | Loss: 0.0215 | Val Loss: 0.0289
#       Stage 2 Epoch 200 | Loss: 0.0168 | Val Loss: 0.0337
#       Stage 2 Epoch 210 | Loss: 0.0123 | Val Loss: 0.0184
#       Stage 2 Epoch 220 | Loss: 0.0195 | Val Loss: 0.0214
#       Stage 2 Epoch 230 | Loss: 0.0151 | Val Loss: 0.0262
#       Stage 2 Early stopping at epoch 235
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_MLP_OS_NoCSL_42.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9960604070912672, 'prec': 0.6923076923076923, 'rec': 0.8181818181818182, 'f1': 0.7500000000000001}
# Results ready to be saved to results/eval_first_graph_GAT_MLP_OS_NoCSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GAT + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_MLP_OS_NoCSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0504 | Val Loss: 0.0669
#       Stage 2 Epoch 20 | Loss: 0.0301 | Val Loss: 0.0263
#       Stage 2 Epoch 30 | Loss: 0.0301 | Val Loss: 0.0383
#       Stage 2 Epoch 40 | Loss: 0.0207 | Val Loss: 0.0255
#       Stage 2 Epoch 50 | Loss: 0.0212 | Val Loss: 0.0430
#       Stage 2 Epoch 60 | Loss: 0.0196 | Val Loss: 0.0249
#       Stage 2 Epoch 70 | Loss: 0.0188 | Val Loss: 0.0349
#       Stage 2 Epoch 80 | Loss: 0.0220 | Val Loss: 0.0128
#       Stage 2 Epoch 90 | Loss: 0.0214 | Val Loss: 0.0296
#       Stage 2 Epoch 100 | Loss: 0.0176 | Val Loss: 0.0487
#       Stage 2 Epoch 110 | Loss: 0.0193 | Val Loss: 0.0257
#       Stage 2 Epoch 120 | Loss: 0.0183 | Val Loss: 0.0325
#       Stage 2 Epoch 130 | Loss: 0.0163 | Val Loss: 0.0256
#       Stage 2 Epoch 140 | Loss: 0.0206 | Val Loss: 0.0223
#       Stage 2 Epoch 150 | Loss: 0.0178 | Val Loss: 0.0275
#       Stage 2 Epoch 160 | Loss: 0.0222 | Val Loss: 0.0278
#       Stage 2 Epoch 170 | Loss: 0.0169 | Val Loss: 0.0193
#       Stage 2 Early stopping at epoch 180
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_MLP_OS_NoCSL_101.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9960604070912672, 'prec': 0.6923076923076923, 'rec': 0.8181818181818182, 'f1': 0.7500000000000001}
# Results ready to be saved to results/eval_first_graph_GAT_MLP_OS_NoCSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GAT + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_MLP_OS_NoCSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.1049 | Val Loss: 0.0762
#       Stage 2 Epoch 20 | Loss: 0.0357 | Val Loss: 0.0279
#       Stage 2 Epoch 30 | Loss: 0.0350 | Val Loss: 0.0412
#       Stage 2 Epoch 40 | Loss: 0.0239 | Val Loss: 0.0278
#       Stage 2 Epoch 50 | Loss: 0.0208 | Val Loss: 0.0247
#       Stage 2 Epoch 60 | Loss: 0.0259 | Val Loss: 0.0295
#       Stage 2 Epoch 70 | Loss: 0.0239 | Val Loss: 0.0554
#       Stage 2 Epoch 80 | Loss: 0.0215 | Val Loss: 0.0279
#       Stage 2 Epoch 90 | Loss: 0.0176 | Val Loss: 0.0306
#       Stage 2 Epoch 100 | Loss: 0.0236 | Val Loss: 0.0247
#       Stage 2 Epoch 110 | Loss: 0.0183 | Val Loss: 0.0288
#       Stage 2 Epoch 120 | Loss: 0.0232 | Val Loss: 0.0249
#       Stage 2 Epoch 130 | Loss: 0.0182 | Val Loss: 0.0211
#       Stage 2 Epoch 140 | Loss: 0.0182 | Val Loss: 0.0290
#       Stage 2 Epoch 150 | Loss: 0.0192 | Val Loss: 0.0287
#       Stage 2 Epoch 160 | Loss: 0.0188 | Val Loss: 0.0314
#       Stage 2 Early stopping at epoch 169
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_MLP_OS_NoCSL_1024.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9967170059093894, 'prec': 0.7142857142857143, 'rec': 0.9090909090909091, 'f1': 0.8}
# Results ready to be saved to results/eval_first_graph_GAT_MLP_OS_NoCSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GAT + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_MLP_OS_NoCSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.0852 | Val Loss: 0.0633
#       Stage 2 Epoch 20 | Loss: 0.0770 | Val Loss: 0.0635
#       Stage 2 Epoch 30 | Loss: 0.0761 | Val Loss: 0.0347
#       Stage 2 Epoch 40 | Loss: 0.0633 | Val Loss: 0.0262
#       Stage 2 Epoch 50 | Loss: 0.0693 | Val Loss: 0.0446
#       Stage 2 Epoch 60 | Loss: 0.0658 | Val Loss: 0.0356
#       Stage 2 Epoch 70 | Loss: 0.0588 | Val Loss: 0.0389
#       Stage 2 Epoch 80 | Loss: 0.0647 | Val Loss: 0.0356
#       Stage 2 Epoch 90 | Loss: 0.0549 | Val Loss: 0.0293
#       Stage 2 Epoch 100 | Loss: 0.0602 | Val Loss: 0.0323
#       Stage 2 Epoch 110 | Loss: 0.0576 | Val Loss: 0.0219
#       Stage 2 Epoch 120 | Loss: 0.0584 | Val Loss: 0.0271
#       Stage 2 Epoch 130 | Loss: 0.0700 | Val Loss: 0.0494
#       Stage 2 Epoch 140 | Loss: 0.0629 | Val Loss: 0.0304
#       Stage 2 Epoch 150 | Loss: 0.0616 | Val Loss: 0.0341
#       Stage 2 Epoch 160 | Loss: 0.0559 | Val Loss: 0.0306
#       Stage 2 Epoch 170 | Loss: 0.0563 | Val Loss: 0.0295
#       Stage 2 Epoch 180 | Loss: 0.0596 | Val Loss: 0.0449
#       Stage 2 Epoch 190 | Loss: 0.0596 | Val Loss: 0.0469
#       Stage 2 Epoch 200 | Loss: 0.0571 | Val Loss: 0.0254
#       Stage 2 Epoch 210 | Loss: 0.0590 | Val Loss: 0.0288
#       Stage 2 Epoch 220 | Loss: 0.0554 | Val Loss: 0.0304
#       Stage 2 Epoch 230 | Loss: 0.0579 | Val Loss: 0.0428
#       Stage 2 Epoch 240 | Loss: 0.0591 | Val Loss: 0.0388
#       Stage 2 Epoch 250 | Loss: 0.0591 | Val Loss: 0.0377
#       Stage 2 Epoch 260 | Loss: 0.0582 | Val Loss: 0.0382
#       Stage 2 Early stopping at epoch 262
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_MLP_OS_NoCSL_2025.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9967170059093894, 'prec': 0.7142857142857143, 'rec': 0.9090909090909091, 'f1': 0.8}
# Results ready to be saved to results/eval_first_graph_GAT_MLP_OS_NoCSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/wacgan-ethereum-balanced/graph_data/wgangp_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GraphSAGE \
--classifier MLP \
--epochs_stage2 1000 --patience 100 --use_oversampling --output_file
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/wacgan-ethereum-balanced/graph_data/wgangp_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 7713 nodes and 24896 edges
# Merge Info: 7613 overlapping nodes (anchors), 100 new synthetic nodes.
# Num nodes 7713 | Features: torch.Size([7713, 27]) | Fraud Train: 139 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5581 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7713, Edges: 24896, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 1000, Patience: 100
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GraphSAGE + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_MLP_OS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0213 | Val Loss: 0.0720
#       Stage 2 Epoch 20 | Loss: 0.0127 | Val Loss: 0.0396
#       Stage 2 Epoch 30 | Loss: 0.0067 | Val Loss: 0.0511
#       Stage 2 Epoch 40 | Loss: 0.0123 | Val Loss: 0.0295
#       Stage 2 Epoch 50 | Loss: 0.0027 | Val Loss: 0.0433
#       Stage 2 Epoch 60 | Loss: 0.0022 | Val Loss: 0.0261
#       Stage 2 Epoch 70 | Loss: 0.0024 | Val Loss: 0.0170
#       Stage 2 Epoch 80 | Loss: 0.0020 | Val Loss: 0.0124
#       Stage 2 Epoch 90 | Loss: 0.0019 | Val Loss: 0.0156
#       Stage 2 Epoch 100 | Loss: 0.0018 | Val Loss: 0.0185
#       Stage 2 Epoch 110 | Loss: 0.0026 | Val Loss: 0.0139
#       Stage 2 Epoch 120 | Loss: 0.0021 | Val Loss: 0.0156
#       Stage 2 Epoch 130 | Loss: 0.0027 | Val Loss: 0.0116
#       Stage 2 Epoch 140 | Loss: 0.0025 | Val Loss: 0.0174
#       Stage 2 Epoch 150 | Loss: 0.0029 | Val Loss: 0.0126
#       Stage 2 Epoch 160 | Loss: 0.0021 | Val Loss: 0.0121
#       Stage 2 Epoch 170 | Loss: 0.0018 | Val Loss: 0.0142
#       Stage 2 Epoch 180 | Loss: 0.0021 | Val Loss: 0.0153
#       Stage 2 Epoch 190 | Loss: 0.0023 | Val Loss: 0.0142
#       Stage 2 Epoch 200 | Loss: 0.0019 | Val Loss: 0.0223
#       Stage 2 Epoch 210 | Loss: 0.0020 | Val Loss: 0.0169
#       Stage 2 Epoch 220 | Loss: 0.0025 | Val Loss: 0.0173
#       Stage 2 Epoch 230 | Loss: 0.0034 | Val Loss: 0.0170
#       Stage 2 Epoch 240 | Loss: 0.0019 | Val Loss: 0.0150
#       Stage 2 Epoch 250 | Loss: 0.0013 | Val Loss: 0.0162
#       Stage 2 Epoch 260 | Loss: 0.0021 | Val Loss: 0.0151
#       Stage 2 Epoch 270 | Loss: 0.0031 | Val Loss: 0.0160
#       Stage 2 Epoch 280 | Loss: 0.0017 | Val Loss: 0.0156
#       Stage 2 Epoch 290 | Loss: 0.0016 | Val Loss: 0.0126
#       Stage 2 Epoch 300 | Loss: 0.0024 | Val Loss: 0.0127
#       Stage 2 Early stopping at epoch 306
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_0.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9980302035456337, 'prec': 0.8333333333333334, 'rec': 0.9090909090909091, 'f1': 0.8695652173913043}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GraphSAGE + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_MLP_OS_NoCSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0206 | Val Loss: 0.0578
#       Stage 2 Epoch 20 | Loss: 0.0089 | Val Loss: 0.0357
#       Stage 2 Epoch 30 | Loss: 0.0051 | Val Loss: 0.0276
#       Stage 2 Epoch 40 | Loss: 0.0023 | Val Loss: 0.0287
#       Stage 2 Epoch 50 | Loss: 0.0023 | Val Loss: 0.0168
#       Stage 2 Epoch 60 | Loss: 0.0032 | Val Loss: 0.0243
#       Stage 2 Epoch 70 | Loss: 0.0020 | Val Loss: 0.0199
#       Stage 2 Epoch 80 | Loss: 0.0020 | Val Loss: 0.0113
#       Stage 2 Epoch 90 | Loss: 0.0017 | Val Loss: 0.0249
#       Stage 2 Epoch 100 | Loss: 0.0024 | Val Loss: 0.0206
#       Stage 2 Epoch 110 | Loss: 0.0021 | Val Loss: 0.0203
#       Stage 2 Epoch 120 | Loss: 0.0039 | Val Loss: 0.0165
#       Stage 2 Epoch 130 | Loss: 0.0033 | Val Loss: 0.0191
#       Stage 2 Epoch 140 | Loss: 0.0032 | Val Loss: 0.0136
#       Stage 2 Epoch 150 | Loss: 0.0027 | Val Loss: 0.0196
#       Stage 2 Epoch 160 | Loss: 0.0018 | Val Loss: 0.0121
#       Stage 2 Epoch 170 | Loss: 0.0026 | Val Loss: 0.0149
#       Stage 2 Epoch 180 | Loss: 0.0036 | Val Loss: 0.0168
#       Stage 2 Epoch 190 | Loss: 0.0036 | Val Loss: 0.0153
#       Stage 2 Epoch 200 | Loss: 0.0024 | Val Loss: 0.0101
#       Stage 2 Epoch 210 | Loss: 0.0022 | Val Loss: 0.0167
#       Stage 2 Epoch 220 | Loss: 0.0020 | Val Loss: 0.0136
#       Stage 2 Epoch 230 | Loss: 0.0019 | Val Loss: 0.0130
#       Stage 2 Epoch 240 | Loss: 0.0026 | Val Loss: 0.0133
#       Stage 2 Epoch 250 | Loss: 0.0021 | Val Loss: 0.0128
#       Stage 2 Epoch 260 | Loss: 0.0020 | Val Loss: 0.0130
#       Stage 2 Epoch 270 | Loss: 0.0057 | Val Loss: 0.0153
#       Stage 2 Epoch 280 | Loss: 0.0032 | Val Loss: 0.0145
#       Stage 2 Epoch 290 | Loss: 0.0033 | Val Loss: 0.0155
#       Stage 2 Early stopping at epoch 299
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_42.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9993434011818779, 'prec': 1.0, 'rec': 0.9090909090909091, 'f1': 0.9523809523809523}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GraphSAGE + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_MLP_OS_NoCSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0202 | Val Loss: 0.0406
#       Stage 2 Epoch 20 | Loss: 0.0113 | Val Loss: 0.0224
#       Stage 2 Epoch 30 | Loss: 0.0079 | Val Loss: 0.0197
#       Stage 2 Epoch 40 | Loss: 0.0028 | Val Loss: 0.0198
#       Stage 2 Epoch 50 | Loss: 0.0026 | Val Loss: 0.0125
#       Stage 2 Epoch 60 | Loss: 0.0037 | Val Loss: 0.0110
#       Stage 2 Epoch 70 | Loss: 0.0023 | Val Loss: 0.0160
#       Stage 2 Epoch 80 | Loss: 0.0023 | Val Loss: 0.0159
#       Stage 2 Epoch 90 | Loss: 0.0015 | Val Loss: 0.0150
#       Stage 2 Epoch 100 | Loss: 0.0024 | Val Loss: 0.0156
#       Stage 2 Epoch 110 | Loss: 0.0020 | Val Loss: 0.0151
#       Stage 2 Epoch 120 | Loss: 0.0016 | Val Loss: 0.0181
#       Stage 2 Epoch 130 | Loss: 0.0023 | Val Loss: 0.0172
#       Stage 2 Early stopping at epoch 132
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_101.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9986868023637557, 'prec': 0.9090909090909091, 'rec': 0.9090909090909091, 'f1': 0.9090909090909091}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GraphSAGE + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_MLP_OS_NoCSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.0235 | Val Loss: 0.0394
#       Stage 2 Epoch 20 | Loss: 0.0129 | Val Loss: 0.0393
#       Stage 2 Epoch 30 | Loss: 0.0053 | Val Loss: 0.0185
#       Stage 2 Epoch 40 | Loss: 0.0026 | Val Loss: 0.0166
#       Stage 2 Epoch 50 | Loss: 0.0024 | Val Loss: 0.0172
#       Stage 2 Epoch 60 | Loss: 0.0016 | Val Loss: 0.0166
#       Stage 2 Epoch 70 | Loss: 0.0018 | Val Loss: 0.0159
#       Stage 2 Epoch 80 | Loss: 0.0031 | Val Loss: 0.0102
#       Stage 2 Epoch 90 | Loss: 0.0022 | Val Loss: 0.0129
#       Stage 2 Epoch 100 | Loss: 0.0025 | Val Loss: 0.0171
#       Stage 2 Epoch 110 | Loss: 0.0033 | Val Loss: 0.0139
#       Stage 2 Epoch 120 | Loss: 0.0021 | Val Loss: 0.0170
#       Stage 2 Early stopping at epoch 129
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_1024.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9980302035456337, 'prec': 0.8333333333333334, 'rec': 0.9090909090909091, 'f1': 0.8695652173913043}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GraphSAGE + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_MLP_OS_NoCSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.0183 | Val Loss: 0.0544
#       Stage 2 Epoch 20 | Loss: 0.0105 | Val Loss: 0.0275
#       Stage 2 Epoch 30 | Loss: 0.0080 | Val Loss: 0.0227
#       Stage 2 Epoch 40 | Loss: 0.0054 | Val Loss: 0.0432
#       Stage 2 Epoch 50 | Loss: 0.0040 | Val Loss: 0.0270
#       Stage 2 Epoch 60 | Loss: 0.0030 | Val Loss: 0.0194
#       Stage 2 Epoch 70 | Loss: 0.0025 | Val Loss: 0.0140
#       Stage 2 Epoch 80 | Loss: 0.0029 | Val Loss: 0.0137
#       Stage 2 Epoch 90 | Loss: 0.0018 | Val Loss: 0.0196
#       Stage 2 Epoch 100 | Loss: 0.0017 | Val Loss: 0.0146
#       Stage 2 Epoch 110 | Loss: 0.0025 | Val Loss: 0.0169
#       Stage 2 Epoch 120 | Loss: 0.0029 | Val Loss: 0.0132
#       Stage 2 Epoch 130 | Loss: 0.0031 | Val Loss: 0.0125
#       Stage 2 Epoch 140 | Loss: 0.0019 | Val Loss: 0.0156
#       Stage 2 Epoch 150 | Loss: 0.0018 | Val Loss: 0.0092
#       Stage 2 Epoch 160 | Loss: 0.0020 | Val Loss: 0.0202
#       Stage 2 Epoch 170 | Loss: 0.0018 | Val Loss: 0.0158
#       Stage 2 Epoch 180 | Loss: 0.0022 | Val Loss: 0.0146
#       Stage 2 Epoch 190 | Loss: 0.0019 | Val Loss: 0.0157
#       Stage 2 Epoch 200 | Loss: 0.0022 | Val Loss: 0.0123
#       Stage 2 Epoch 210 | Loss: 0.0014 | Val Loss: 0.0154
#       Stage 2 Epoch 220 | Loss: 0.0031 | Val Loss: 0.0212
#       Stage 2 Early stopping at epoch 221
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_2025.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9986868023637557, 'prec': 1.0, 'rec': 0.8181818181818182, 'f1': 0.9}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/wacgan-ethereum-balanced/graph_data/wgangp_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GIN \
--classifier MLP \
--epochs_stage2 1000 --patience 100 --use_oversampling --output_file
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/wacgan-ethereum-balanced/graph_data/wgangp_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 7713 nodes and 24896 edges
# Merge Info: 7613 overlapping nodes (anchors), 100 new synthetic nodes.
# Num nodes 7713 | Features: torch.Size([7713, 27]) | Fraud Train: 139 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5581 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7713, Edges: 24896, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 1000, Patience: 100
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GIN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_MLP_OS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0548 | Val Loss: 0.0681
#       Stage 2 Epoch 20 | Loss: 0.0202 | Val Loss: 0.0321
#       Stage 2 Epoch 30 | Loss: 0.0138 | Val Loss: 0.0280
#       Stage 2 Epoch 40 | Loss: 0.0150 | Val Loss: 0.0271
#       Stage 2 Epoch 50 | Loss: 0.0118 | Val Loss: 0.0297
#       Stage 2 Epoch 60 | Loss: 0.0136 | Val Loss: 0.0274
#       Stage 2 Epoch 70 | Loss: 0.0125 | Val Loss: 0.0279
#       Stage 2 Epoch 80 | Loss: 0.0102 | Val Loss: 0.0251
#       Stage 2 Epoch 90 | Loss: 0.0142 | Val Loss: 0.0211
#       Stage 2 Epoch 100 | Loss: 0.0118 | Val Loss: 0.0212
#       Stage 2 Epoch 110 | Loss: 0.0106 | Val Loss: 0.0221
#       Stage 2 Epoch 120 | Loss: 0.0123 | Val Loss: 0.0295
#       Stage 2 Epoch 130 | Loss: 0.0097 | Val Loss: 0.0259
#       Stage 2 Epoch 140 | Loss: 0.0113 | Val Loss: 0.0274
#       Stage 2 Epoch 150 | Loss: 0.0089 | Val Loss: 0.0224
#       Stage 2 Epoch 160 | Loss: 0.0082 | Val Loss: 0.0176
#       Stage 2 Epoch 170 | Loss: 0.0069 | Val Loss: 0.0245
#       Stage 2 Epoch 180 | Loss: 0.0090 | Val Loss: 0.0219
#       Stage 2 Epoch 190 | Loss: 0.0109 | Val Loss: 0.0270
#       Stage 2 Epoch 200 | Loss: 0.0082 | Val Loss: 0.0268
#       Stage 2 Epoch 210 | Loss: 0.0061 | Val Loss: 0.0173
#       Stage 2 Early stopping at epoch 213
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_MLP_OS_NoCSL_0.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9954038082731451, 'prec': 0.6666666666666666, 'rec': 0.7272727272727273, 'f1': 0.6956521739130435}
# Results ready to be saved to results/eval_first_graph_GIN_MLP_OS_NoCSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GIN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_MLP_OS_NoCSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0384 | Val Loss: 0.0561
#       Stage 2 Epoch 20 | Loss: 0.0229 | Val Loss: 0.0295
#       Stage 2 Epoch 30 | Loss: 0.0163 | Val Loss: 0.0340
#       Stage 2 Epoch 40 | Loss: 0.0183 | Val Loss: 0.0452
#       Stage 2 Epoch 50 | Loss: 0.0136 | Val Loss: 0.0289
#       Stage 2 Epoch 60 | Loss: 0.0121 | Val Loss: 0.0255
#       Stage 2 Epoch 70 | Loss: 0.0121 | Val Loss: 0.0252
#       Stage 2 Epoch 80 | Loss: 0.0112 | Val Loss: 0.0240
#       Stage 2 Epoch 90 | Loss: 0.0122 | Val Loss: 0.0277
#       Stage 2 Epoch 100 | Loss: 0.0133 | Val Loss: 0.0255
#       Stage 2 Epoch 110 | Loss: 0.0106 | Val Loss: 0.0232
#       Stage 2 Epoch 120 | Loss: 0.0153 | Val Loss: 0.0245
#       Stage 2 Epoch 130 | Loss: 0.0104 | Val Loss: 0.0238
#       Stage 2 Epoch 140 | Loss: 0.0101 | Val Loss: 0.0225
#       Stage 2 Epoch 150 | Loss: 0.0095 | Val Loss: 0.0238
#       Stage 2 Epoch 160 | Loss: 0.0092 | Val Loss: 0.0263
#       Stage 2 Epoch 170 | Loss: 0.0102 | Val Loss: 0.0329
#       Stage 2 Epoch 180 | Loss: 0.0081 | Val Loss: 0.0254
#       Stage 2 Epoch 190 | Loss: 0.0071 | Val Loss: 0.0188
#       Stage 2 Epoch 200 | Loss: 0.0205 | Val Loss: 0.0304
#       Stage 2 Epoch 210 | Loss: 0.0156 | Val Loss: 0.0295
#       Stage 2 Epoch 220 | Loss: 0.0105 | Val Loss: 0.0259
#       Stage 2 Epoch 230 | Loss: 0.0123 | Val Loss: 0.0224
#       Stage 2 Epoch 240 | Loss: 0.0134 | Val Loss: 0.0302
#       Stage 2 Epoch 250 | Loss: 0.0102 | Val Loss: 0.0222
#       Stage 2 Epoch 260 | Loss: 0.0093 | Val Loss: 0.0185
#       Stage 2 Epoch 270 | Loss: 0.0080 | Val Loss: 0.0266
#       Stage 2 Epoch 280 | Loss: 0.0101 | Val Loss: 0.0194
#       Stage 2 Early stopping at epoch 290
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_MLP_OS_NoCSL_42.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9967170059093894, 'prec': 0.8, 'rec': 0.7272727272727273, 'f1': 0.761904761904762}
# Results ready to be saved to results/eval_first_graph_GIN_MLP_OS_NoCSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GIN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_MLP_OS_NoCSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0390 | Val Loss: 0.0606
#       Stage 2 Epoch 20 | Loss: 0.0198 | Val Loss: 0.0303
#       Stage 2 Epoch 30 | Loss: 0.0172 | Val Loss: 0.0311
#       Stage 2 Epoch 40 | Loss: 0.0131 | Val Loss: 0.0284
#       Stage 2 Epoch 50 | Loss: 0.0113 | Val Loss: 0.0311
#       Stage 2 Epoch 60 | Loss: 0.0119 | Val Loss: 0.0265
#       Stage 2 Epoch 70 | Loss: 0.0112 | Val Loss: 0.0279
#       Stage 2 Epoch 80 | Loss: 0.0105 | Val Loss: 0.0230
#       Stage 2 Epoch 90 | Loss: 0.0109 | Val Loss: 0.0233
#       Stage 2 Epoch 100 | Loss: 0.0104 | Val Loss: 0.0221
#       Stage 2 Epoch 110 | Loss: 0.0086 | Val Loss: 0.0243
#       Stage 2 Epoch 120 | Loss: 0.0084 | Val Loss: 0.0217
#       Stage 2 Epoch 130 | Loss: 0.0110 | Val Loss: 0.0264
#       Stage 2 Epoch 140 | Loss: 0.0104 | Val Loss: 0.0277
#       Stage 2 Epoch 150 | Loss: 0.0097 | Val Loss: 0.0238
#       Stage 2 Epoch 160 | Loss: 0.0083 | Val Loss: 0.0232
#       Stage 2 Epoch 170 | Loss: 0.0078 | Val Loss: 0.0234
#       Stage 2 Epoch 180 | Loss: 0.0071 | Val Loss: 0.0261
#       Stage 2 Epoch 190 | Loss: 0.0070 | Val Loss: 0.0138
#       Stage 2 Epoch 200 | Loss: 0.0054 | Val Loss: 0.0175
#       Stage 2 Epoch 210 | Loss: 0.0042 | Val Loss: 0.0190
#       Stage 2 Epoch 220 | Loss: 0.0044 | Val Loss: 0.0240
#       Stage 2 Epoch 230 | Loss: 0.0056 | Val Loss: 0.0220
#       Stage 2 Epoch 240 | Loss: 0.0051 | Val Loss: 0.0238
#       Stage 2 Epoch 250 | Loss: 0.0116 | Val Loss: 0.0283
#       Stage 2 Epoch 260 | Loss: 0.0117 | Val Loss: 0.0297
#       Stage 2 Epoch 270 | Loss: 0.0083 | Val Loss: 0.0226
#       Stage 2 Epoch 280 | Loss: 0.0041 | Val Loss: 0.0214
#       Stage 2 Early stopping at epoch 290
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_MLP_OS_NoCSL_101.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9973736047275115, 'prec': 0.8181818181818182, 'rec': 0.8181818181818182, 'f1': 0.8181818181818182}
# Results ready to be saved to results/eval_first_graph_GIN_MLP_OS_NoCSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GIN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_MLP_OS_NoCSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.0579 | Val Loss: 0.0765
#       Stage 2 Epoch 20 | Loss: 0.0247 | Val Loss: 0.0445
#       Stage 2 Epoch 30 | Loss: 0.0168 | Val Loss: 0.0347
#       Stage 2 Epoch 40 | Loss: 0.0142 | Val Loss: 0.0283
#       Stage 2 Epoch 50 | Loss: 0.0137 | Val Loss: 0.0272
#       Stage 2 Epoch 60 | Loss: 0.0136 | Val Loss: 0.0258
#       Stage 2 Epoch 70 | Loss: 0.0117 | Val Loss: 0.0252
#       Stage 2 Epoch 80 | Loss: 0.0114 | Val Loss: 0.0251
#       Stage 2 Epoch 90 | Loss: 0.0107 | Val Loss: 0.0234
#       Stage 2 Epoch 100 | Loss: 0.0109 | Val Loss: 0.0215
#       Stage 2 Epoch 110 | Loss: 0.0132 | Val Loss: 0.0271
#       Stage 2 Epoch 120 | Loss: 0.0102 | Val Loss: 0.0228
#       Stage 2 Epoch 130 | Loss: 0.0140 | Val Loss: 0.0279
#       Stage 2 Epoch 140 | Loss: 0.0111 | Val Loss: 0.0268
#       Stage 2 Epoch 150 | Loss: 0.0092 | Val Loss: 0.0216
#       Stage 2 Epoch 160 | Loss: 0.0105 | Val Loss: 0.0205
#       Stage 2 Epoch 170 | Loss: 0.0103 | Val Loss: 0.0238
#       Stage 2 Epoch 180 | Loss: 0.0107 | Val Loss: 0.0278
#       Stage 2 Epoch 190 | Loss: 0.0074 | Val Loss: 0.0220
#       Stage 2 Epoch 200 | Loss: 0.0066 | Val Loss: 0.0187
#       Stage 2 Epoch 210 | Loss: 0.0069 | Val Loss: 0.0208
#       Stage 2 Epoch 220 | Loss: 0.0095 | Val Loss: 0.0238
#       Stage 2 Epoch 230 | Loss: 0.0082 | Val Loss: 0.0209
#       Stage 2 Epoch 240 | Loss: 0.0064 | Val Loss: 0.0174
#       Stage 2 Epoch 250 | Loss: 0.0067 | Val Loss: 0.0247
#       Stage 2 Epoch 260 | Loss: 0.0187 | Val Loss: 0.0289
#       Stage 2 Epoch 270 | Loss: 0.0176 | Val Loss: 0.0263
#       Stage 2 Epoch 280 | Loss: 0.0111 | Val Loss: 0.0222
#       Stage 2 Epoch 290 | Loss: 0.0120 | Val Loss: 0.0274
#       Stage 2 Epoch 300 | Loss: 0.0103 | Val Loss: 0.0228
#       Stage 2 Epoch 310 | Loss: 0.0097 | Val Loss: 0.0208
#       Stage 2 Epoch 320 | Loss: 0.0079 | Val Loss: 0.0222
#       Stage 2 Early stopping at epoch 324
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_MLP_OS_NoCSL_1024.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9967170059093894, 'prec': 0.8, 'rec': 0.7272727272727273, 'f1': 0.761904761904762}
# Results ready to be saved to results/eval_first_graph_GIN_MLP_OS_NoCSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GIN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_MLP_OS_NoCSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.0574 | Val Loss: 0.0779
#       Stage 2 Epoch 20 | Loss: 0.0216 | Val Loss: 0.0319
#       Stage 2 Epoch 30 | Loss: 0.0180 | Val Loss: 0.0292
#       Stage 2 Epoch 40 | Loss: 0.0160 | Val Loss: 0.0279
#       Stage 2 Epoch 50 | Loss: 0.0131 | Val Loss: 0.0308
#       Stage 2 Epoch 60 | Loss: 0.0166 | Val Loss: 0.0287
#       Stage 2 Epoch 70 | Loss: 0.0136 | Val Loss: 0.0271
#       Stage 2 Epoch 80 | Loss: 0.0157 | Val Loss: 0.0295
#       Stage 2 Epoch 90 | Loss: 0.0138 | Val Loss: 0.0286
#       Stage 2 Epoch 100 | Loss: 0.0136 | Val Loss: 0.0244
#       Stage 2 Epoch 110 | Loss: 0.0126 | Val Loss: 0.0257
#       Stage 2 Epoch 120 | Loss: 0.0126 | Val Loss: 0.0247
#       Stage 2 Epoch 130 | Loss: 0.0117 | Val Loss: 0.0243
#       Stage 2 Epoch 140 | Loss: 0.0115 | Val Loss: 0.0267
#       Stage 2 Epoch 150 | Loss: 0.0174 | Val Loss: 0.0286
#       Stage 2 Epoch 160 | Loss: 0.0126 | Val Loss: 0.0248
#       Stage 2 Epoch 170 | Loss: 0.0108 | Val Loss: 0.0205
#       Stage 2 Epoch 180 | Loss: 0.0094 | Val Loss: 0.0238
#       Stage 2 Epoch 190 | Loss: 0.0099 | Val Loss: 0.0233
#       Stage 2 Epoch 200 | Loss: 0.0116 | Val Loss: 0.0237
#       Stage 2 Epoch 210 | Loss: 0.0143 | Val Loss: 0.0279
#       Stage 2 Epoch 220 | Loss: 0.0124 | Val Loss: 0.0232
#       Stage 2 Epoch 230 | Loss: 0.0093 | Val Loss: 0.0220
#       Stage 2 Epoch 240 | Loss: 0.0107 | Val Loss: 0.0236
#       Stage 2 Epoch 250 | Loss: 0.0091 | Val Loss: 0.0243
#       Stage 2 Epoch 260 | Loss: 0.0093 | Val Loss: 0.0207
#       Stage 2 Epoch 270 | Loss: 0.0067 | Val Loss: 0.0215
#       Stage 2 Epoch 280 | Loss: 0.0077 | Val Loss: 0.0198
#       Stage 2 Epoch 290 | Loss: 0.0068 | Val Loss: 0.0229
#       Stage 2 Early stopping at epoch 294
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_MLP_OS_NoCSL_2025.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9960604070912672, 'prec': 0.6923076923076923, 'rec': 0.8181818181818182, 'f1': 0.7500000000000001}
# Results ready to be saved to results/eval_first_graph_GIN_MLP_OS_NoCSL_2025.json

# %%
# !cd /kaggle/working/results
# !zip -r G1-MLP-WGANGP-NoCSL.zip /kaggle/working/results/
# Out:
#   adding: kaggle/working/results/ (stored 0%)
#   adding: kaggle/working/results/eval_first_graph_GAT_MLP_OS_NoCSL_101.json (deflated 41%)
#   adding: kaggle/working/results/eval_first_graph_GCN_MLP_OS_NoCSL_0.json (deflated 38%)
#   adding: kaggle/working/results/eval_first_graph_GCN_MLP_OS_NoCSL_2025.json (deflated 38%)
#   adding: kaggle/working/results/pred_first_graph_GCN_MLP_OS_NoCSL_101.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_0.json (deflated 39%)
#   adding: kaggle/working/results/eval_first_graph_GAT_MLP_OS_NoCSL_1024.json (deflated 38%)
#   adding: kaggle/working/results/pred_first_graph_GAT_MLP_OS_NoCSL_101.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GIN_MLP_OS_NoCSL_1024.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GIN_MLP_OS_NoCSL_0.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GCN_MLP_OS_NoCSL_42.json (deflated 38%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_1024.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GIN_MLP_OS_NoCSL_2025.json (deflated 41%)
#   adding: kaggle/working/results/eval_first_graph_GIN_MLP_OS_NoCSL_42.json (deflated 39%)
#   adding: kaggle/working/results/pred_first_graph_GCN_MLP_OS_NoCSL_0.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_1024.json (deflated 39%)
#   adding: kaggle/working/results/eval_first_graph_GAT_MLP_OS_NoCSL_2025.json (deflated 38%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_42.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_42.json (deflated 38%)
#   adding: kaggle/working/results/pred_first_graph_GCN_MLP_OS_NoCSL_42.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_2025.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GAT_MLP_OS_NoCSL_2025.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_101.json (deflated 45%)
#   adding: kaggle/working/results/pred_first_graph_GCN_MLP_OS_NoCSL_2025.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GAT_MLP_OS_NoCSL_42.json (deflated 41%)
#   adding: kaggle/working/results/eval_first_graph_GAT_MLP_OS_NoCSL_0.json (deflated 37%)
#   adding: kaggle/working/results/eval_first_graph_GCN_MLP_OS_NoCSL_1024.json (deflated 38%)
#   adding: kaggle/working/results/eval_first_graph_GIN_MLP_OS_NoCSL_0.json (deflated 40%)
#   adding: kaggle/working/results/pred_first_graph_GIN_MLP_OS_NoCSL_101.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_101.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GIN_MLP_OS_NoCSL_2025.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GIN_MLP_OS_NoCSL_42.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GIN_MLP_OS_NoCSL_101.json (deflated 45%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_2025.json (deflated 36%)
#   adding: kaggle/working/results/pred_first_graph_GAT_MLP_OS_NoCSL_1024.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GAT_MLP_OS_NoCSL_42.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GCN_MLP_OS_NoCSL_1024.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GCN_MLP_OS_NoCSL_101.json (deflated 38%)
#   adding: kaggle/working/results/pred_first_graph_GAT_MLP_OS_NoCSL_0.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GIN_MLP_OS_NoCSL_1024.json (deflated 39%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_0.csv (deflated 98%)
