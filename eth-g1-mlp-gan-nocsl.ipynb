# %%
# !pip install torch_geometric
# !pip install git+https://github.com/Blealtan/efficient-kan.git
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.13.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2025.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (7.1.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2025.10.5)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal>=1.4.0->aiohttp->torch_geometric) (4.15.0)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torch_geometric) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torch_geometric) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torch_geometric) (2024.2.0)
# Downloading torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 28.2 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.7.0
# Collecting git+https://github.com/Blealtan/efficient-kan.git
#   Cloning https://github.com/Blealtan/efficient-kan.git to /tmp/pip-req-build-deexegzj
#   Running command git clone --filter=blob:none --quiet https://github.com/Blealtan/efficient-kan.git /tmp/pip-req-build-deexegzj
#   Resolved https://github.com/Blealtan/efficient-kan.git to commit 7b6ce1c87f18c8bc90c208f6b494042344216b11
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (2.6.0+cu124)
# Requirement already satisfied: pytest>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (8.4.1)
# Requirement already satisfied: tqdm>=4.66.2 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (4.67.1)
# Requirement already satisfied: torchvision>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (0.21.0+cu124)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (2.1.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (25.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (2.19.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (2025.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.3.0->efficient-kan==0.1.0) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.18.0->efficient-kan==0.1.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.18.0->efficient-kan==0.1.0) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.3.0->efficient-kan==0.1.0) (3.0.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2.4.1)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 120.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 94.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 54.3 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 35.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 15.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 104.2 MB/s eta 0:00:00
# Building wheels for collected packages: efficient-kan
#   Building wheel for efficient-kan (pyproject.toml) ... done
#   Created wheel for efficient-kan: filename=efficient_kan-0.1.0-py3-none-any.whl size=5981 sha256=3fadb37365bda971d6bcb716e5ecf58aca9c70ee79e32324453796857b325548
#   Stored in directory: /tmp/pip-ephem-wheel-cache-l2o618af/wheels/da/a3/b4/30b3e3df2edaded3c87227cb9faea5878f18ec03e1c2137839
# Successfully built efficient-kan
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, efficient-kan
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed efficient-kan-0.1.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !git clone https://agusth24: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@github.com/agusth24/ethereum-fraud-detection.git
# Out:
# Cloning into 'ethereum-fraud-detection'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (31/31), done.
# Receiving objects: 100% (51/51), 14.72 KiB | 2.94 MiB/s, done.
# remote: Total 51 (delta 23), reused 45 (delta 17), pack-reused 0 (from 0)
# Resolving deltas: 100% (23/23), done.

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/etehereum-balanced-gd/graph_data/graphgan_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GCN \
--classifier MLP \
--epochs_stage2 1000 --patience 100 --use_oversampling --output_file
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/etehereum-balanced-gd/graph_data/graphgan_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 6290 nodes and 17269 edges
# Merge Info: 6091 overlapping nodes (anchors), 199 new synthetic nodes.
# Num nodes 7812 | Features: torch.Size([7812, 28]) | Fraud Train: 238 | Fraud Val: 4 | Fraud Test: 12
# Final Split | Train: 5680 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7812, Edges: 25308, Features: 28
#
# Starting Experiments with 5 seeds. Max Epochs: 1000, Patience: 100
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GCN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_MLP_OS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0061 | Val Loss: 0.0065
#       Stage 2 Epoch 20 | Loss: 0.0029 | Val Loss: 0.0082
#       Stage 2 Epoch 30 | Loss: 0.0032 | Val Loss: 0.0051
#       Stage 2 Epoch 40 | Loss: 0.0024 | Val Loss: 0.0064
#       Stage 2 Epoch 50 | Loss: 0.0027 | Val Loss: 0.0061
#       Stage 2 Epoch 60 | Loss: 0.0026 | Val Loss: 0.0049
#       Stage 2 Epoch 70 | Loss: 0.0025 | Val Loss: 0.0061
#       Stage 2 Epoch 80 | Loss: 0.0022 | Val Loss: 0.0040
#       Stage 2 Epoch 90 | Loss: 0.0032 | Val Loss: 0.0039
#       Stage 2 Epoch 100 | Loss: 0.0028 | Val Loss: 0.0044
#       Stage 2 Epoch 110 | Loss: 0.0020 | Val Loss: 0.0049
#       Stage 2 Epoch 120 | Loss: 0.0022 | Val Loss: 0.0037
#       Stage 2 Epoch 130 | Loss: 0.0025 | Val Loss: 0.0050
#       Stage 2 Epoch 140 | Loss: 0.0026 | Val Loss: 0.0049
#       Stage 2 Epoch 150 | Loss: 0.0022 | Val Loss: 0.0034
#       Stage 2 Epoch 160 | Loss: 0.0022 | Val Loss: 0.0054
#       Stage 2 Early stopping at epoch 162
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_MLP_OS_NoCSL_0.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9914642153644123, 'prec': 0.4, 'rec': 0.16666666666666666, 'f1': 0.23529411764705882}
# Results ready to be saved to results/eval_first_graph_GCN_MLP_OS_NoCSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GCN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_MLP_OS_NoCSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0103 | Val Loss: 0.0090
#       Stage 2 Epoch 20 | Loss: 0.0035 | Val Loss: 0.0054
#       Stage 2 Epoch 30 | Loss: 0.0031 | Val Loss: 0.0058
#       Stage 2 Epoch 40 | Loss: 0.0030 | Val Loss: 0.0065
#       Stage 2 Epoch 50 | Loss: 0.0031 | Val Loss: 0.0070
#       Stage 2 Epoch 60 | Loss: 0.0029 | Val Loss: 0.0028
#       Stage 2 Epoch 70 | Loss: 0.0034 | Val Loss: 0.0014
#       Stage 2 Epoch 80 | Loss: 0.0027 | Val Loss: 0.0057
#       Stage 2 Epoch 90 | Loss: 0.0020 | Val Loss: 0.0053
#       Stage 2 Epoch 100 | Loss: 0.0024 | Val Loss: 0.0056
#       Stage 2 Epoch 110 | Loss: 0.0022 | Val Loss: 0.0039
#       Stage 2 Epoch 120 | Loss: 0.0025 | Val Loss: 0.0061
#       Stage 2 Epoch 130 | Loss: 0.0022 | Val Loss: 0.0014
#       Stage 2 Epoch 140 | Loss: 0.0020 | Val Loss: 0.0007
#       Stage 2 Epoch 150 | Loss: 0.0019 | Val Loss: 0.0015
#       Stage 2 Epoch 160 | Loss: 0.0023 | Val Loss: 0.0015
#       Stage 2 Early stopping at epoch 170
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_MLP_OS_NoCSL_42.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9921208141825345, 'prec': 0.5, 'rec': 0.25, 'f1': 0.3333333333333333}
# Results ready to be saved to results/eval_first_graph_GCN_MLP_OS_NoCSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GCN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_MLP_OS_NoCSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0070 | Val Loss: 0.0094
#       Stage 2 Epoch 20 | Loss: 0.0034 | Val Loss: 0.0048
#       Stage 2 Epoch 30 | Loss: 0.0029 | Val Loss: 0.0082
#       Stage 2 Epoch 40 | Loss: 0.0034 | Val Loss: 0.0027
#       Stage 2 Epoch 50 | Loss: 0.0025 | Val Loss: 0.0027
#       Stage 2 Epoch 60 | Loss: 0.0024 | Val Loss: 0.0033
#       Stage 2 Epoch 70 | Loss: 0.0025 | Val Loss: 0.0029
#       Stage 2 Epoch 80 | Loss: 0.0026 | Val Loss: 0.0067
#       Stage 2 Epoch 90 | Loss: 0.0029 | Val Loss: 0.0045
#       Stage 2 Epoch 100 | Loss: 0.0024 | Val Loss: 0.0035
#       Stage 2 Epoch 110 | Loss: 0.0026 | Val Loss: 0.0075
#       Stage 2 Epoch 120 | Loss: 0.0026 | Val Loss: 0.0021
#       Stage 2 Epoch 130 | Loss: 0.0023 | Val Loss: 0.0016
#       Stage 2 Epoch 140 | Loss: 0.0022 | Val Loss: 0.0003
#       Stage 2 Epoch 150 | Loss: 0.0025 | Val Loss: 0.0029
#       Stage 2 Early stopping at epoch 153
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_MLP_OS_NoCSL_101.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9914642153644123, 'prec': 0.4, 'rec': 0.16666666666666666, 'f1': 0.23529411764705882}
# Results ready to be saved to results/eval_first_graph_GCN_MLP_OS_NoCSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GCN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_MLP_OS_NoCSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.0049 | Val Loss: 0.0081
#       Stage 2 Epoch 20 | Loss: 0.0032 | Val Loss: 0.0078
#       Stage 2 Epoch 30 | Loss: 0.0025 | Val Loss: 0.0073
#       Stage 2 Epoch 40 | Loss: 0.0036 | Val Loss: 0.0042
#       Stage 2 Epoch 50 | Loss: 0.0034 | Val Loss: 0.0039
#       Stage 2 Epoch 60 | Loss: 0.0026 | Val Loss: 0.0061
#       Stage 2 Epoch 70 | Loss: 0.0021 | Val Loss: 0.0009
#       Stage 2 Epoch 80 | Loss: 0.0020 | Val Loss: 0.0039
#       Stage 2 Epoch 90 | Loss: 0.0027 | Val Loss: 0.0051
#       Stage 2 Epoch 100 | Loss: 0.0019 | Val Loss: 0.0004
#       Stage 2 Epoch 110 | Loss: 0.0023 | Val Loss: 0.0033
#       Stage 2 Epoch 120 | Loss: 0.0018 | Val Loss: 0.0013
#       Stage 2 Epoch 130 | Loss: 0.0020 | Val Loss: 0.0061
#       Stage 2 Epoch 140 | Loss: 0.0024 | Val Loss: 0.0007
#       Stage 2 Epoch 150 | Loss: 0.0023 | Val Loss: 0.0015
#       Stage 2 Epoch 160 | Loss: 0.0026 | Val Loss: 0.0056
#       Stage 2 Epoch 170 | Loss: 0.0029 | Val Loss: 0.0078
#       Stage 2 Early stopping at epoch 172
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_MLP_OS_NoCSL_1024.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9908076165462902, 'prec': 0.25, 'rec': 0.08333333333333333, 'f1': 0.125}
# Results ready to be saved to results/eval_first_graph_GCN_MLP_OS_NoCSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GCN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_MLP_OS_NoCSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.0072 | Val Loss: 0.0075
#       Stage 2 Epoch 20 | Loss: 0.0038 | Val Loss: 0.0060
#       Stage 2 Epoch 30 | Loss: 0.0042 | Val Loss: 0.0039
#       Stage 2 Epoch 40 | Loss: 0.0029 | Val Loss: 0.0036
#       Stage 2 Epoch 50 | Loss: 0.0022 | Val Loss: 0.0058
#       Stage 2 Epoch 60 | Loss: 0.0032 | Val Loss: 0.0060
#       Stage 2 Epoch 70 | Loss: 0.0028 | Val Loss: 0.0044
#       Stage 2 Epoch 80 | Loss: 0.0022 | Val Loss: 0.0055
#       Stage 2 Epoch 90 | Loss: 0.0027 | Val Loss: 0.0059
#       Stage 2 Epoch 100 | Loss: 0.0026 | Val Loss: 0.0035
#       Stage 2 Epoch 110 | Loss: 0.0026 | Val Loss: 0.0046
#       Stage 2 Epoch 120 | Loss: 0.0032 | Val Loss: 0.0045
#       Stage 2 Epoch 130 | Loss: 0.0020 | Val Loss: 0.0010
#       Stage 2 Epoch 140 | Loss: 0.0027 | Val Loss: 0.0054
#       Stage 2 Epoch 150 | Loss: 0.0028 | Val Loss: 0.0029
#       Stage 2 Epoch 160 | Loss: 0.0023 | Val Loss: 0.0036
#       Stage 2 Epoch 170 | Loss: 0.0023 | Val Loss: 0.0063
#       Stage 2 Early stopping at epoch 177
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_MLP_OS_NoCSL_2025.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9914642153644123, 'prec': 0.3333333333333333, 'rec': 0.08333333333333333, 'f1': 0.13333333333333333}
# Results ready to be saved to results/eval_first_graph_GCN_MLP_OS_NoCSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/etehereum-balanced-gd/graph_data/graphgan_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GAT \
--classifier MLP \
--epochs_stage2 1000 --patience 100 --use_oversampling --output_file
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/etehereum-balanced-gd/graph_data/graphgan_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 6290 nodes and 17269 edges
# Merge Info: 6091 overlapping nodes (anchors), 199 new synthetic nodes.
# Num nodes 7812 | Features: torch.Size([7812, 28]) | Fraud Train: 238 | Fraud Val: 4 | Fraud Test: 12
# Final Split | Train: 5680 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7812, Edges: 25308, Features: 28
#
# Starting Experiments with 5 seeds. Max Epochs: 1000, Patience: 100
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GAT + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_MLP_OS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0987 | Val Loss: 0.0275
#       Stage 2 Epoch 20 | Loss: 0.0868 | Val Loss: 0.0439
#       Stage 2 Epoch 30 | Loss: 0.0875 | Val Loss: 0.0434
#       Stage 2 Epoch 40 | Loss: 0.0679 | Val Loss: 0.0330
#       Stage 2 Epoch 50 | Loss: 0.0462 | Val Loss: 0.0071
#       Stage 2 Epoch 60 | Loss: 0.0217 | Val Loss: 0.0160
#       Stage 2 Epoch 70 | Loss: 0.0173 | Val Loss: 0.0191
#       Stage 2 Epoch 80 | Loss: 0.0204 | Val Loss: 0.0033
#       Stage 2 Epoch 90 | Loss: 0.0232 | Val Loss: 0.0033
#       Stage 2 Epoch 100 | Loss: 0.0203 | Val Loss: 0.0126
#       Stage 2 Epoch 110 | Loss: 0.0243 | Val Loss: 0.0039
#       Stage 2 Epoch 120 | Loss: 0.0191 | Val Loss: 0.0064
#       Stage 2 Epoch 130 | Loss: 0.0113 | Val Loss: 0.0200
#       Stage 2 Epoch 140 | Loss: 0.0183 | Val Loss: 0.0036
#       Stage 2 Epoch 150 | Loss: 0.0178 | Val Loss: 0.0180
#       Stage 2 Epoch 160 | Loss: 0.0156 | Val Loss: 0.0026
#       Stage 2 Epoch 170 | Loss: 0.0201 | Val Loss: 0.0179
#       Stage 2 Epoch 180 | Loss: 0.0166 | Val Loss: 0.0239
#       Stage 2 Epoch 190 | Loss: 0.0173 | Val Loss: 0.0022
#       Stage 2 Epoch 200 | Loss: 0.0181 | Val Loss: 0.0037
#       Stage 2 Early stopping at epoch 202
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_MLP_OS_NoCSL_0.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9914642153644123, 'prec': 0.4, 'rec': 0.16666666666666666, 'f1': 0.23529411764705882}
# Results ready to be saved to results/eval_first_graph_GAT_MLP_OS_NoCSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GAT + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_MLP_OS_NoCSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0615 | Val Loss: 0.0256
#       Stage 2 Epoch 20 | Loss: 0.0359 | Val Loss: 0.0234
#       Stage 2 Epoch 30 | Loss: 0.0184 | Val Loss: 0.0098
#       Stage 2 Epoch 40 | Loss: 0.0198 | Val Loss: 0.0057
#       Stage 2 Epoch 50 | Loss: 0.0180 | Val Loss: 0.0036
#       Stage 2 Epoch 60 | Loss: 0.0159 | Val Loss: 0.0037
#       Stage 2 Epoch 70 | Loss: 0.0173 | Val Loss: 0.0053
#       Stage 2 Epoch 80 | Loss: 0.0193 | Val Loss: 0.0028
#       Stage 2 Epoch 90 | Loss: 0.0213 | Val Loss: 0.0109
#       Stage 2 Epoch 100 | Loss: 0.0219 | Val Loss: 0.0049
#       Stage 2 Epoch 110 | Loss: 0.0116 | Val Loss: 0.0030
#       Stage 2 Epoch 120 | Loss: 0.0158 | Val Loss: 0.0022
#       Stage 2 Epoch 130 | Loss: 0.0119 | Val Loss: 0.0041
#       Stage 2 Epoch 140 | Loss: 0.0206 | Val Loss: 0.0053
#       Stage 2 Epoch 150 | Loss: 0.0128 | Val Loss: 0.0033
#       Stage 2 Epoch 160 | Loss: 0.0202 | Val Loss: 0.0091
#       Stage 2 Epoch 170 | Loss: 0.0169 | Val Loss: 0.0015
#       Stage 2 Epoch 180 | Loss: 0.0199 | Val Loss: 0.0031
#       Stage 2 Epoch 190 | Loss: 0.0195 | Val Loss: 0.0044
#       Stage 2 Early stopping at epoch 196
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_MLP_OS_NoCSL_42.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9921208141825345, 'prec': 0.5, 'rec': 0.16666666666666666, 'f1': 0.25}
# Results ready to be saved to results/eval_first_graph_GAT_MLP_OS_NoCSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GAT + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_MLP_OS_NoCSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0806 | Val Loss: 0.0566
#       Stage 2 Epoch 20 | Loss: 0.0673 | Val Loss: 0.0353
#       Stage 2 Epoch 30 | Loss: 0.0379 | Val Loss: 0.0111
#       Stage 2 Epoch 40 | Loss: 0.0191 | Val Loss: 0.0165
#       Stage 2 Epoch 50 | Loss: 0.0185 | Val Loss: 0.0095
#       Stage 2 Epoch 60 | Loss: 0.0222 | Val Loss: 0.0040
#       Stage 2 Epoch 70 | Loss: 0.0183 | Val Loss: 0.0037
#       Stage 2 Epoch 80 | Loss: 0.0167 | Val Loss: 0.0055
#       Stage 2 Epoch 90 | Loss: 0.0165 | Val Loss: 0.0026
#       Stage 2 Epoch 100 | Loss: 0.0217 | Val Loss: 0.0032
#       Stage 2 Epoch 110 | Loss: 0.0179 | Val Loss: 0.0044
#       Stage 2 Epoch 120 | Loss: 0.0185 | Val Loss: 0.0155
#       Stage 2 Epoch 130 | Loss: 0.0161 | Val Loss: 0.0042
#       Stage 2 Early stopping at epoch 139
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_MLP_OS_NoCSL_101.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9927774130006566, 'prec': 0.5714285714285714, 'rec': 0.3333333333333333, 'f1': 0.4210526315789474}
# Results ready to be saved to results/eval_first_graph_GAT_MLP_OS_NoCSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GAT + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_MLP_OS_NoCSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.0566 | Val Loss: 0.0073
#       Stage 2 Epoch 20 | Loss: 0.0446 | Val Loss: 0.0306
#       Stage 2 Epoch 30 | Loss: 0.0275 | Val Loss: 0.0089
#       Stage 2 Epoch 40 | Loss: 0.0174 | Val Loss: 0.0051
#       Stage 2 Epoch 50 | Loss: 0.0178 | Val Loss: 0.0119
#       Stage 2 Epoch 60 | Loss: 0.0196 | Val Loss: 0.0134
#       Stage 2 Epoch 70 | Loss: 0.0302 | Val Loss: 0.0112
#       Stage 2 Epoch 80 | Loss: 0.0166 | Val Loss: 0.0036
#       Stage 2 Epoch 90 | Loss: 0.0199 | Val Loss: 0.0162
#       Stage 2 Epoch 100 | Loss: 0.0186 | Val Loss: 0.0035
#       Stage 2 Epoch 110 | Loss: 0.0206 | Val Loss: 0.0161
#       Stage 2 Epoch 120 | Loss: 0.0175 | Val Loss: 0.0209
#       Stage 2 Epoch 130 | Loss: 0.0165 | Val Loss: 0.0130
#       Stage 2 Epoch 140 | Loss: 0.0158 | Val Loss: 0.0135
#       Stage 2 Epoch 150 | Loss: 0.0155 | Val Loss: 0.0146
#       Stage 2 Early stopping at epoch 157
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_MLP_OS_NoCSL_1024.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9914642153644123, 'prec': 0.4, 'rec': 0.16666666666666666, 'f1': 0.23529411764705882}
# Results ready to be saved to results/eval_first_graph_GAT_MLP_OS_NoCSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GAT + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_MLP_OS_NoCSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.0339 | Val Loss: 0.0029
#       Stage 2 Epoch 20 | Loss: 0.0197 | Val Loss: 0.0049
#       Stage 2 Epoch 30 | Loss: 0.0271 | Val Loss: 0.0383
#       Stage 2 Epoch 40 | Loss: 0.0227 | Val Loss: 0.0053
#       Stage 2 Epoch 50 | Loss: 0.0199 | Val Loss: 0.0155
#       Stage 2 Epoch 60 | Loss: 0.0180 | Val Loss: 0.0172
#       Stage 2 Epoch 70 | Loss: 0.0166 | Val Loss: 0.0112
#       Stage 2 Epoch 80 | Loss: 0.0202 | Val Loss: 0.0033
#       Stage 2 Epoch 90 | Loss: 0.0266 | Val Loss: 0.0233
#       Stage 2 Epoch 100 | Loss: 0.0199 | Val Loss: 0.0029
#       Stage 2 Epoch 110 | Loss: 0.0150 | Val Loss: 0.0049
#       Stage 2 Epoch 120 | Loss: 0.0215 | Val Loss: 0.0093
#       Stage 2 Epoch 130 | Loss: 0.0211 | Val Loss: 0.0023
#       Stage 2 Early stopping at epoch 134
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_MLP_OS_NoCSL_2025.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9921208141825345, 'prec': 0.5, 'rec': 0.16666666666666666, 'f1': 0.25}
# Results ready to be saved to results/eval_first_graph_GAT_MLP_OS_NoCSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/etehereum-balanced-gd/graph_data/graphgan_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GraphSAGE \
--classifier MLP \
--epochs_stage2 1000 --patience 100 --use_oversampling --output_file
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/etehereum-balanced-gd/graph_data/graphgan_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 6290 nodes and 17269 edges
# Merge Info: 6091 overlapping nodes (anchors), 199 new synthetic nodes.
# Num nodes 7812 | Features: torch.Size([7812, 28]) | Fraud Train: 238 | Fraud Val: 4 | Fraud Test: 12
# Final Split | Train: 5680 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7812, Edges: 25308, Features: 28
#
# Starting Experiments with 5 seeds. Max Epochs: 1000, Patience: 100
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GraphSAGE + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_MLP_OS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0106 | Val Loss: 0.0068
#       Stage 2 Epoch 20 | Loss: 0.0035 | Val Loss: 0.0002
#       Stage 2 Epoch 30 | Loss: 0.0011 | Val Loss: 0.0018
#       Stage 2 Epoch 40 | Loss: 0.0001 | Val Loss: 0.0007
#       Stage 2 Epoch 50 | Loss: 0.0001 | Val Loss: 0.0002
#       Stage 2 Epoch 60 | Loss: 0.0004 | Val Loss: 0.0035
#       Stage 2 Epoch 70 | Loss: 0.0002 | Val Loss: 0.0002
#       Stage 2 Epoch 80 | Loss: 0.0005 | Val Loss: 0.0002
#       Stage 2 Epoch 90 | Loss: 0.0004 | Val Loss: 0.0004
#       Stage 2 Epoch 100 | Loss: 0.0006 | Val Loss: 0.0003
#       Stage 2 Epoch 110 | Loss: 0.0005 | Val Loss: 0.0004
#       Stage 2 Early stopping at epoch 120
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_0.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9921208141825345, 'prec': 0.5, 'rec': 0.16666666666666666, 'f1': 0.25}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GraphSAGE + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_MLP_OS_NoCSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0067 | Val Loss: 0.0073
#       Stage 2 Epoch 20 | Loss: 0.0026 | Val Loss: 0.0065
#       Stage 2 Epoch 30 | Loss: 0.0006 | Val Loss: 0.0001
#       Stage 2 Epoch 40 | Loss: 0.0002 | Val Loss: 0.0003
#       Stage 2 Epoch 50 | Loss: 0.0001 | Val Loss: 0.0001
#       Stage 2 Epoch 60 | Loss: 0.0003 | Val Loss: 0.0002
#       Stage 2 Epoch 70 | Loss: 0.0003 | Val Loss: 0.0001
#       Stage 2 Epoch 80 | Loss: 0.0008 | Val Loss: 0.0002
#       Stage 2 Epoch 90 | Loss: 0.0004 | Val Loss: 0.0004
#       Stage 2 Epoch 100 | Loss: 0.0004 | Val Loss: 0.0004
#       Stage 2 Epoch 110 | Loss: 0.0004 | Val Loss: 0.0003
#       Stage 2 Early stopping at epoch 119
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_42.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9934340118187788, 'prec': 0.6, 'rec': 0.5, 'f1': 0.5454545454545454}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GraphSAGE + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_MLP_OS_NoCSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0079 | Val Loss: 0.0115
#       Stage 2 Epoch 20 | Loss: 0.0050 | Val Loss: 0.0016
#       Stage 2 Epoch 30 | Loss: 0.0002 | Val Loss: 0.0000
#       Stage 2 Epoch 40 | Loss: 0.0011 | Val Loss: 0.0000
#       Stage 2 Epoch 50 | Loss: 0.0002 | Val Loss: 0.0000
#       Stage 2 Epoch 60 | Loss: 0.0002 | Val Loss: 0.0001
#       Stage 2 Epoch 70 | Loss: 0.0008 | Val Loss: 0.0003
#       Stage 2 Epoch 80 | Loss: 0.0004 | Val Loss: 0.0005
#       Stage 2 Epoch 90 | Loss: 0.0006 | Val Loss: 0.0005
#       Stage 2 Epoch 100 | Loss: 0.0007 | Val Loss: 0.0003
#       Stage 2 Epoch 110 | Loss: 0.0008 | Val Loss: 0.0004
#       Stage 2 Early stopping at epoch 117
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_101.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9921208141825345, 'prec': 0.5, 'rec': 0.25, 'f1': 0.3333333333333333}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GraphSAGE + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_MLP_OS_NoCSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.0055 | Val Loss: 0.0083
#       Stage 2 Epoch 20 | Loss: 0.0067 | Val Loss: 0.0004
#       Stage 2 Epoch 30 | Loss: 0.0007 | Val Loss: 0.0020
#       Stage 2 Epoch 40 | Loss: 0.0006 | Val Loss: 0.0009
#       Stage 2 Epoch 50 | Loss: 0.0002 | Val Loss: 0.0001
#       Stage 2 Epoch 60 | Loss: 0.0010 | Val Loss: 0.0017
#       Stage 2 Epoch 70 | Loss: 0.0004 | Val Loss: 0.0003
#       Stage 2 Epoch 80 | Loss: 0.0003 | Val Loss: 0.0004
#       Stage 2 Epoch 90 | Loss: 0.0014 | Val Loss: 0.0002
#       Stage 2 Epoch 100 | Loss: 0.0006 | Val Loss: 0.0004
#       Stage 2 Epoch 110 | Loss: 0.0009 | Val Loss: 0.0005
#       Stage 2 Early stopping at epoch 118
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_1024.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9921208141825345, 'prec': 0.5, 'rec': 0.25, 'f1': 0.3333333333333333}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GraphSAGE + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_MLP_OS_NoCSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.0069 | Val Loss: 0.0108
#       Stage 2 Epoch 20 | Loss: 0.0020 | Val Loss: 0.0032
#       Stage 2 Epoch 30 | Loss: 0.0005 | Val Loss: 0.0000
#       Stage 2 Epoch 40 | Loss: 0.0001 | Val Loss: 0.0000
#       Stage 2 Epoch 50 | Loss: 0.0009 | Val Loss: 0.0004
#       Stage 2 Epoch 60 | Loss: 0.0006 | Val Loss: 0.0051
#       Stage 2 Epoch 70 | Loss: 0.0004 | Val Loss: 0.0017
#       Stage 2 Epoch 80 | Loss: 0.0003 | Val Loss: 0.0002
#       Stage 2 Epoch 90 | Loss: 0.0006 | Val Loss: 0.0003
#       Stage 2 Epoch 100 | Loss: 0.0006 | Val Loss: 0.0005
#       Stage 2 Epoch 110 | Loss: 0.0004 | Val Loss: 0.0004
#       Stage 2 Early stopping at epoch 119
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_2025.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9927774130006566, 'prec': 0.5555555555555556, 'rec': 0.4166666666666667, 'f1': 0.4761904761904762}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/etehereum-balanced-gd/graph_data/graphgan_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GIN \
--classifier MLP \
--epochs_stage2 1000 --patience 100 --use_oversampling --output_file
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/etehereum-balanced-gd/graph_data/graphgan_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 6290 nodes and 17269 edges
# Merge Info: 6091 overlapping nodes (anchors), 199 new synthetic nodes.
# Num nodes 7812 | Features: torch.Size([7812, 28]) | Fraud Train: 238 | Fraud Val: 4 | Fraud Test: 12
# Final Split | Train: 5680 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7812, Edges: 25308, Features: 28
#
# Starting Experiments with 5 seeds. Max Epochs: 1000, Patience: 100
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GIN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_MLP_OS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0119 | Val Loss: 0.0112
#       Stage 2 Epoch 20 | Loss: 0.0026 | Val Loss: 0.0047
#       Stage 2 Epoch 30 | Loss: 0.0027 | Val Loss: 0.0045
#       Stage 2 Epoch 40 | Loss: 0.0026 | Val Loss: 0.0043
#       Stage 2 Epoch 50 | Loss: 0.0018 | Val Loss: 0.0003
#       Stage 2 Epoch 60 | Loss: 0.0019 | Val Loss: 0.0000
#       Stage 2 Epoch 70 | Loss: 0.0019 | Val Loss: 0.0001
#       Stage 2 Epoch 80 | Loss: 0.0016 | Val Loss: 0.0005
#       Stage 2 Epoch 90 | Loss: 0.0018 | Val Loss: 0.0003
#       Stage 2 Epoch 100 | Loss: 0.0017 | Val Loss: 0.0002
#       Stage 2 Epoch 110 | Loss: 0.0019 | Val Loss: 0.0003
#       Stage 2 Early stopping at epoch 116
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_MLP_OS_NoCSL_0.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9908076165462902, 'prec': 0.25, 'rec': 0.08333333333333333, 'f1': 0.125}
# Results ready to be saved to results/eval_first_graph_GIN_MLP_OS_NoCSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GIN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_MLP_OS_NoCSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0097 | Val Loss: 0.0107
#       Stage 2 Epoch 20 | Loss: 0.0023 | Val Loss: 0.0011
#       Stage 2 Epoch 30 | Loss: 0.0020 | Val Loss: 0.0001
#       Stage 2 Epoch 40 | Loss: 0.0020 | Val Loss: 0.0008
#       Stage 2 Epoch 50 | Loss: 0.0026 | Val Loss: 0.0053
#       Stage 2 Epoch 60 | Loss: 0.0028 | Val Loss: 0.0024
#       Stage 2 Epoch 70 | Loss: 0.0024 | Val Loss: 0.0002
#       Stage 2 Epoch 80 | Loss: 0.0019 | Val Loss: 0.0006
#       Stage 2 Epoch 90 | Loss: 0.0017 | Val Loss: 0.0003
#       Stage 2 Epoch 100 | Loss: 0.0019 | Val Loss: 0.0005
#       Stage 2 Epoch 110 | Loss: 0.0020 | Val Loss: 0.0004
#       Stage 2 Epoch 120 | Loss: 0.0018 | Val Loss: 0.0023
#       Stage 2 Epoch 130 | Loss: 0.0021 | Val Loss: 0.0005
#       Stage 2 Early stopping at epoch 133
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_MLP_OS_NoCSL_42.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9908076165462902, 'prec': 0.25, 'rec': 0.08333333333333333, 'f1': 0.125}
# Results ready to be saved to results/eval_first_graph_GIN_MLP_OS_NoCSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GIN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_MLP_OS_NoCSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0077 | Val Loss: 0.0105
#       Stage 2 Epoch 20 | Loss: 0.0022 | Val Loss: 0.0001
#       Stage 2 Epoch 30 | Loss: 0.0023 | Val Loss: 0.0034
#       Stage 2 Epoch 40 | Loss: 0.0021 | Val Loss: 0.0002
#       Stage 2 Epoch 50 | Loss: 0.0019 | Val Loss: 0.0007
#       Stage 2 Epoch 60 | Loss: 0.0017 | Val Loss: 0.0005
#       Stage 2 Epoch 70 | Loss: 0.0020 | Val Loss: 0.0038
#       Stage 2 Epoch 80 | Loss: 0.0018 | Val Loss: 0.0002
#       Stage 2 Epoch 90 | Loss: 0.0020 | Val Loss: 0.0025
#       Stage 2 Epoch 100 | Loss: 0.0017 | Val Loss: 0.0003
#       Stage 2 Epoch 110 | Loss: 0.0018 | Val Loss: 0.0007
#       Stage 2 Early stopping at epoch 114
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_MLP_OS_NoCSL_101.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9875246224556796, 'prec': 0.18181818181818182, 'rec': 0.16666666666666666, 'f1': 0.17391304347826086}
# Results ready to be saved to results/eval_first_graph_GIN_MLP_OS_NoCSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GIN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_MLP_OS_NoCSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.0030 | Val Loss: 0.0040
#       Stage 2 Epoch 20 | Loss: 0.0021 | Val Loss: 0.0002
#       Stage 2 Epoch 30 | Loss: 0.0018 | Val Loss: 0.0013
#       Stage 2 Epoch 40 | Loss: 0.0024 | Val Loss: 0.0003
#       Stage 2 Epoch 50 | Loss: 0.0019 | Val Loss: 0.0002
#       Stage 2 Epoch 60 | Loss: 0.0021 | Val Loss: 0.0001
#       Stage 2 Epoch 70 | Loss: 0.0018 | Val Loss: 0.0002
#       Stage 2 Epoch 80 | Loss: 0.0018 | Val Loss: 0.0001
#       Stage 2 Epoch 90 | Loss: 0.0020 | Val Loss: 0.0004
#       Stage 2 Epoch 100 | Loss: 0.0017 | Val Loss: 0.0002
#       Stage 2 Epoch 110 | Loss: 0.0021 | Val Loss: 0.0007
#       Stage 2 Early stopping at epoch 113
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_MLP_OS_NoCSL_1024.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9908076165462902, 'prec': 0.25, 'rec': 0.08333333333333333, 'f1': 0.125}
# Results ready to be saved to results/eval_first_graph_GIN_MLP_OS_NoCSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GIN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_MLP_OS_NoCSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.0027 | Val Loss: 0.0030
#       Stage 2 Epoch 20 | Loss: 0.0024 | Val Loss: 0.0038
#       Stage 2 Epoch 30 | Loss: 0.0025 | Val Loss: 0.0000
#       Stage 2 Epoch 40 | Loss: 0.0026 | Val Loss: 0.0043
#       Stage 2 Epoch 50 | Loss: 0.0018 | Val Loss: 0.0045
#       Stage 2 Epoch 60 | Loss: 0.0018 | Val Loss: 0.0002
#       Stage 2 Epoch 70 | Loss: 0.0017 | Val Loss: 0.0003
#       Stage 2 Epoch 80 | Loss: 0.0018 | Val Loss: 0.0002
#       Stage 2 Epoch 90 | Loss: 0.0021 | Val Loss: 0.0005
#       Stage 2 Epoch 100 | Loss: 0.0018 | Val Loss: 0.0001
#       Stage 2 Epoch 110 | Loss: 0.0019 | Val Loss: 0.0008
#       Stage 2 Early stopping at epoch 118
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_MLP_OS_NoCSL_2025.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: MLP, Oversample: True, CSL: False
# {'acc': 0.9908076165462902, 'prec': 0.25, 'rec': 0.08333333333333333, 'f1': 0.125}
# Results ready to be saved to results/eval_first_graph_GIN_MLP_OS_NoCSL_2025.json

# %%
# !cd /kaggle/working/results
# !zip -r G1-MLP-GAN-NoCSL.zip /kaggle/working/results/
# Out:
#   adding: kaggle/working/results/ (stored 0%)
#   adding: kaggle/working/results/eval_first_graph_GCN_MLP_OS_NoCSL_101.json (deflated 37%)
#   adding: kaggle/working/results/eval_first_graph_GAT_MLP_OS_NoCSL_42.json (deflated 38%)
#   adding: kaggle/working/results/eval_first_graph_GAT_MLP_OS_NoCSL_2025.json (deflated 38%)
#   adding: kaggle/working/results/eval_first_graph_GCN_MLP_OS_NoCSL_42.json (deflated 39%)
#   adding: kaggle/working/results/pred_first_graph_GIN_MLP_OS_NoCSL_101.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GAT_MLP_OS_NoCSL_1024.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GAT_MLP_OS_NoCSL_42.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GCN_MLP_OS_NoCSL_42.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GAT_MLP_OS_NoCSL_1024.json (deflated 37%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_1024.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GIN_MLP_OS_NoCSL_1024.json (deflated 38%)
#   adding: kaggle/working/results/pred_first_graph_GIN_MLP_OS_NoCSL_42.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_2025.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_2025.json (deflated 42%)
#   adding: kaggle/working/results/pred_first_graph_GCN_MLP_OS_NoCSL_0.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GCN_MLP_OS_NoCSL_0.json (deflated 37%)
#   adding: kaggle/working/results/pred_first_graph_GIN_MLP_OS_NoCSL_2025.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GCN_MLP_OS_NoCSL_1024.json (deflated 38%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_101.json (deflated 38%)
#   adding: kaggle/working/results/pred_first_graph_GCN_MLP_OS_NoCSL_2025.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GAT_MLP_OS_NoCSL_0.json (deflated 37%)
#   adding: kaggle/working/results/pred_first_graph_GAT_MLP_OS_NoCSL_2025.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_0.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GAT_MLP_OS_NoCSL_101.json (deflated 39%)
#   adding: kaggle/working/results/pred_first_graph_GAT_MLP_OS_NoCSL_101.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GIN_MLP_OS_NoCSL_101.json (deflated 40%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_42.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GIN_MLP_OS_NoCSL_0.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GIN_MLP_OS_NoCSL_2025.json (deflated 38%)
#   adding: kaggle/working/results/pred_first_graph_GCN_MLP_OS_NoCSL_101.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GCN_MLP_OS_NoCSL_1024.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_1024.json (deflated 38%)
#   adding: kaggle/working/results/eval_first_graph_GIN_MLP_OS_NoCSL_42.json (deflated 38%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_0.json (deflated 37%)
#   adding: kaggle/working/results/pred_first_graph_GIN_MLP_OS_NoCSL_1024.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GCN_MLP_OS_NoCSL_2025.json (deflated 45%)
#   adding: kaggle/working/results/eval_first_graph_GIN_MLP_OS_NoCSL_0.json (deflated 38%)
#   adding: kaggle/working/results/pred_first_graph_GAT_MLP_OS_NoCSL_0.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_MLP_OS_NoCSL_42.json (deflated 37%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_MLP_OS_NoCSL_101.csv (deflated 98%)
