# %%
# !pip install torch_geometric
# !pip install git+https://github.com/Blealtan/efficient-kan.git
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.13.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2025.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (7.1.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2025.10.5)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal>=1.4.0->aiohttp->torch_geometric) (4.15.0)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torch_geometric) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torch_geometric) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torch_geometric) (2024.2.0)
# Downloading torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 28.6 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.7.0
# Collecting git+https://github.com/Blealtan/efficient-kan.git
#   Cloning https://github.com/Blealtan/efficient-kan.git to /tmp/pip-req-build-y_0zzcoj
#   Running command git clone --filter=blob:none --quiet https://github.com/Blealtan/efficient-kan.git /tmp/pip-req-build-y_0zzcoj
#   Resolved https://github.com/Blealtan/efficient-kan.git to commit 7b6ce1c87f18c8bc90c208f6b494042344216b11
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (2.6.0+cu124)
# Requirement already satisfied: pytest>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (8.4.1)
# Requirement already satisfied: tqdm>=4.66.2 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (4.67.1)
# Requirement already satisfied: torchvision>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (0.21.0+cu124)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (2.1.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (25.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (2.19.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (2025.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.3.0->efficient-kan==0.1.0) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.18.0->efficient-kan==0.1.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.18.0->efficient-kan==0.1.0) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.3.0->efficient-kan==0.1.0) (3.0.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2.4.1)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 107.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 34.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.9 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 102.6 MB/s eta 0:00:00
# Building wheels for collected packages: efficient-kan
#   Building wheel for efficient-kan (pyproject.toml) ... done
#   Created wheel for efficient-kan: filename=efficient_kan-0.1.0-py3-none-any.whl size=5981 sha256=3fadb37365bda971d6bcb716e5ecf58aca9c70ee79e32324453796857b325548
#   Stored in directory: /tmp/pip-ephem-wheel-cache-e2iuwo2o/wheels/da/a3/b4/30b3e3df2edaded3c87227cb9faea5878f18ec03e1c2137839
# Successfully built efficient-kan
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, efficient-kan
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed efficient-kan-0.1.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !git clone https://agusth24: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@github.com/agusth24/ethereum-fraud-detection.git
# Out:
# Cloning into 'ethereum-fraud-detection'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 51 (delta 23), reused 45 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (51/51), 14.72 KiB | 3.68 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/etehereum-balanced-gd/graph_data/graphgan_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GCN \
--classifier CNN \
--epochs_stage2 200 --patience 50 --use_oversampling --output_file
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/etehereum-balanced-gd/graph_data/graphgan_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 6290 nodes and 17269 edges
# Merge Info: 6091 overlapping nodes (anchors), 199 new synthetic nodes.
# Num nodes 7812 | Features: torch.Size([7812, 28]) | Fraud Train: 238 | Fraud Val: 4 | Fraud Test: 12
# Final Split | Train: 5680 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7812, Edges: 25308, Features: 28
#
# Starting Experiments with 5 seeds. Max Epochs: 200, Patience: 50
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GCN + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_CNN_OS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.1030 | Val Loss: 0.0187
#       Stage 2 Epoch 20 | Loss: 0.0365 | Val Loss: 0.0119
#       Stage 2 Epoch 30 | Loss: 0.0320 | Val Loss: 0.0059
#       Stage 2 Epoch 40 | Loss: 0.0088 | Val Loss: 0.0028
#       Stage 2 Epoch 50 | Loss: 0.0031 | Val Loss: 0.0063
#       Stage 2 Epoch 60 | Loss: 0.0029 | Val Loss: 0.0091
#       Stage 2 Epoch 70 | Loss: 0.0025 | Val Loss: 0.0064
#       Stage 2 Epoch 80 | Loss: 0.0026 | Val Loss: 0.0020
#       Stage 2 Epoch 90 | Loss: 0.0027 | Val Loss: 0.0051
#       Stage 2 Epoch 100 | Loss: 0.0052 | Val Loss: 0.0010
#       Stage 2 Early stopping at epoch 108
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_CNN_OS_NoCSL_0.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9914642153644123, 'prec': 0.4, 'rec': 0.16666666666666666, 'f1': 0.23529411764705882}
# Results ready to be saved to results/eval_first_graph_GCN_CNN_OS_NoCSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GCN + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_CNN_OS_NoCSL_42...
#       Stage 2 Epoch 10 | Loss: 0.1696 | Val Loss: 0.0390
#       Stage 2 Epoch 20 | Loss: 0.1749 | Val Loss: 0.0381
#       Stage 2 Epoch 30 | Loss: 0.1364 | Val Loss: 0.0643
#       Stage 2 Epoch 40 | Loss: 0.0643 | Val Loss: 0.0147
#       Stage 2 Epoch 50 | Loss: 0.0151 | Val Loss: 0.0068
#       Stage 2 Epoch 60 | Loss: 0.0040 | Val Loss: 0.0075
#       Stage 2 Epoch 70 | Loss: 0.0033 | Val Loss: 0.0070
#       Stage 2 Epoch 80 | Loss: 0.0034 | Val Loss: 0.0060
#       Stage 2 Epoch 90 | Loss: 0.0031 | Val Loss: 0.0066
#       Stage 2 Epoch 100 | Loss: 0.0033 | Val Loss: 0.0052
#       Stage 2 Epoch 110 | Loss: 0.0037 | Val Loss: 0.0054
#       Stage 2 Epoch 120 | Loss: 0.0037 | Val Loss: 0.0052
#       Stage 2 Epoch 130 | Loss: 0.0030 | Val Loss: 0.0005
#       Stage 2 Epoch 140 | Loss: 0.0030 | Val Loss: 0.0054
#       Stage 2 Early stopping at epoch 143
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_CNN_OS_NoCSL_42.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9908076165462902, 'prec': 0.25, 'rec': 0.08333333333333333, 'f1': 0.125}
# Results ready to be saved to results/eval_first_graph_GCN_CNN_OS_NoCSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GCN + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_CNN_OS_NoCSL_101...
#       Stage 2 Epoch 10 | Loss: 0.1411 | Val Loss: 0.0221
#       Stage 2 Epoch 20 | Loss: 0.0516 | Val Loss: 0.0225
#       Stage 2 Epoch 30 | Loss: 0.0379 | Val Loss: 0.0100
#       Stage 2 Epoch 40 | Loss: 0.0349 | Val Loss: 0.0070
#       Stage 2 Epoch 50 | Loss: 0.0323 | Val Loss: 0.0061
#       Stage 2 Epoch 60 | Loss: 0.0309 | Val Loss: 0.0061
#       Stage 2 Epoch 70 | Loss: 0.0296 | Val Loss: 0.0054
#       Stage 2 Epoch 80 | Loss: 0.0281 | Val Loss: 0.0058
#       Stage 2 Epoch 90 | Loss: 0.0272 | Val Loss: 0.0056
#       Stage 2 Epoch 100 | Loss: 0.0255 | Val Loss: 0.0055
#       Stage 2 Epoch 110 | Loss: 0.0254 | Val Loss: 0.0053
#       Stage 2 Epoch 120 | Loss: 0.0230 | Val Loss: 0.0051
#       Stage 2 Epoch 130 | Loss: 0.0234 | Val Loss: 0.0048
#       Stage 2 Epoch 140 | Loss: 0.0209 | Val Loss: 0.0039
#       Stage 2 Epoch 150 | Loss: 0.0197 | Val Loss: 0.0047
#       Stage 2 Epoch 160 | Loss: 0.0184 | Val Loss: 0.0048
#       Stage 2 Early stopping at epoch 169
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_CNN_OS_NoCSL_101.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9921208141825345, 'prec': 0.5, 'rec': 0.08333333333333333, 'f1': 0.14285714285714285}
# Results ready to be saved to results/eval_first_graph_GCN_CNN_OS_NoCSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GCN + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_CNN_OS_NoCSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.1692 | Val Loss: 0.0300
#       Stage 2 Epoch 20 | Loss: 0.0779 | Val Loss: 0.0230
#       Stage 2 Epoch 30 | Loss: 0.0454 | Val Loss: 0.0194
#       Stage 2 Epoch 40 | Loss: 0.0365 | Val Loss: 0.0072
#       Stage 2 Epoch 50 | Loss: 0.0332 | Val Loss: 0.0067
#       Stage 2 Epoch 60 | Loss: 0.0325 | Val Loss: 0.0060
#       Stage 2 Epoch 70 | Loss: 0.0307 | Val Loss: 0.0060
#       Stage 2 Epoch 80 | Loss: 0.0297 | Val Loss: 0.0059
#       Stage 2 Epoch 90 | Loss: 0.0222 | Val Loss: 0.0049
#       Stage 2 Epoch 100 | Loss: 0.0056 | Val Loss: 0.0041
#       Stage 2 Epoch 110 | Loss: 0.0032 | Val Loss: 0.0031
#       Stage 2 Epoch 120 | Loss: 0.0029 | Val Loss: 0.0066
#       Stage 2 Epoch 130 | Loss: 0.0028 | Val Loss: 0.0064
#       Stage 2 Epoch 140 | Loss: 0.0028 | Val Loss: 0.0035
#       Stage 2 Epoch 150 | Loss: 0.0037 | Val Loss: 0.0054
#       Stage 2 Epoch 160 | Loss: 0.0031 | Val Loss: 0.0068
#       Stage 2 Epoch 170 | Loss: 0.0027 | Val Loss: 0.0053
#       Stage 2 Early stopping at epoch 176
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_CNN_OS_NoCSL_1024.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9908076165462902, 'prec': 0.25, 'rec': 0.08333333333333333, 'f1': 0.125}
# Results ready to be saved to results/eval_first_graph_GCN_CNN_OS_NoCSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GCN + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_CNN_OS_NoCSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.1639 | Val Loss: 0.0426
#       Stage 2 Epoch 20 | Loss: 0.1544 | Val Loss: 0.0349
#       Stage 2 Epoch 30 | Loss: 0.1274 | Val Loss: 0.0558
#       Stage 2 Epoch 40 | Loss: 0.0972 | Val Loss: 0.0295
#       Stage 2 Epoch 50 | Loss: 0.0844 | Val Loss: 0.0298
#       Stage 2 Epoch 60 | Loss: 0.0683 | Val Loss: 0.0271
#       Stage 2 Epoch 70 | Loss: 0.0521 | Val Loss: 0.0121
#       Stage 2 Epoch 80 | Loss: 0.0412 | Val Loss: 0.0096
#       Stage 2 Epoch 90 | Loss: 0.0371 | Val Loss: 0.0082
#       Stage 2 Epoch 100 | Loss: 0.0339 | Val Loss: 0.0072
#       Stage 2 Epoch 110 | Loss: 0.0318 | Val Loss: 0.0067
#       Stage 2 Epoch 120 | Loss: 0.0307 | Val Loss: 0.0063
#       Stage 2 Epoch 130 | Loss: 0.0273 | Val Loss: 0.0058
#       Stage 2 Epoch 140 | Loss: 0.0058 | Val Loss: 0.0053
#       Stage 2 Epoch 150 | Loss: 0.0024 | Val Loss: 0.0049
#       Stage 2 Epoch 160 | Loss: 0.0030 | Val Loss: 0.0052
#       Stage 2 Epoch 170 | Loss: 0.0035 | Val Loss: 0.0072
#       Stage 2 Epoch 180 | Loss: 0.0027 | Val Loss: 0.0062
#       Stage 2 Epoch 190 | Loss: 0.0027 | Val Loss: 0.0054
#       Stage 2 Epoch 200 | Loss: 0.0020 | Val Loss: 0.0063
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_CNN_OS_NoCSL_2025.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9914642153644123, 'prec': 0.4, 'rec': 0.16666666666666666, 'f1': 0.23529411764705882}
# Results ready to be saved to results/eval_first_graph_GCN_CNN_OS_NoCSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/etehereum-balanced-gd/graph_data/graphgan_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GAT \
--classifier CNN \
--epochs_stage2 200 --patience 50 --use_oversampling --output_file
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/etehereum-balanced-gd/graph_data/graphgan_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 6290 nodes and 17269 edges
# Merge Info: 6091 overlapping nodes (anchors), 199 new synthetic nodes.
# Num nodes 7812 | Features: torch.Size([7812, 28]) | Fraud Train: 238 | Fraud Val: 4 | Fraud Test: 12
# Final Split | Train: 5680 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7812, Edges: 25308, Features: 28
#
# Starting Experiments with 5 seeds. Max Epochs: 200, Patience: 50
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GAT + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_CNN_OS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.1038 | Val Loss: 0.0198
#       Stage 2 Epoch 20 | Loss: 0.0495 | Val Loss: 0.0081
#       Stage 2 Epoch 30 | Loss: 0.0307 | Val Loss: 0.0087
#       Stage 2 Epoch 40 | Loss: 0.0205 | Val Loss: 0.0053
#       Stage 2 Epoch 50 | Loss: 0.0214 | Val Loss: 0.0023
#       Stage 2 Epoch 60 | Loss: 0.0167 | Val Loss: 0.0048
#       Stage 2 Epoch 70 | Loss: 0.0130 | Val Loss: 0.0039
#       Stage 2 Epoch 80 | Loss: 0.0172 | Val Loss: 0.0034
#       Stage 2 Early stopping at epoch 88
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_CNN_OS_NoCSL_0.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9921208141825345, 'prec': 0.5, 'rec': 0.16666666666666666, 'f1': 0.25}
# Results ready to be saved to results/eval_first_graph_GAT_CNN_OS_NoCSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GAT + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_CNN_OS_NoCSL_42...
#       Stage 2 Epoch 10 | Loss: 0.1847 | Val Loss: 0.0342
#       Stage 2 Epoch 20 | Loss: 0.1502 | Val Loss: 0.0526
#       Stage 2 Epoch 30 | Loss: 0.1105 | Val Loss: 0.0352
#       Stage 2 Epoch 40 | Loss: 0.0647 | Val Loss: 0.0164
#       Stage 2 Epoch 50 | Loss: 0.0473 | Val Loss: 0.0103
#       Stage 2 Epoch 60 | Loss: 0.0448 | Val Loss: 0.0133
#       Stage 2 Epoch 70 | Loss: 0.0449 | Val Loss: 0.0097
#       Stage 2 Epoch 80 | Loss: 0.0451 | Val Loss: 0.0091
#       Stage 2 Epoch 90 | Loss: 0.0481 | Val Loss: 0.0135
#       Stage 2 Epoch 100 | Loss: 0.0455 | Val Loss: 0.0098
#       Stage 2 Epoch 110 | Loss: 0.0375 | Val Loss: 0.0104
#       Stage 2 Epoch 120 | Loss: 0.0379 | Val Loss: 0.0087
#       Stage 2 Epoch 130 | Loss: 0.0340 | Val Loss: 0.0081
#       Stage 2 Epoch 140 | Loss: 0.0386 | Val Loss: 0.0084
#       Stage 2 Epoch 150 | Loss: 0.0261 | Val Loss: 0.0045
#       Stage 2 Epoch 160 | Loss: 0.0244 | Val Loss: 0.0077
#       Stage 2 Epoch 170 | Loss: 0.0195 | Val Loss: 0.0097
#       Stage 2 Epoch 180 | Loss: 0.0235 | Val Loss: 0.0129
#       Stage 2 Epoch 190 | Loss: 0.0233 | Val Loss: 0.0093
#       Stage 2 Epoch 200 | Loss: 0.0215 | Val Loss: 0.0016
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_CNN_OS_NoCSL_42.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9914642153644123, 'prec': 0.4, 'rec': 0.16666666666666666, 'f1': 0.23529411764705882}
# Results ready to be saved to results/eval_first_graph_GAT_CNN_OS_NoCSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GAT + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_CNN_OS_NoCSL_101...
#       Stage 2 Epoch 10 | Loss: 0.1231 | Val Loss: 0.0323
#       Stage 2 Epoch 20 | Loss: 0.0499 | Val Loss: 0.0102
#       Stage 2 Epoch 30 | Loss: 0.0349 | Val Loss: 0.0159
#       Stage 2 Epoch 40 | Loss: 0.0227 | Val Loss: 0.0224
#       Stage 2 Epoch 50 | Loss: 0.0167 | Val Loss: 0.0083
#       Stage 2 Epoch 60 | Loss: 0.0181 | Val Loss: 0.0047
#       Stage 2 Epoch 70 | Loss: 0.0169 | Val Loss: 0.0043
#       Stage 2 Epoch 80 | Loss: 0.0132 | Val Loss: 0.0037
#       Stage 2 Epoch 90 | Loss: 0.0181 | Val Loss: 0.0038
#       Stage 2 Epoch 100 | Loss: 0.0216 | Val Loss: 0.0035
#       Stage 2 Epoch 110 | Loss: 0.0194 | Val Loss: 0.0034
#       Stage 2 Early stopping at epoch 112
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_CNN_OS_NoCSL_101.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9934340118187788, 'prec': 1.0, 'rec': 0.16666666666666666, 'f1': 0.2857142857142857}
# Results ready to be saved to results/eval_first_graph_GAT_CNN_OS_NoCSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GAT + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_CNN_OS_NoCSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.1609 | Val Loss: 0.0367
#       Stage 2 Epoch 20 | Loss: 0.0715 | Val Loss: 0.0253
#       Stage 2 Epoch 30 | Loss: 0.0529 | Val Loss: 0.0202
#       Stage 2 Epoch 40 | Loss: 0.0417 | Val Loss: 0.0138
#       Stage 2 Epoch 50 | Loss: 0.0438 | Val Loss: 0.0139
#       Stage 2 Epoch 60 | Loss: 0.0407 | Val Loss: 0.0125
#       Stage 2 Epoch 70 | Loss: 0.0474 | Val Loss: 0.0090
#       Stage 2 Epoch 80 | Loss: 0.0373 | Val Loss: 0.0072
#       Stage 2 Epoch 90 | Loss: 0.0406 | Val Loss: 0.0085
#       Stage 2 Epoch 100 | Loss: 0.0381 | Val Loss: 0.0074
#       Stage 2 Epoch 110 | Loss: 0.0383 | Val Loss: 0.0079
#       Stage 2 Epoch 120 | Loss: 0.0351 | Val Loss: 0.0073
#       Stage 2 Early stopping at epoch 128
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_CNN_OS_NoCSL_1024.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9921208141825345, 'prec': 0.5, 'rec': 0.16666666666666666, 'f1': 0.25}
# Results ready to be saved to results/eval_first_graph_GAT_CNN_OS_NoCSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GAT + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_CNN_OS_NoCSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.2002 | Val Loss: 0.0327
#       Stage 2 Epoch 20 | Loss: 0.1473 | Val Loss: 0.0614
#       Stage 2 Epoch 30 | Loss: 0.1125 | Val Loss: 0.0360
#       Stage 2 Epoch 40 | Loss: 0.0623 | Val Loss: 0.0150
#       Stage 2 Epoch 50 | Loss: 0.0489 | Val Loss: 0.0147
#       Stage 2 Epoch 60 | Loss: 0.0438 | Val Loss: 0.0122
#       Stage 2 Epoch 70 | Loss: 0.0431 | Val Loss: 0.0143
#       Stage 2 Epoch 80 | Loss: 0.0346 | Val Loss: 0.0076
#       Stage 2 Epoch 90 | Loss: 0.0267 | Val Loss: 0.0122
#       Stage 2 Epoch 100 | Loss: 0.0199 | Val Loss: 0.0098
#       Stage 2 Epoch 110 | Loss: 0.0232 | Val Loss: 0.0039
#       Stage 2 Epoch 120 | Loss: 0.0219 | Val Loss: 0.0144
#       Stage 2 Epoch 130 | Loss: 0.0232 | Val Loss: 0.0025
#       Stage 2 Epoch 140 | Loss: 0.0197 | Val Loss: 0.0061
#       Stage 2 Epoch 150 | Loss: 0.0154 | Val Loss: 0.0039
#       Stage 2 Epoch 160 | Loss: 0.0216 | Val Loss: 0.0038
#       Stage 2 Epoch 170 | Loss: 0.0145 | Val Loss: 0.0031
#       Stage 2 Early stopping at epoch 177
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_CNN_OS_NoCSL_2025.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9927774130006566, 'prec': 0.6666666666666666, 'rec': 0.16666666666666666, 'f1': 0.26666666666666666}
# Results ready to be saved to results/eval_first_graph_GAT_CNN_OS_NoCSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/etehereum-balanced-gd/graph_data/graphgan_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GraphSAGE \
--classifier CNN \
--epochs_stage2 200 --patience 50 --use_oversampling --output_file
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/etehereum-balanced-gd/graph_data/graphgan_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 6290 nodes and 17269 edges
# Merge Info: 6091 overlapping nodes (anchors), 199 new synthetic nodes.
# Num nodes 7812 | Features: torch.Size([7812, 28]) | Fraud Train: 238 | Fraud Val: 4 | Fraud Test: 12
# Final Split | Train: 5680 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7812, Edges: 25308, Features: 28
#
# Starting Experiments with 5 seeds. Max Epochs: 200, Patience: 50
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GraphSAGE + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_CNN_OS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.1082 | Val Loss: 0.0191
#       Stage 2 Epoch 20 | Loss: 0.0443 | Val Loss: 0.0085
#       Stage 2 Epoch 30 | Loss: 0.0298 | Val Loss: 0.0067
#       Stage 2 Epoch 40 | Loss: 0.0217 | Val Loss: 0.0035
#       Stage 2 Epoch 50 | Loss: 0.0048 | Val Loss: 0.0035
#       Stage 2 Epoch 60 | Loss: 0.0011 | Val Loss: 0.0006
#       Stage 2 Epoch 70 | Loss: 0.0005 | Val Loss: 0.0005
#       Stage 2 Epoch 80 | Loss: 0.0006 | Val Loss: 0.0005
#       Stage 2 Epoch 90 | Loss: 0.0007 | Val Loss: 0.0004
#       Stage 2 Epoch 100 | Loss: 0.0004 | Val Loss: 0.0003
#       Stage 2 Early stopping at epoch 102
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_CNN_OS_NoCSL_0.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9934340118187788, 'prec': 1.0, 'rec': 0.16666666666666666, 'f1': 0.2857142857142857}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_CNN_OS_NoCSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GraphSAGE + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_CNN_OS_NoCSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0793 | Val Loss: 0.0132
#       Stage 2 Epoch 20 | Loss: 0.0451 | Val Loss: 0.0093
#       Stage 2 Epoch 30 | Loss: 0.0416 | Val Loss: 0.0097
#       Stage 2 Epoch 40 | Loss: 0.0367 | Val Loss: 0.0074
#       Stage 2 Epoch 50 | Loss: 0.0314 | Val Loss: 0.0049
#       Stage 2 Epoch 60 | Loss: 0.0267 | Val Loss: 0.0045
#       Stage 2 Epoch 70 | Loss: 0.0211 | Val Loss: 0.0034
#       Stage 2 Epoch 80 | Loss: 0.0153 | Val Loss: 0.0025
#       Stage 2 Epoch 90 | Loss: 0.0103 | Val Loss: 0.0019
#       Stage 2 Epoch 100 | Loss: 0.0067 | Val Loss: 0.0013
#       Stage 2 Epoch 110 | Loss: 0.0045 | Val Loss: 0.0009
#       Stage 2 Epoch 120 | Loss: 0.0032 | Val Loss: 0.0007
#       Stage 2 Epoch 130 | Loss: 0.0031 | Val Loss: 0.0030
#       Stage 2 Epoch 140 | Loss: 0.0023 | Val Loss: 0.0006
#       Stage 2 Early stopping at epoch 149
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_CNN_OS_NoCSL_42.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9934340118187788, 'prec': 1.0, 'rec': 0.16666666666666666, 'f1': 0.2857142857142857}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_CNN_OS_NoCSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GraphSAGE + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_CNN_OS_NoCSL_101...
#       Stage 2 Epoch 10 | Loss: 0.1773 | Val Loss: 0.0337
#       Stage 2 Epoch 20 | Loss: 0.1161 | Val Loss: 0.0392
#       Stage 2 Epoch 30 | Loss: 0.0631 | Val Loss: 0.0234
#       Stage 2 Epoch 40 | Loss: 0.0415 | Val Loss: 0.0077
#       Stage 2 Epoch 50 | Loss: 0.0335 | Val Loss: 0.0055
#       Stage 2 Epoch 60 | Loss: 0.0321 | Val Loss: 0.0055
#       Stage 2 Epoch 70 | Loss: 0.0310 | Val Loss: 0.0051
#       Stage 2 Epoch 80 | Loss: 0.0297 | Val Loss: 0.0049
#       Stage 2 Epoch 90 | Loss: 0.0283 | Val Loss: 0.0046
#       Stage 2 Epoch 100 | Loss: 0.0271 | Val Loss: 0.0050
#       Stage 2 Epoch 110 | Loss: 0.0257 | Val Loss: 0.0042
#       Stage 2 Epoch 120 | Loss: 0.0249 | Val Loss: 0.0041
#       Stage 2 Epoch 130 | Loss: 0.0234 | Val Loss: 0.0039
#       Stage 2 Epoch 140 | Loss: 0.0222 | Val Loss: 0.0040
#       Stage 2 Early stopping at epoch 145
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_CNN_OS_NoCSL_101.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9934340118187788, 'prec': 1.0, 'rec': 0.16666666666666666, 'f1': 0.2857142857142857}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_CNN_OS_NoCSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GraphSAGE + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_CNN_OS_NoCSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.1316 | Val Loss: 0.0277
#       Stage 2 Epoch 20 | Loss: 0.0722 | Val Loss: 0.0138
#       Stage 2 Epoch 30 | Loss: 0.0403 | Val Loss: 0.0111
#       Stage 2 Epoch 40 | Loss: 0.0351 | Val Loss: 0.0064
#       Stage 2 Epoch 50 | Loss: 0.0320 | Val Loss: 0.0056
#       Stage 2 Epoch 60 | Loss: 0.0275 | Val Loss: 0.0045
#       Stage 2 Epoch 70 | Loss: 0.0199 | Val Loss: 0.0043
#       Stage 2 Epoch 80 | Loss: 0.0114 | Val Loss: 0.0019
#       Stage 2 Epoch 90 | Loss: 0.0057 | Val Loss: 0.0010
#       Stage 2 Epoch 100 | Loss: 0.0031 | Val Loss: 0.0006
#       Stage 2 Epoch 110 | Loss: 0.0025 | Val Loss: 0.0005
#       Stage 2 Epoch 120 | Loss: 0.0020 | Val Loss: 0.0005
#       Stage 2 Epoch 130 | Loss: 0.0012 | Val Loss: 0.0003
#       Stage 2 Epoch 140 | Loss: 0.0010 | Val Loss: 0.0008
#       Stage 2 Epoch 150 | Loss: 0.0009 | Val Loss: 0.0004
#       Stage 2 Epoch 160 | Loss: 0.0009 | Val Loss: 0.0009
#       Stage 2 Epoch 170 | Loss: 0.0009 | Val Loss: 0.0004
#       Stage 2 Early stopping at epoch 172
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_CNN_OS_NoCSL_1024.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9934340118187788, 'prec': 1.0, 'rec': 0.16666666666666666, 'f1': 0.2857142857142857}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_CNN_OS_NoCSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GraphSAGE + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_CNN_OS_NoCSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.1443 | Val Loss: 0.0399
#       Stage 2 Epoch 20 | Loss: 0.1314 | Val Loss: 0.0249
#       Stage 2 Epoch 30 | Loss: 0.0708 | Val Loss: 0.0264
#       Stage 2 Epoch 40 | Loss: 0.0438 | Val Loss: 0.0126
#       Stage 2 Epoch 50 | Loss: 0.0150 | Val Loss: 0.0066
#       Stage 2 Epoch 60 | Loss: 0.0018 | Val Loss: 0.0014
#       Stage 2 Epoch 70 | Loss: 0.0021 | Val Loss: 0.0011
#       Stage 2 Epoch 80 | Loss: 0.0006 | Val Loss: 0.0005
#       Stage 2 Epoch 90 | Loss: 0.0010 | Val Loss: 0.0004
#       Stage 2 Epoch 100 | Loss: 0.0008 | Val Loss: 0.0007
#       Stage 2 Early stopping at epoch 109
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_CNN_OS_NoCSL_2025.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9947472094550229, 'prec': 1.0, 'rec': 0.3333333333333333, 'f1': 0.5}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_CNN_OS_NoCSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--syn_graph_path "/kaggle/input/etehereum-balanced-gd/graph_data/graphgan_balanced_G1.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GIN \
--classifier CNN \
--epochs_stage2 200 --patience 50 --use_oversampling --output_file
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Loading Synthetic Graph: /kaggle/input/etehereum-balanced-gd/graph_data/graphgan_balanced_G1.pkl
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: DiGraph with 6290 nodes and 17269 edges
# Merge Info: 6091 overlapping nodes (anchors), 199 new synthetic nodes.
# Num nodes 7812 | Features: torch.Size([7812, 28]) | Fraud Train: 238 | Fraud Val: 4 | Fraud Test: 12
# Final Split | Train: 5680 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7812, Edges: 25308, Features: 28
#
# Starting Experiments with 5 seeds. Max Epochs: 200, Patience: 50
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GIN + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_CNN_OS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.1461 | Val Loss: 0.0379
#       Stage 2 Epoch 20 | Loss: 0.1331 | Val Loss: 0.0233
#       Stage 2 Epoch 30 | Loss: 0.0541 | Val Loss: 0.0206
#       Stage 2 Epoch 40 | Loss: 0.0060 | Val Loss: 0.0067
#       Stage 2 Epoch 50 | Loss: 0.0029 | Val Loss: 0.0035
#       Stage 2 Epoch 60 | Loss: 0.0026 | Val Loss: 0.0009
#       Stage 2 Epoch 70 | Loss: 0.0026 | Val Loss: 0.0016
#       Stage 2 Epoch 80 | Loss: 0.0025 | Val Loss: 0.0016
#       Stage 2 Epoch 90 | Loss: 0.0027 | Val Loss: 0.0024
#       Stage 2 Epoch 100 | Loss: 0.0026 | Val Loss: 0.0013
#       Stage 2 Epoch 110 | Loss: 0.0026 | Val Loss: 0.0008
#       Stage 2 Epoch 120 | Loss: 0.0023 | Val Loss: 0.0028
#       Stage 2 Epoch 130 | Loss: 0.0022 | Val Loss: 0.0015
#       Stage 2 Early stopping at epoch 133
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_CNN_OS_NoCSL_0.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9921208141825345, 'prec': 0.5, 'rec': 0.08333333333333333, 'f1': 0.14285714285714285}
# Results ready to be saved to results/eval_first_graph_GIN_CNN_OS_NoCSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GIN + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_CNN_OS_NoCSL_42...
#       Stage 2 Epoch 10 | Loss: 0.1262 | Val Loss: 0.0354
#       Stage 2 Epoch 20 | Loss: 0.0824 | Val Loss: 0.0297
#       Stage 2 Epoch 30 | Loss: 0.0372 | Val Loss: 0.0095
#       Stage 2 Epoch 40 | Loss: 0.0148 | Val Loss: 0.0034
#       Stage 2 Epoch 50 | Loss: 0.0033 | Val Loss: 0.0046
#       Stage 2 Epoch 60 | Loss: 0.0033 | Val Loss: 0.0027
#       Stage 2 Epoch 70 | Loss: 0.0028 | Val Loss: 0.0017
#       Stage 2 Epoch 80 | Loss: 0.0025 | Val Loss: 0.0023
#       Stage 2 Epoch 90 | Loss: 0.0026 | Val Loss: 0.0023
#       Stage 2 Early stopping at epoch 91
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_CNN_OS_NoCSL_42.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9908076165462902, 'prec': 0.25, 'rec': 0.08333333333333333, 'f1': 0.125}
# Results ready to be saved to results/eval_first_graph_GIN_CNN_OS_NoCSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GIN + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_CNN_OS_NoCSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0926 | Val Loss: 0.0323
#       Stage 2 Epoch 20 | Loss: 0.0572 | Val Loss: 0.0101
#       Stage 2 Epoch 30 | Loss: 0.0408 | Val Loss: 0.0092
#       Stage 2 Epoch 40 | Loss: 0.0170 | Val Loss: 0.0060
#       Stage 2 Epoch 50 | Loss: 0.0029 | Val Loss: 0.0039
#       Stage 2 Epoch 60 | Loss: 0.0026 | Val Loss: 0.0045
#       Stage 2 Epoch 70 | Loss: 0.0032 | Val Loss: 0.0032
#       Stage 2 Epoch 80 | Loss: 0.0034 | Val Loss: 0.0020
#       Stage 2 Epoch 90 | Loss: 0.0025 | Val Loss: 0.0016
#       Stage 2 Epoch 100 | Loss: 0.0025 | Val Loss: 0.0023
#       Stage 2 Epoch 110 | Loss: 0.0023 | Val Loss: 0.0023
#       Stage 2 Epoch 120 | Loss: 0.0026 | Val Loss: 0.0011
#       Stage 2 Early stopping at epoch 123
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_CNN_OS_NoCSL_101.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9914642153644123, 'prec': 0.3333333333333333, 'rec': 0.08333333333333333, 'f1': 0.13333333333333333}
# Results ready to be saved to results/eval_first_graph_GIN_CNN_OS_NoCSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GIN + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_CNN_OS_NoCSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.1712 | Val Loss: 0.0336
#       Stage 2 Epoch 20 | Loss: 0.0944 | Val Loss: 0.0169
#       Stage 2 Epoch 30 | Loss: 0.0397 | Val Loss: 0.0120
#       Stage 2 Epoch 40 | Loss: 0.0338 | Val Loss: 0.0068
#       Stage 2 Epoch 50 | Loss: 0.0323 | Val Loss: 0.0058
#       Stage 2 Epoch 60 | Loss: 0.0313 | Val Loss: 0.0057
#       Stage 2 Epoch 70 | Loss: 0.0279 | Val Loss: 0.0055
#       Stage 2 Epoch 80 | Loss: 0.0078 | Val Loss: 0.0030
#       Stage 2 Epoch 90 | Loss: 0.0035 | Val Loss: 0.0047
#       Stage 2 Epoch 100 | Loss: 0.0028 | Val Loss: 0.0024
#       Stage 2 Epoch 110 | Loss: 0.0031 | Val Loss: 0.0039
#       Stage 2 Epoch 120 | Loss: 0.0023 | Val Loss: 0.0003
#       Stage 2 Epoch 130 | Loss: 0.0022 | Val Loss: 0.0013
#       Stage 2 Early stopping at epoch 139
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_CNN_OS_NoCSL_1024.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9908076165462902, 'prec': 0.25, 'rec': 0.08333333333333333, 'f1': 0.125}
# Results ready to be saved to results/eval_first_graph_GIN_CNN_OS_NoCSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GIN + CNN...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_CNN_OS_NoCSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.1504 | Val Loss: 0.0357
#       Stage 2 Epoch 20 | Loss: 0.0895 | Val Loss: 0.0149
#       Stage 2 Epoch 30 | Loss: 0.0254 | Val Loss: 0.0086
#       Stage 2 Epoch 40 | Loss: 0.0063 | Val Loss: 0.0091
#       Stage 2 Epoch 50 | Loss: 0.0035 | Val Loss: 0.0034
#       Stage 2 Epoch 60 | Loss: 0.0029 | Val Loss: 0.0029
#       Stage 2 Epoch 70 | Loss: 0.0028 | Val Loss: 0.0038
#       Stage 2 Epoch 80 | Loss: 0.0025 | Val Loss: 0.0028
#       Stage 2 Epoch 90 | Loss: 0.0029 | Val Loss: 0.0015
#       Stage 2 Epoch 100 | Loss: 0.0030 | Val Loss: 0.0025
#       Stage 2 Epoch 110 | Loss: 0.0022 | Val Loss: 0.0020
#       Stage 2 Epoch 120 | Loss: 0.0025 | Val Loss: 0.0013
#       Stage 2 Epoch 130 | Loss: 0.0026 | Val Loss: 0.0004
#       Stage 2 Early stopping at epoch 139
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_CNN_OS_NoCSL_2025.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: CNN, Oversample: True, CSL: False
# {'acc': 0.9914642153644123, 'prec': 0.3333333333333333, 'rec': 0.08333333333333333, 'f1': 0.13333333333333333}
# Results ready to be saved to results/eval_first_graph_GIN_CNN_OS_NoCSL_2025.json

# %%
# !cd /kaggle/working/results
# !zip -r G1-CNN-GAN-NoCSL.zip /kaggle/working/results/
# Out:
#   adding: kaggle/working/results/ (stored 0%)
#   adding: kaggle/working/results/pred_first_graph_GCN_CNN_OS_NoCSL_1024.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GCN_CNN_OS_NoCSL_0.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_CNN_OS_NoCSL_2025.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GAT_CNN_OS_NoCSL_1024.json (deflated 38%)
#   adding: kaggle/working/results/eval_first_graph_GCN_CNN_OS_NoCSL_1024.json (deflated 39%)
#   adding: kaggle/working/results/pred_first_graph_GAT_CNN_OS_NoCSL_2025.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GAT_CNN_OS_NoCSL_42.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_CNN_OS_NoCSL_0.json (deflated 38%)
#   adding: kaggle/working/results/pred_first_graph_GIN_CNN_OS_NoCSL_42.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GIN_CNN_OS_NoCSL_1024.json (deflated 38%)
#   adding: kaggle/working/results/eval_first_graph_GAT_CNN_OS_NoCSL_101.json (deflated 38%)
#   adding: kaggle/working/results/pred_first_graph_GAT_CNN_OS_NoCSL_1024.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_CNN_OS_NoCSL_42.json (deflated 38%)
#   adding: kaggle/working/results/eval_first_graph_GCN_CNN_OS_NoCSL_2025.json (deflated 38%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_CNN_OS_NoCSL_2025.json (deflated 37%)
#   adding: kaggle/working/results/pred_first_graph_GIN_CNN_OS_NoCSL_1024.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GCN_CNN_OS_NoCSL_2025.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GAT_CNN_OS_NoCSL_0.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GIN_CNN_OS_NoCSL_2025.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_CNN_OS_NoCSL_1024.json (deflated 38%)
#   adding: kaggle/working/results/pred_first_graph_GAT_CNN_OS_NoCSL_101.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GIN_CNN_OS_NoCSL_0.json (deflated 40%)
#   adding: kaggle/working/results/pred_first_graph_GCN_CNN_OS_NoCSL_42.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GIN_CNN_OS_NoCSL_2025.json (deflated 45%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_CNN_OS_NoCSL_42.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GIN_CNN_OS_NoCSL_101.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GCN_CNN_OS_NoCSL_101.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_CNN_OS_NoCSL_101.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GIN_CNN_OS_NoCSL_101.json (deflated 45%)
#   adding: kaggle/working/results/eval_first_graph_GAT_CNN_OS_NoCSL_0.json (deflated 38%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_CNN_OS_NoCSL_0.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GCN_CNN_OS_NoCSL_0.json (deflated 38%)
#   adding: kaggle/working/results/eval_first_graph_GAT_CNN_OS_NoCSL_42.json (deflated 38%)
#   adding: kaggle/working/results/eval_first_graph_GAT_CNN_OS_NoCSL_2025.json (deflated 45%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_CNN_OS_NoCSL_101.json (deflated 38%)
#   adding: kaggle/working/results/eval_first_graph_GIN_CNN_OS_NoCSL_42.json (deflated 38%)
#   adding: kaggle/working/results/eval_first_graph_GCN_CNN_OS_NoCSL_42.json (deflated 39%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_CNN_OS_NoCSL_1024.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GCN_CNN_OS_NoCSL_101.json (deflated 40%)
#   adding: kaggle/working/results/pred_first_graph_GIN_CNN_OS_NoCSL_0.csv (deflated 99%)
