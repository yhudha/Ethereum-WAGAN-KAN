# %%
# !pip install torch_geometric
# !pip install git+https://github.com/Blealtan/efficient-kan.git
# Out:
# Collecting torch_geometric
#   Downloading torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.13.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2025.10.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (7.1.3)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.0.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (2.32.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from torch_geometric) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->torch_geometric) (1.22.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch_geometric) (3.0.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torch_geometric) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torch_geometric) (2025.10.5)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.11/dist-packages (from aiosignal>=1.4.0->aiohttp->torch_geometric) (4.15.0)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torch_geometric) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torch_geometric) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torch_geometric) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torch_geometric) (2024.2.0)
# Downloading torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 21.7 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.7.0
# Collecting git+https://github.com/Blealtan/efficient-kan.git
#   Cloning https://github.com/Blealtan/efficient-kan.git to /tmp/pip-req-build-lnip16y2
#   Running command git clone --filter=blob:none --quiet https://github.com/Blealtan/efficient-kan.git /tmp/pip-req-build-lnip16y2
#   Resolved https://github.com/Blealtan/efficient-kan.git to commit 7b6ce1c87f18c8bc90c208f6b494042344216b11
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (2.6.0+cu124)
# Requirement already satisfied: pytest>=8.2.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (8.4.1)
# Requirement already satisfied: tqdm>=4.66.2 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (4.67.1)
# Requirement already satisfied: torchvision>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from efficient-kan==0.1.0) (0.21.0+cu124)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (2.1.0)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (25.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from pytest>=8.2.0->efficient-kan==0.1.0) (2.19.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (2025.10.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.3.0->efficient-kan==0.1.0)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->efficient-kan==0.1.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.3.0->efficient-kan==0.1.0) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.18.0->efficient-kan==0.1.0) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision>=0.18.0->efficient-kan==0.1.0) (11.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.3.0->efficient-kan==0.1.0) (3.0.3)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2025.3.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2022.3.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2.4.1)
# Requirement already satisfied: onemkl-license==2025.3.0 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2025.3.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2022.3.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision>=0.18.0->efficient-kan==0.1.0) (2024.2.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 94.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 78.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 8.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 30.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 13.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.8 MB/s eta 0:00:00
# Building wheels for collected packages: efficient-kan
#   Building wheel for efficient-kan (pyproject.toml) ... done
#   Created wheel for efficient-kan: filename=efficient_kan-0.1.0-py3-none-any.whl size=5981 sha256=3fadb37365bda971d6bcb716e5ecf58aca9c70ee79e32324453796857b325548
#   Stored in directory: /tmp/pip-ephem-wheel-cache-da0u9bme/wheels/da/a3/b4/30b3e3df2edaded3c87227cb9faea5878f18ec03e1c2137839
# Successfully built efficient-kan
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, efficient-kan
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# Successfully installed efficient-kan-0.1.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127

# %%
# !git clone https://agusth24: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@github.com/agusth24/ethereum-fraud-detection.git
# Out:
# Cloning into 'ethereum-fraud-detection'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 51 (delta 23), reused 45 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (51/51), 14.72 KiB | 14.72 MiB/s, done.
# Resolving deltas: 100% (23/23), done.

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GCN \
--classifier MLP \
--epochs_stage2 1000 --patience 100 --output_file
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Mode: Non-Oversampling
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: None
# Num nodes 7613 | Features: torch.Size([7613, 27]) | Fraud Train: 39 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5481 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7613, Edges: 24108, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 1000, Patience: 100
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GCN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_MLP_NoOS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0423 | Val Loss: 0.0425
#       Stage 2 Epoch 20 | Loss: 0.0198 | Val Loss: 0.0226
#       Stage 2 Epoch 30 | Loss: 0.0155 | Val Loss: 0.0400
#       Stage 2 Epoch 40 | Loss: 0.0134 | Val Loss: 0.0222
#       Stage 2 Epoch 50 | Loss: 0.0119 | Val Loss: 0.0222
#       Stage 2 Epoch 60 | Loss: 0.0120 | Val Loss: 0.0209
#       Stage 2 Epoch 70 | Loss: 0.0101 | Val Loss: 0.0206
#       Stage 2 Epoch 80 | Loss: 0.0108 | Val Loss: 0.0175
#       Stage 2 Epoch 90 | Loss: 0.0099 | Val Loss: 0.0168
#       Stage 2 Epoch 100 | Loss: 0.0107 | Val Loss: 0.0206
#       Stage 2 Epoch 110 | Loss: 0.0103 | Val Loss: 0.0259
#       Stage 2 Epoch 120 | Loss: 0.0093 | Val Loss: 0.0251
#       Stage 2 Epoch 130 | Loss: 0.0093 | Val Loss: 0.0220
#       Stage 2 Epoch 140 | Loss: 0.0095 | Val Loss: 0.0236
#       Stage 2 Epoch 150 | Loss: 0.0107 | Val Loss: 0.0286
#       Stage 2 Epoch 160 | Loss: 0.0102 | Val Loss: 0.0189
#       Stage 2 Epoch 170 | Loss: 0.0099 | Val Loss: 0.0240
#       Stage 2 Epoch 180 | Loss: 0.0095 | Val Loss: 0.0295
#       Stage 2 Early stopping at epoch 190
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_MLP_NoOS_NoCSL_0.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9947472094550229, 'prec': 0.6666666666666666, 'rec': 0.5454545454545454, 'f1': 0.6}
# Results ready to be saved to results/eval_first_graph_GCN_MLP_NoOS_NoCSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GCN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_MLP_NoOS_NoCSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0461 | Val Loss: 0.0207
#       Stage 2 Epoch 20 | Loss: 0.0241 | Val Loss: 0.0193
#       Stage 2 Epoch 30 | Loss: 0.0161 | Val Loss: 0.0451
#       Stage 2 Epoch 40 | Loss: 0.0152 | Val Loss: 0.0201
#       Stage 2 Epoch 50 | Loss: 0.0116 | Val Loss: 0.0181
#       Stage 2 Epoch 60 | Loss: 0.0110 | Val Loss: 0.0186
#       Stage 2 Epoch 70 | Loss: 0.0113 | Val Loss: 0.0202
#       Stage 2 Epoch 80 | Loss: 0.0102 | Val Loss: 0.0186
#       Stage 2 Epoch 90 | Loss: 0.0094 | Val Loss: 0.0195
#       Stage 2 Epoch 100 | Loss: 0.0097 | Val Loss: 0.0227
#       Stage 2 Epoch 110 | Loss: 0.0098 | Val Loss: 0.0167
#       Stage 2 Epoch 120 | Loss: 0.0113 | Val Loss: 0.0208
#       Stage 2 Epoch 130 | Loss: 0.0109 | Val Loss: 0.0188
#       Stage 2 Epoch 140 | Loss: 0.0111 | Val Loss: 0.0164
#       Stage 2 Epoch 150 | Loss: 0.0100 | Val Loss: 0.0180
#       Stage 2 Epoch 160 | Loss: 0.0099 | Val Loss: 0.0213
#       Stage 2 Epoch 170 | Loss: 0.0101 | Val Loss: 0.0237
#       Stage 2 Epoch 180 | Loss: 0.0106 | Val Loss: 0.0217
#       Stage 2 Epoch 190 | Loss: 0.0093 | Val Loss: 0.0305
#       Stage 2 Epoch 200 | Loss: 0.0104 | Val Loss: 0.0206
#       Stage 2 Epoch 210 | Loss: 0.0095 | Val Loss: 0.0174
#       Stage 2 Early stopping at epoch 216
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_MLP_NoOS_NoCSL_42.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9947472094550229, 'prec': 0.6363636363636364, 'rec': 0.6363636363636364, 'f1': 0.6363636363636364}
# Results ready to be saved to results/eval_first_graph_GCN_MLP_NoOS_NoCSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GCN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_MLP_NoOS_NoCSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0466 | Val Loss: 0.0374
#       Stage 2 Epoch 20 | Loss: 0.0271 | Val Loss: 0.0179
#       Stage 2 Epoch 30 | Loss: 0.0192 | Val Loss: 0.0227
#       Stage 2 Epoch 40 | Loss: 0.0139 | Val Loss: 0.0209
#       Stage 2 Epoch 50 | Loss: 0.0144 | Val Loss: 0.0205
#       Stage 2 Epoch 60 | Loss: 0.0107 | Val Loss: 0.0164
#       Stage 2 Epoch 70 | Loss: 0.0101 | Val Loss: 0.0176
#       Stage 2 Epoch 80 | Loss: 0.0098 | Val Loss: 0.0152
#       Stage 2 Epoch 90 | Loss: 0.0098 | Val Loss: 0.0180
#       Stage 2 Epoch 100 | Loss: 0.0101 | Val Loss: 0.0208
#       Stage 2 Epoch 110 | Loss: 0.0092 | Val Loss: 0.0199
#       Stage 2 Epoch 120 | Loss: 0.0104 | Val Loss: 0.0239
#       Stage 2 Epoch 130 | Loss: 0.0098 | Val Loss: 0.0243
#       Stage 2 Epoch 140 | Loss: 0.0097 | Val Loss: 0.0295
#       Stage 2 Epoch 150 | Loss: 0.0106 | Val Loss: 0.0230
#       Stage 2 Early stopping at epoch 158
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_MLP_NoOS_NoCSL_101.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9934340118187788, 'prec': 0.5454545454545454, 'rec': 0.5454545454545454, 'f1': 0.5454545454545454}
# Results ready to be saved to results/eval_first_graph_GCN_MLP_NoOS_NoCSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GCN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_MLP_NoOS_NoCSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.0361 | Val Loss: 0.0316
#       Stage 2 Epoch 20 | Loss: 0.0204 | Val Loss: 0.0196
#       Stage 2 Epoch 30 | Loss: 0.0137 | Val Loss: 0.0172
#       Stage 2 Epoch 40 | Loss: 0.0123 | Val Loss: 0.0210
#       Stage 2 Epoch 50 | Loss: 0.0110 | Val Loss: 0.0223
#       Stage 2 Epoch 60 | Loss: 0.0110 | Val Loss: 0.0221
#       Stage 2 Epoch 70 | Loss: 0.0106 | Val Loss: 0.0194
#       Stage 2 Epoch 80 | Loss: 0.0102 | Val Loss: 0.0224
#       Stage 2 Epoch 90 | Loss: 0.0094 | Val Loss: 0.0253
#       Stage 2 Epoch 100 | Loss: 0.0092 | Val Loss: 0.0209
#       Stage 2 Epoch 110 | Loss: 0.0097 | Val Loss: 0.0230
#       Stage 2 Epoch 120 | Loss: 0.0085 | Val Loss: 0.0265
#       Stage 2 Epoch 130 | Loss: 0.0096 | Val Loss: 0.0252
#       Stage 2 Epoch 140 | Loss: 0.0101 | Val Loss: 0.0188
#       Stage 2 Epoch 150 | Loss: 0.0098 | Val Loss: 0.0175
#       Stage 2 Epoch 160 | Loss: 0.0102 | Val Loss: 0.0265
#       Stage 2 Epoch 170 | Loss: 0.0110 | Val Loss: 0.0332
#       Stage 2 Epoch 180 | Loss: 0.0104 | Val Loss: 0.0253
#       Stage 2 Early stopping at epoch 188
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_MLP_NoOS_NoCSL_1024.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9947472094550229, 'prec': 0.6666666666666666, 'rec': 0.5454545454545454, 'f1': 0.6}
# Results ready to be saved to results/eval_first_graph_GCN_MLP_NoOS_NoCSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GCN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GCN_MLP_NoOS_NoCSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.0440 | Val Loss: 0.0343
#       Stage 2 Epoch 20 | Loss: 0.0233 | Val Loss: 0.0189
#       Stage 2 Epoch 30 | Loss: 0.0170 | Val Loss: 0.0310
#       Stage 2 Epoch 40 | Loss: 0.0154 | Val Loss: 0.0209
#       Stage 2 Epoch 50 | Loss: 0.0115 | Val Loss: 0.0196
#       Stage 2 Epoch 60 | Loss: 0.0101 | Val Loss: 0.0200
#       Stage 2 Epoch 70 | Loss: 0.0102 | Val Loss: 0.0199
#       Stage 2 Epoch 80 | Loss: 0.0102 | Val Loss: 0.0180
#       Stage 2 Epoch 90 | Loss: 0.0097 | Val Loss: 0.0193
#       Stage 2 Epoch 100 | Loss: 0.0097 | Val Loss: 0.0233
#       Stage 2 Epoch 110 | Loss: 0.0103 | Val Loss: 0.0159
#       Stage 2 Epoch 120 | Loss: 0.0101 | Val Loss: 0.0187
#       Stage 2 Epoch 130 | Loss: 0.0091 | Val Loss: 0.0203
#       Stage 2 Epoch 140 | Loss: 0.0086 | Val Loss: 0.0194
#       Stage 2 Epoch 150 | Loss: 0.0092 | Val Loss: 0.0201
#       Stage 2 Epoch 160 | Loss: 0.0086 | Val Loss: 0.0263
#       Stage 2 Early stopping at epoch 165
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GCN_MLP_NoOS_NoCSL_2025.csv
#
# === Final Results ===
# Encoder: GCN, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9940906106369009, 'prec': 0.625, 'rec': 0.45454545454545453, 'f1': 0.5263157894736842}
# Results ready to be saved to results/eval_first_graph_GCN_MLP_NoOS_NoCSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GAT \
--classifier MLP \
--epochs_stage2 1000 --patience 100 --output_file
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Mode: Non-Oversampling
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: None
# Num nodes 7613 | Features: torch.Size([7613, 27]) | Fraud Train: 39 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5481 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7613, Edges: 24108, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 1000, Patience: 100
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GAT + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_MLP_NoOS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0687 | Val Loss: 0.0495
#       Stage 2 Epoch 20 | Loss: 0.0420 | Val Loss: 0.0358
#       Stage 2 Epoch 30 | Loss: 0.0377 | Val Loss: 0.0405
#       Stage 2 Epoch 40 | Loss: 0.0337 | Val Loss: 0.0313
#       Stage 2 Epoch 50 | Loss: 0.0300 | Val Loss: 0.0389
#       Stage 2 Epoch 60 | Loss: 0.0311 | Val Loss: 0.0323
#       Stage 2 Epoch 70 | Loss: 0.0343 | Val Loss: 0.0360
#       Stage 2 Epoch 80 | Loss: 0.0293 | Val Loss: 0.0345
#       Stage 2 Epoch 90 | Loss: 0.0326 | Val Loss: 0.0440
#       Stage 2 Epoch 100 | Loss: 0.0314 | Val Loss: 0.0290
#       Stage 2 Epoch 110 | Loss: 0.0290 | Val Loss: 0.0367
#       Stage 2 Epoch 120 | Loss: 0.0287 | Val Loss: 0.0427
#       Stage 2 Epoch 130 | Loss: 0.0286 | Val Loss: 0.0322
#       Stage 2 Epoch 140 | Loss: 0.0292 | Val Loss: 0.0409
#       Stage 2 Epoch 150 | Loss: 0.0261 | Val Loss: 0.0348
#       Stage 2 Epoch 160 | Loss: 0.0305 | Val Loss: 0.0302
#       Stage 2 Epoch 170 | Loss: 0.0295 | Val Loss: 0.0394
#       Stage 2 Epoch 180 | Loss: 0.0261 | Val Loss: 0.0443
#       Stage 2 Epoch 190 | Loss: 0.0264 | Val Loss: 0.0387
#       Stage 2 Epoch 200 | Loss: 0.0292 | Val Loss: 0.0346
#       Stage 2 Epoch 210 | Loss: 0.0275 | Val Loss: 0.0371
#       Stage 2 Early stopping at epoch 211
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_MLP_NoOS_NoCSL_0.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9921208141825345, 'prec': 0.3333333333333333, 'rec': 0.09090909090909091, 'f1': 0.14285714285714288}
# Results ready to be saved to results/eval_first_graph_GAT_MLP_NoOS_NoCSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GAT + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_MLP_NoOS_NoCSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0718 | Val Loss: 0.0714
#       Stage 2 Epoch 20 | Loss: 0.0416 | Val Loss: 0.0623
#       Stage 2 Epoch 30 | Loss: 0.0390 | Val Loss: 0.0326
#       Stage 2 Epoch 40 | Loss: 0.0359 | Val Loss: 0.0434
#       Stage 2 Epoch 50 | Loss: 0.0327 | Val Loss: 0.0378
#       Stage 2 Epoch 60 | Loss: 0.0323 | Val Loss: 0.0340
#       Stage 2 Epoch 70 | Loss: 0.0364 | Val Loss: 0.0429
#       Stage 2 Epoch 80 | Loss: 0.0310 | Val Loss: 0.0316
#       Stage 2 Epoch 90 | Loss: 0.0308 | Val Loss: 0.0320
#       Stage 2 Epoch 100 | Loss: 0.0312 | Val Loss: 0.0320
#       Stage 2 Epoch 110 | Loss: 0.0306 | Val Loss: 0.0317
#       Stage 2 Epoch 120 | Loss: 0.0242 | Val Loss: 0.0296
#       Stage 2 Epoch 130 | Loss: 0.0303 | Val Loss: 0.0327
#       Stage 2 Epoch 140 | Loss: 0.0292 | Val Loss: 0.0294
#       Stage 2 Epoch 150 | Loss: 0.0301 | Val Loss: 0.0354
#       Stage 2 Early stopping at epoch 158
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_MLP_NoOS_NoCSL_42.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9927774130006566, 'prec': 0.0, 'rec': 0.0, 'f1': 0.0}
# Results ready to be saved to results/eval_first_graph_GAT_MLP_NoOS_NoCSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GAT + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_MLP_NoOS_NoCSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0658 | Val Loss: 0.0355
#       Stage 2 Epoch 20 | Loss: 0.0495 | Val Loss: 0.0394
#       Stage 2 Epoch 30 | Loss: 0.0388 | Val Loss: 0.0373
#       Stage 2 Epoch 40 | Loss: 0.0338 | Val Loss: 0.0192
#       Stage 2 Epoch 50 | Loss: 0.0298 | Val Loss: 0.0422
#       Stage 2 Epoch 60 | Loss: 0.0345 | Val Loss: 0.0414
#       Stage 2 Epoch 70 | Loss: 0.0305 | Val Loss: 0.0316
#       Stage 2 Epoch 80 | Loss: 0.0325 | Val Loss: 0.0247
#       Stage 2 Epoch 90 | Loss: 0.0255 | Val Loss: 0.0344
#       Stage 2 Epoch 100 | Loss: 0.0256 | Val Loss: 0.0341
#       Stage 2 Epoch 110 | Loss: 0.0280 | Val Loss: 0.0382
#       Stage 2 Epoch 120 | Loss: 0.0247 | Val Loss: 0.0216
#       Stage 2 Epoch 130 | Loss: 0.0353 | Val Loss: 0.0311
#       Stage 2 Epoch 140 | Loss: 0.0262 | Val Loss: 0.0322
#       Stage 2 Epoch 150 | Loss: 0.0248 | Val Loss: 0.0301
#       Stage 2 Epoch 160 | Loss: 0.0257 | Val Loss: 0.0197
#       Stage 2 Epoch 170 | Loss: 0.0289 | Val Loss: 0.0335
#       Stage 2 Epoch 180 | Loss: 0.0285 | Val Loss: 0.0343
#       Stage 2 Epoch 190 | Loss: 0.0263 | Val Loss: 0.0379
#       Stage 2 Epoch 200 | Loss: 0.0286 | Val Loss: 0.0392
#       Stage 2 Epoch 210 | Loss: 0.0304 | Val Loss: 0.0365
#       Stage 2 Epoch 220 | Loss: 0.0262 | Val Loss: 0.0439
#       Stage 2 Epoch 230 | Loss: 0.0269 | Val Loss: 0.0269
#       Stage 2 Epoch 240 | Loss: 0.0279 | Val Loss: 0.0258
#       Stage 2 Epoch 250 | Loss: 0.0267 | Val Loss: 0.0363
#       Stage 2 Early stopping at epoch 255
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_MLP_NoOS_NoCSL_101.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9940906106369009, 'prec': 0.625, 'rec': 0.45454545454545453, 'f1': 0.5263157894736842}
# Results ready to be saved to results/eval_first_graph_GAT_MLP_NoOS_NoCSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GAT + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_MLP_NoOS_NoCSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.0736 | Val Loss: 0.0763
#       Stage 2 Epoch 20 | Loss: 0.0456 | Val Loss: 0.0380
#       Stage 2 Epoch 30 | Loss: 0.0359 | Val Loss: 0.0375
#       Stage 2 Epoch 40 | Loss: 0.0397 | Val Loss: 0.0363
#       Stage 2 Epoch 50 | Loss: 0.0361 | Val Loss: 0.0328
#       Stage 2 Epoch 60 | Loss: 0.0358 | Val Loss: 0.0289
#       Stage 2 Epoch 70 | Loss: 0.0337 | Val Loss: 0.0331
#       Stage 2 Epoch 80 | Loss: 0.0357 | Val Loss: 0.0223
#       Stage 2 Epoch 90 | Loss: 0.0301 | Val Loss: 0.0237
#       Stage 2 Epoch 100 | Loss: 0.0304 | Val Loss: 0.0349
#       Stage 2 Epoch 110 | Loss: 0.0364 | Val Loss: 0.0318
#       Stage 2 Epoch 120 | Loss: 0.0319 | Val Loss: 0.0294
#       Stage 2 Epoch 130 | Loss: 0.0341 | Val Loss: 0.0311
#       Stage 2 Epoch 140 | Loss: 0.0328 | Val Loss: 0.0356
#       Stage 2 Epoch 150 | Loss: 0.0292 | Val Loss: 0.0258
#       Stage 2 Epoch 160 | Loss: 0.0288 | Val Loss: 0.0302
#       Stage 2 Early stopping at epoch 161
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_MLP_NoOS_NoCSL_1024.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9914642153644123, 'prec': 0.0, 'rec': 0.0, 'f1': 0.0}
# Results ready to be saved to results/eval_first_graph_GAT_MLP_NoOS_NoCSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GAT + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GAT_MLP_NoOS_NoCSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.0608 | Val Loss: 0.0691
#       Stage 2 Epoch 20 | Loss: 0.0637 | Val Loss: 0.0357
#       Stage 2 Epoch 30 | Loss: 0.0380 | Val Loss: 0.0297
#       Stage 2 Epoch 40 | Loss: 0.0361 | Val Loss: 0.0368
#       Stage 2 Epoch 50 | Loss: 0.0287 | Val Loss: 0.0363
#       Stage 2 Epoch 60 | Loss: 0.0331 | Val Loss: 0.0282
#       Stage 2 Epoch 70 | Loss: 0.0287 | Val Loss: 0.0424
#       Stage 2 Epoch 80 | Loss: 0.0344 | Val Loss: 0.0300
#       Stage 2 Epoch 90 | Loss: 0.0273 | Val Loss: 0.0338
#       Stage 2 Epoch 100 | Loss: 0.0283 | Val Loss: 0.0337
#       Stage 2 Epoch 110 | Loss: 0.0281 | Val Loss: 0.0296
#       Stage 2 Epoch 120 | Loss: 0.0305 | Val Loss: 0.0257
#       Stage 2 Epoch 130 | Loss: 0.0294 | Val Loss: 0.0369
#       Stage 2 Epoch 140 | Loss: 0.0283 | Val Loss: 0.0367
#       Stage 2 Epoch 150 | Loss: 0.0278 | Val Loss: 0.0275
#       Stage 2 Epoch 160 | Loss: 0.0285 | Val Loss: 0.0393
#       Stage 2 Epoch 170 | Loss: 0.0291 | Val Loss: 0.0164
#       Stage 2 Epoch 180 | Loss: 0.0246 | Val Loss: 0.0386
#       Stage 2 Epoch 190 | Loss: 0.0276 | Val Loss: 0.0203
#       Stage 2 Epoch 200 | Loss: 0.0286 | Val Loss: 0.0205
#       Stage 2 Epoch 210 | Loss: 0.0260 | Val Loss: 0.0299
#       Stage 2 Early stopping at epoch 215
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GAT_MLP_NoOS_NoCSL_2025.csv
#
# === Final Results ===
# Encoder: GAT, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9914642153644123, 'prec': 0.0, 'rec': 0.0, 'f1': 0.0}
# Results ready to be saved to results/eval_first_graph_GAT_MLP_NoOS_NoCSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GraphSAGE \
--classifier MLP \
--epochs_stage2 1000 --patience 100 --output_file
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Mode: Non-Oversampling
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: None
# Num nodes 7613 | Features: torch.Size([7613, 27]) | Fraud Train: 39 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5481 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7613, Edges: 24108, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 1000, Patience: 100
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GraphSAGE + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_MLP_NoOS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0444 | Val Loss: 0.0526
#       Stage 2 Epoch 20 | Loss: 0.0179 | Val Loss: 0.0132
#       Stage 2 Epoch 30 | Loss: 0.0114 | Val Loss: 0.0175
#       Stage 2 Epoch 40 | Loss: 0.0092 | Val Loss: 0.0207
#       Stage 2 Epoch 50 | Loss: 0.0099 | Val Loss: 0.0296
#       Stage 2 Epoch 60 | Loss: 0.0089 | Val Loss: 0.0178
#       Stage 2 Epoch 70 | Loss: 0.0079 | Val Loss: 0.0148
#       Stage 2 Epoch 80 | Loss: 0.0068 | Val Loss: 0.0146
#       Stage 2 Epoch 90 | Loss: 0.0065 | Val Loss: 0.0160
#       Stage 2 Epoch 100 | Loss: 0.0063 | Val Loss: 0.0145
#       Stage 2 Epoch 110 | Loss: 0.0070 | Val Loss: 0.0120
#       Stage 2 Epoch 120 | Loss: 0.0068 | Val Loss: 0.0179
#       Stage 2 Early stopping at epoch 122
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_MLP_NoOS_NoCSL_0.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9940906106369009, 'prec': 0.5833333333333334, 'rec': 0.6363636363636364, 'f1': 0.6086956521739131}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_MLP_NoOS_NoCSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GraphSAGE + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_MLP_NoOS_NoCSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0323 | Val Loss: 0.0337
#       Stage 2 Epoch 20 | Loss: 0.0146 | Val Loss: 0.0103
#       Stage 2 Epoch 30 | Loss: 0.0111 | Val Loss: 0.0153
#       Stage 2 Epoch 40 | Loss: 0.0083 | Val Loss: 0.0194
#       Stage 2 Epoch 50 | Loss: 0.0068 | Val Loss: 0.0172
#       Stage 2 Epoch 60 | Loss: 0.0074 | Val Loss: 0.0158
#       Stage 2 Epoch 70 | Loss: 0.0078 | Val Loss: 0.0140
#       Stage 2 Epoch 80 | Loss: 0.0078 | Val Loss: 0.0116
#       Stage 2 Epoch 90 | Loss: 0.0065 | Val Loss: 0.0120
#       Stage 2 Epoch 100 | Loss: 0.0064 | Val Loss: 0.0212
#       Stage 2 Epoch 110 | Loss: 0.0049 | Val Loss: 0.0137
#       Stage 2 Early stopping at epoch 120
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_MLP_NoOS_NoCSL_42.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9940906106369009, 'prec': 0.6, 'rec': 0.5454545454545454, 'f1': 0.5714285714285713}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_MLP_NoOS_NoCSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GraphSAGE + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_MLP_NoOS_NoCSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0376 | Val Loss: 0.0372
#       Stage 2 Epoch 20 | Loss: 0.0136 | Val Loss: 0.0179
#       Stage 2 Epoch 30 | Loss: 0.0126 | Val Loss: 0.0291
#       Stage 2 Epoch 40 | Loss: 0.0072 | Val Loss: 0.0136
#       Stage 2 Epoch 50 | Loss: 0.0066 | Val Loss: 0.0134
#       Stage 2 Epoch 60 | Loss: 0.0082 | Val Loss: 0.0136
#       Stage 2 Epoch 70 | Loss: 0.0067 | Val Loss: 0.0154
#       Stage 2 Epoch 80 | Loss: 0.0077 | Val Loss: 0.0107
#       Stage 2 Epoch 90 | Loss: 0.0063 | Val Loss: 0.0127
#       Stage 2 Epoch 100 | Loss: 0.0063 | Val Loss: 0.0188
#       Stage 2 Epoch 110 | Loss: 0.0052 | Val Loss: 0.0125
#       Stage 2 Epoch 120 | Loss: 0.0050 | Val Loss: 0.0232
#       Stage 2 Epoch 130 | Loss: 0.0050 | Val Loss: 0.0144
#       Stage 2 Epoch 140 | Loss: 0.0054 | Val Loss: 0.0136
#       Stage 2 Epoch 150 | Loss: 0.0057 | Val Loss: 0.0162
#       Stage 2 Epoch 160 | Loss: 0.0058 | Val Loss: 0.0164
#       Stage 2 Epoch 170 | Loss: 0.0056 | Val Loss: 0.0130
#       Stage 2 Epoch 180 | Loss: 0.0069 | Val Loss: 0.0148
#       Stage 2 Epoch 190 | Loss: 0.0077 | Val Loss: 0.0168
#       Stage 2 Epoch 200 | Loss: 0.0057 | Val Loss: 0.0126
#       Stage 2 Epoch 210 | Loss: 0.0071 | Val Loss: 0.0186
#       Stage 2 Epoch 220 | Loss: 0.0060 | Val Loss: 0.0146
#       Stage 2 Epoch 230 | Loss: 0.0052 | Val Loss: 0.0161
#       Stage 2 Epoch 240 | Loss: 0.0053 | Val Loss: 0.0120
#       Stage 2 Epoch 250 | Loss: 0.0050 | Val Loss: 0.0192
#       Stage 2 Epoch 260 | Loss: 0.0060 | Val Loss: 0.0113
#       Stage 2 Epoch 270 | Loss: 0.0057 | Val Loss: 0.0125
#       Stage 2 Epoch 280 | Loss: 0.0063 | Val Loss: 0.0092
#       Stage 2 Early stopping at epoch 284
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_MLP_NoOS_NoCSL_101.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9986868023637557, 'prec': 0.9090909090909091, 'rec': 0.9090909090909091, 'f1': 0.9090909090909091}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_MLP_NoOS_NoCSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GraphSAGE + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_MLP_NoOS_NoCSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.0333 | Val Loss: 0.0297
#       Stage 2 Epoch 20 | Loss: 0.0156 | Val Loss: 0.0226
#       Stage 2 Epoch 30 | Loss: 0.0115 | Val Loss: 0.0233
#       Stage 2 Epoch 40 | Loss: 0.0091 | Val Loss: 0.0168
#       Stage 2 Epoch 50 | Loss: 0.0070 | Val Loss: 0.0243
#       Stage 2 Epoch 60 | Loss: 0.0075 | Val Loss: 0.0221
#       Stage 2 Epoch 70 | Loss: 0.0075 | Val Loss: 0.0187
#       Stage 2 Epoch 80 | Loss: 0.0071 | Val Loss: 0.0139
#       Stage 2 Epoch 90 | Loss: 0.0066 | Val Loss: 0.0138
#       Stage 2 Epoch 100 | Loss: 0.0064 | Val Loss: 0.0127
#       Stage 2 Epoch 110 | Loss: 0.0058 | Val Loss: 0.0121
#       Stage 2 Epoch 120 | Loss: 0.0067 | Val Loss: 0.0197
#       Stage 2 Epoch 130 | Loss: 0.0056 | Val Loss: 0.0138
#       Stage 2 Epoch 140 | Loss: 0.0055 | Val Loss: 0.0098
#       Stage 2 Epoch 150 | Loss: 0.0063 | Val Loss: 0.0133
#       Stage 2 Epoch 160 | Loss: 0.0067 | Val Loss: 0.0170
#       Stage 2 Epoch 170 | Loss: 0.0075 | Val Loss: 0.0154
#       Stage 2 Epoch 180 | Loss: 0.0058 | Val Loss: 0.0138
#       Stage 2 Epoch 190 | Loss: 0.0064 | Val Loss: 0.0123
#       Stage 2 Epoch 200 | Loss: 0.0064 | Val Loss: 0.0168
#       Stage 2 Epoch 210 | Loss: 0.0081 | Val Loss: 0.0147
#       Stage 2 Epoch 220 | Loss: 0.0062 | Val Loss: 0.0103
#       Stage 2 Epoch 230 | Loss: 0.0080 | Val Loss: 0.0137
#       Stage 2 Early stopping at epoch 235
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_MLP_NoOS_NoCSL_1024.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9980302035456337, 'prec': 1.0, 'rec': 0.7272727272727273, 'f1': 0.8421052631578948}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_MLP_NoOS_NoCSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GraphSAGE + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GraphSAGE_MLP_NoOS_NoCSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.0362 | Val Loss: 0.0396
#       Stage 2 Epoch 20 | Loss: 0.0176 | Val Loss: 0.0187
#       Stage 2 Epoch 30 | Loss: 0.0106 | Val Loss: 0.0182
#       Stage 2 Epoch 40 | Loss: 0.0096 | Val Loss: 0.0120
#       Stage 2 Epoch 50 | Loss: 0.0085 | Val Loss: 0.0170
#       Stage 2 Epoch 60 | Loss: 0.0081 | Val Loss: 0.0133
#       Stage 2 Epoch 70 | Loss: 0.0068 | Val Loss: 0.0124
#       Stage 2 Epoch 80 | Loss: 0.0071 | Val Loss: 0.0133
#       Stage 2 Epoch 90 | Loss: 0.0085 | Val Loss: 0.0153
#       Stage 2 Epoch 100 | Loss: 0.0068 | Val Loss: 0.0179
#       Stage 2 Epoch 110 | Loss: 0.0075 | Val Loss: 0.0163
#       Stage 2 Epoch 120 | Loss: 0.0062 | Val Loss: 0.0130
#       Stage 2 Epoch 130 | Loss: 0.0068 | Val Loss: 0.0106
#       Stage 2 Epoch 140 | Loss: 0.0059 | Val Loss: 0.0084
#       Stage 2 Epoch 150 | Loss: 0.0061 | Val Loss: 0.0114
#       Stage 2 Epoch 160 | Loss: 0.0051 | Val Loss: 0.0102
#       Stage 2 Epoch 170 | Loss: 0.0053 | Val Loss: 0.0106
#       Stage 2 Epoch 180 | Loss: 0.0064 | Val Loss: 0.0138
#       Stage 2 Epoch 190 | Loss: 0.0050 | Val Loss: 0.0164
#       Stage 2 Epoch 200 | Loss: 0.0047 | Val Loss: 0.0098
#       Stage 2 Epoch 210 | Loss: 0.0050 | Val Loss: 0.0109
#       Stage 2 Early stopping at epoch 215
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GraphSAGE_MLP_NoOS_NoCSL_2025.csv
#
# === Final Results ===
# Encoder: GraphSAGE, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9973736047275115, 'prec': 1.0, 'rec': 0.6363636363636364, 'f1': 0.7777777777777778}
# Results ready to be saved to results/eval_first_graph_GraphSAGE_MLP_NoOS_NoCSL_2025.json

# %%
# !python /kaggle/working/ethereum-fraud-detection/train.py \
--main_graph_path "/kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl" \
--test_nodes_path "/kaggle/input/ethereum-graph-dataset/first_test_graph.json" \
--encoder GIN \
--classifier MLP \
--epochs_stage2 1000 --patience 100 --output_file
# Out:
# Using device: cuda
# Loading Main Graph: /kaggle/input/ethereum-graph-dataset/graph_data/first_graph.pkl
# Mode: Non-Oversampling
# Loading Test Nodes...
# Merging and Converting to PyG Data...
# Graph Real: DiGraph with 7613 nodes and 24108 edges | Graph Syn: None
# Num nodes 7613 | Features: torch.Size([7613, 27]) | Fraud Train: 39 | Fraud Val: 4 | Fraud Test: 11
# Final Split | Train: 5481 (Real+Syn), Val: 609 (Real), Test: 1523 (Real)
# Data Ready. Nodes: 7613, Edges: 24108, Features: 27
#
# Starting Experiments with 5 seeds. Max Epochs: 1000, Patience: 100
# ======================================================================
#
# [RUN 1/5] Setting Seed: 0
# Initializing GIN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_MLP_NoOS_NoCSL_0...
#       Stage 2 Epoch 10 | Loss: 0.0574 | Val Loss: 0.0541
#       Stage 2 Epoch 20 | Loss: 0.0385 | Val Loss: 0.0362
#       Stage 2 Epoch 30 | Loss: 0.0316 | Val Loss: 0.0363
#       Stage 2 Epoch 40 | Loss: 0.0245 | Val Loss: 0.0334
#       Stage 2 Epoch 50 | Loss: 0.0184 | Val Loss: 0.0256
#       Stage 2 Epoch 60 | Loss: 0.0177 | Val Loss: 0.0285
#       Stage 2 Epoch 70 | Loss: 0.0133 | Val Loss: 0.0227
#       Stage 2 Epoch 80 | Loss: 0.0122 | Val Loss: 0.0299
#       Stage 2 Epoch 90 | Loss: 0.0118 | Val Loss: 0.0278
#       Stage 2 Epoch 100 | Loss: 0.0129 | Val Loss: 0.0188
#       Stage 2 Epoch 110 | Loss: 0.0122 | Val Loss: 0.0268
#       Stage 2 Epoch 120 | Loss: 0.0106 | Val Loss: 0.0305
#       Stage 2 Epoch 130 | Loss: 0.0102 | Val Loss: 0.0272
#       Stage 2 Epoch 140 | Loss: 0.0102 | Val Loss: 0.0255
#       Stage 2 Epoch 150 | Loss: 0.0142 | Val Loss: 0.0288
#       Stage 2 Epoch 160 | Loss: 0.0115 | Val Loss: 0.0251
#       Stage 2 Epoch 170 | Loss: 0.0096 | Val Loss: 0.0354
#       Stage 2 Epoch 180 | Loss: 0.0082 | Val Loss: 0.0412
#       Stage 2 Early stopping at epoch 188
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_MLP_NoOS_NoCSL_0.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9940906106369009, 'prec': 0.6, 'rec': 0.5454545454545454, 'f1': 0.5714285714285713}
# Results ready to be saved to results/eval_first_graph_GIN_MLP_NoOS_NoCSL_0.json
#
# [RUN 2/5] Setting Seed: 42
# Initializing GIN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_MLP_NoOS_NoCSL_42...
#       Stage 2 Epoch 10 | Loss: 0.0620 | Val Loss: 0.0527
#       Stage 2 Epoch 20 | Loss: 0.0343 | Val Loss: 0.0324
#       Stage 2 Epoch 30 | Loss: 0.0233 | Val Loss: 0.0282
#       Stage 2 Epoch 40 | Loss: 0.0194 | Val Loss: 0.0237
#       Stage 2 Epoch 50 | Loss: 0.0135 | Val Loss: 0.0214
#       Stage 2 Epoch 60 | Loss: 0.0150 | Val Loss: 0.0258
#       Stage 2 Epoch 70 | Loss: 0.0118 | Val Loss: 0.0333
#       Stage 2 Epoch 80 | Loss: 0.0107 | Val Loss: 0.0200
#       Stage 2 Epoch 90 | Loss: 0.0109 | Val Loss: 0.0180
#       Stage 2 Epoch 100 | Loss: 0.0114 | Val Loss: 0.0291
#       Stage 2 Epoch 110 | Loss: 0.0105 | Val Loss: 0.0270
#       Stage 2 Epoch 120 | Loss: 0.0093 | Val Loss: 0.0323
#       Stage 2 Early stopping at epoch 129
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_MLP_NoOS_NoCSL_42.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9927774130006566, 'prec': 0.0, 'rec': 0.0, 'f1': 0.0}
# Results ready to be saved to results/eval_first_graph_GIN_MLP_NoOS_NoCSL_42.json
#
# [RUN 3/5] Setting Seed: 101
# Initializing GIN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_MLP_NoOS_NoCSL_101...
#       Stage 2 Epoch 10 | Loss: 0.0501 | Val Loss: 0.0447
#       Stage 2 Epoch 20 | Loss: 0.0316 | Val Loss: 0.0361
#       Stage 2 Epoch 30 | Loss: 0.0205 | Val Loss: 0.0269
#       Stage 2 Epoch 40 | Loss: 0.0150 | Val Loss: 0.0203
#       Stage 2 Epoch 50 | Loss: 0.0125 | Val Loss: 0.0306
#       Stage 2 Epoch 60 | Loss: 0.0114 | Val Loss: 0.0314
#       Stage 2 Epoch 70 | Loss: 0.0131 | Val Loss: 0.0308
#       Stage 2 Epoch 80 | Loss: 0.0118 | Val Loss: 0.0309
#       Stage 2 Epoch 90 | Loss: 0.0113 | Val Loss: 0.0310
#       Stage 2 Epoch 100 | Loss: 0.0109 | Val Loss: 0.0375
#       Stage 2 Epoch 110 | Loss: 0.0091 | Val Loss: 0.0330
#       Stage 2 Epoch 120 | Loss: 0.0086 | Val Loss: 0.0446
#       Stage 2 Epoch 130 | Loss: 0.0134 | Val Loss: 0.0296
#       Stage 2 Early stopping at epoch 138
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_MLP_NoOS_NoCSL_101.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9954038082731451, 'prec': 0.75, 'rec': 0.5454545454545454, 'f1': 0.631578947368421}
# Results ready to be saved to results/eval_first_graph_GIN_MLP_NoOS_NoCSL_101.json
#
# [RUN 4/5] Setting Seed: 1024
# Initializing GIN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_MLP_NoOS_NoCSL_1024...
#       Stage 2 Epoch 10 | Loss: 0.0661 | Val Loss: 0.0636
#       Stage 2 Epoch 20 | Loss: 0.0374 | Val Loss: 0.0347
#       Stage 2 Epoch 30 | Loss: 0.0308 | Val Loss: 0.0315
#       Stage 2 Epoch 40 | Loss: 0.0240 | Val Loss: 0.0275
#       Stage 2 Epoch 50 | Loss: 0.0179 | Val Loss: 0.0286
#       Stage 2 Epoch 60 | Loss: 0.0139 | Val Loss: 0.0299
#       Stage 2 Epoch 70 | Loss: 0.0122 | Val Loss: 0.0303
#       Stage 2 Epoch 80 | Loss: 0.0121 | Val Loss: 0.0152
#       Stage 2 Epoch 90 | Loss: 0.0118 | Val Loss: 0.0320
#       Stage 2 Epoch 100 | Loss: 0.0169 | Val Loss: 0.0268
#       Stage 2 Epoch 110 | Loss: 0.0141 | Val Loss: 0.0212
#       Stage 2 Epoch 120 | Loss: 0.0131 | Val Loss: 0.0224
#       Stage 2 Epoch 130 | Loss: 0.0138 | Val Loss: 0.0311
#       Stage 2 Epoch 140 | Loss: 0.0111 | Val Loss: 0.0250
#       Stage 2 Epoch 150 | Loss: 0.0095 | Val Loss: 0.0335
#       Stage 2 Epoch 160 | Loss: 0.0104 | Val Loss: 0.0414
#       Stage 2 Epoch 170 | Loss: 0.0091 | Val Loss: 0.0378
#       Stage 2 Early stopping at epoch 180
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_MLP_NoOS_NoCSL_1024.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9947472094550229, 'prec': 0.6363636363636364, 'rec': 0.6363636363636364, 'f1': 0.6363636363636364}
# Results ready to be saved to results/eval_first_graph_GIN_MLP_NoOS_NoCSL_1024.json
#
# [RUN 5/5] Setting Seed: 2025
# Initializing GIN + MLP...
#    [SKIP STAGE 1] Non-CSL mode selected.
#    [STAGE 2] Fine-tuning Classifier for first_graph_GIN_MLP_NoOS_NoCSL_2025...
#       Stage 2 Epoch 10 | Loss: 0.0550 | Val Loss: 0.0473
#       Stage 2 Epoch 20 | Loss: 0.0380 | Val Loss: 0.0326
#       Stage 2 Epoch 30 | Loss: 0.0286 | Val Loss: 0.0277
#       Stage 2 Epoch 40 | Loss: 0.0251 | Val Loss: 0.0312
#       Stage 2 Epoch 50 | Loss: 0.0207 | Val Loss: 0.0293
#       Stage 2 Epoch 60 | Loss: 0.0161 | Val Loss: 0.0248
#       Stage 2 Epoch 70 | Loss: 0.0135 | Val Loss: 0.0313
#       Stage 2 Epoch 80 | Loss: 0.0129 | Val Loss: 0.0211
#       Stage 2 Epoch 90 | Loss: 0.0128 | Val Loss: 0.0209
#       Stage 2 Epoch 100 | Loss: 0.0136 | Val Loss: 0.0254
#       Stage 2 Epoch 110 | Loss: 0.0120 | Val Loss: 0.0253
#       Stage 2 Epoch 120 | Loss: 0.0112 | Val Loss: 0.0242
#       Stage 2 Epoch 130 | Loss: 0.0104 | Val Loss: 0.0290
#       Stage 2 Epoch 140 | Loss: 0.0087 | Val Loss: 0.0288
#       Stage 2 Epoch 150 | Loss: 0.0089 | Val Loss: 0.0294
#       Stage 2 Epoch 160 | Loss: 0.0074 | Val Loss: 0.0253
#       Stage 2 Epoch 170 | Loss: 0.0073 | Val Loss: 0.0329
#       Stage 2 Epoch 180 | Loss: 0.0084 | Val Loss: 0.0305
#       Stage 2 Epoch 190 | Loss: 0.0076 | Val Loss: 0.0241
#       Stage 2 Early stopping at epoch 191
#    Loading best model weights from Stage 2...
# Predictions ready to be saved to results/pred_first_graph_GIN_MLP_NoOS_NoCSL_2025.csv
#
# === Final Results ===
# Encoder: GIN, Classifier: MLP, Oversample: False, CSL: False
# {'acc': 0.9940906106369009, 'prec': 0.6666666666666666, 'rec': 0.36363636363636365, 'f1': 0.4705882352941177}
# Results ready to be saved to results/eval_first_graph_GIN_MLP_NoOS_NoCSL_2025.json

# %%
# !cd /kaggle/working/results
# !zip -r G1-MLP-NoOS-NoCSL.zip /kaggle/working/results/
# Out:
#   adding: kaggle/working/results/ (stored 0%)
#   adding: kaggle/working/results/eval_first_graph_GAT_MLP_NoOS_NoCSL_101.json (deflated 38%)
#   adding: kaggle/working/results/pred_first_graph_GAT_MLP_NoOS_NoCSL_1024.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GAT_MLP_NoOS_NoCSL_42.json (deflated 37%)
#   adding: kaggle/working/results/pred_first_graph_GAT_MLP_NoOS_NoCSL_42.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GCN_MLP_NoOS_NoCSL_1024.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_MLP_NoOS_NoCSL_2025.json (deflated 39%)
#   adding: kaggle/working/results/eval_first_graph_GCN_MLP_NoOS_NoCSL_0.json (deflated 43%)
#   adding: kaggle/working/results/eval_first_graph_GAT_MLP_NoOS_NoCSL_1024.json (deflated 37%)
#   adding: kaggle/working/results/eval_first_graph_GAT_MLP_NoOS_NoCSL_0.json (deflated 43%)
#   adding: kaggle/working/results/eval_first_graph_GCN_MLP_NoOS_NoCSL_42.json (deflated 47%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_MLP_NoOS_NoCSL_101.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_MLP_NoOS_NoCSL_1024.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_MLP_NoOS_NoCSL_1024.json (deflated 36%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_MLP_NoOS_NoCSL_42.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GCN_MLP_NoOS_NoCSL_2025.json (deflated 39%)
#   adding: kaggle/working/results/eval_first_graph_GIN_MLP_NoOS_NoCSL_101.json (deflated 38%)
#   adding: kaggle/working/results/eval_first_graph_GCN_MLP_NoOS_NoCSL_101.json (deflated 47%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_MLP_NoOS_NoCSL_42.json (deflated 40%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_MLP_NoOS_NoCSL_0.json (deflated 41%)
#   adding: kaggle/working/results/eval_first_graph_GraphSAGE_MLP_NoOS_NoCSL_101.json (deflated 48%)
#   adding: kaggle/working/results/eval_first_graph_GIN_MLP_NoOS_NoCSL_1024.json (deflated 47%)
#   adding: kaggle/working/results/pred_first_graph_GIN_MLP_NoOS_NoCSL_1024.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GIN_MLP_NoOS_NoCSL_42.json (deflated 37%)
#   adding: kaggle/working/results/pred_first_graph_GCN_MLP_NoOS_NoCSL_0.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GIN_MLP_NoOS_NoCSL_2025.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GCN_MLP_NoOS_NoCSL_1024.json (deflated 43%)
#   adding: kaggle/working/results/eval_first_graph_GIN_MLP_NoOS_NoCSL_2025.json (deflated 41%)
#   adding: kaggle/working/results/pred_first_graph_GCN_MLP_NoOS_NoCSL_2025.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_MLP_NoOS_NoCSL_0.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GIN_MLP_NoOS_NoCSL_0.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GraphSAGE_MLP_NoOS_NoCSL_2025.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GAT_MLP_NoOS_NoCSL_2025.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GCN_MLP_NoOS_NoCSL_42.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GIN_MLP_NoOS_NoCSL_101.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GAT_MLP_NoOS_NoCSL_0.csv (deflated 99%)
#   adding: kaggle/working/results/eval_first_graph_GAT_MLP_NoOS_NoCSL_2025.json (deflated 37%)
#   adding: kaggle/working/results/pred_first_graph_GCN_MLP_NoOS_NoCSL_101.csv (deflated 98%)
#   adding: kaggle/working/results/pred_first_graph_GIN_MLP_NoOS_NoCSL_42.csv (deflated 99%)
#   adding: kaggle/working/results/pred_first_graph_GAT_MLP_NoOS_NoCSL_101.csv (deflated 98%)
#   adding: kaggle/working/results/eval_first_graph_GIN_MLP_NoOS_NoCSL_0.json (deflated 41%)
